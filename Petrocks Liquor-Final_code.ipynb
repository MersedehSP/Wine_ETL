# %%
import time
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from splinter import Browser

# %%
# Import Splinter and set the chromedriver path

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\merse\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache

# %%
url = "https://www.petrocksliquors.com/category_Wine"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
petrocks_url = "https://www.petrocksliquors.com/category_Wine"
browser.visit(petrocks_url)

wine_list = []

for i in range (247):    
     
    
            for j in range(19):
                time.sleep(3)
                wine ={}
            
                browser.find_by_tag('div[style="width:200px; height:200px;overflow: hidden;"]')[j].click()
                wine_html =  browser.html
                wine_soup = BeautifulSoup(wine_html, 'html.parser')


                try:

                    name = wine_soup.find("span", id="bmg_itemdetail_prod_title").text
                    try: 
                        country =wine_soup.find_all("a", class_="reglink")[0].text
                    except:
                        country = "N/A"
                    try:    
                        region = wine_soup.find(text= "Region:").findNext("a").contents[0]
                    except:
                        region = "N/A"
                    try:
                        sub_region = wine_soup.find(text= "Sub-Region:").findNext("a").contents[0]
                    except:

                        sub_region = "N/A"
                    try:

                        grape_varietal = wine_soup.find(text= "Grape Varietal:").findNext("a").contents[0]
                    except:
                        grape_varietal = "N/A"
                    try:    
                        wine_type = wine_soup.find(text= "Type:").findNext("a").contents[0]
                    except:
                        wine_type = "N/A"
                    try:    
                        bottle_price = wine_soup.find("span", class_="RegularPrice").text
                    except:
                        bottle_price = "N/A"
                    try:
                        sale_price = wine_soup.find("span", class_="SalePrice").text
                    except:
                        sale_price = "N/A"
                    try:    
                        description = wine_soup.find("div", id="moreinfo")
                        description = description.find_all("tr")[1].text
                    except:
                        description = "N/A"
                    merchant = "Petrocks Liquors"
                    address = "419 Amwell Road Hillsborough, NJ 08844"
                except:
                    name= None
                    country =None
                    region = None
                    sub_region = None
                    grape_varietal = None
                    wine_type = None
                    bottle_price = None
                    sale_price = None
                    description = None
                    merchant = None
                    address = None
                wine={
                     "name":name, 
                     "country": country,
                     "region": region,
                    "sub_region": sub_region,
                     "grape_varietal" : grape_varietal,
                      "wine_type" : wine_type,
                       "bottle_price":bottle_price,
                       "sale_price":sale_price,
                       "description" : description, 
                       "merchant": merchant,
                       "address" :address
                     }

                wine_list.append(wine)
        
                browser.back()
            browser.find_by_text(">>").click()
            print(f"I clicked on next page :D", {i})
        
wine_list
# Out:
# I clicked on next page :D {0}
# I clicked on next page :D {1}
# I clicked on next page :D {2}
# I clicked on next page :D {3}
# I clicked on next page :D {4}
# I clicked on next page :D {5}
# I clicked on next page :D {6}
# I clicked on next page :D {7}
# I clicked on next page :D {8}
# I clicked on next page :D {9}
# I clicked on next page :D {10}
# I clicked on next page :D {11}
# I clicked on next page :D {12}
# I clicked on next page :D {13}
# I clicked on next page :D {14}
# I clicked on next page :D {15}
# I clicked on next page :D {16}
# I clicked on next page :D {17}
# I clicked on next page :D {18}
# I clicked on next page :D {19}
# I clicked on next page :D {20}
# I clicked on next page :D {21}
# I clicked on next page :D {22}
# I clicked on next page :D {23}
# I clicked on next page :D {24}
# I clicked on next page :D {25}
# I clicked on next page :D {26}
# I clicked on next page :D {27}
# I clicked on next page :D {28}
# I clicked on next page :D {29}
# I clicked on next page :D {30}
# I clicked on next page :D {31}
# I clicked on next page :D {32}
# I clicked on next page :D {33}
# I clicked on next page :D {34}
# I clicked on next page :D {35}
# I clicked on next page :D {36}
# I clicked on next page :D {37}
# I clicked on next page :D {38}
# I clicked on next page :D {39}
# I clicked on next page :D {40}
# I clicked on next page :D {41}
# I clicked on next page :D {42}
# I clicked on next page :D {43}
# I clicked on next page :D {44}
# I clicked on next page :D {45}
# I clicked on next page :D {46}
# I clicked on next page :D {47}
# I clicked on next page :D {48}
# I clicked on next page :D {49}
# I clicked on next page :D {50}
# I clicked on next page :D {51}
# I clicked on next page :D {52}
# I clicked on next page :D {53}
# I clicked on next page :D {54}
# I clicked on next page :D {55}
# I clicked on next page :D {56}
# I clicked on next page :D {57}
# I clicked on next page :D {58}
# I clicked on next page :D {59}
# I clicked on next page :D {60}
# I clicked on next page :D {61}
# I clicked on next page :D {62}
# I clicked on next page :D {63}
# I clicked on next page :D {64}
# I clicked on next page :D {65}
# I clicked on next page :D {66}
# I clicked on next page :D {67}
# I clicked on next page :D {68}
# I clicked on next page :D {69}
# I clicked on next page :D {70}
# I clicked on next page :D {71}
# I clicked on next page :D {72}
# I clicked on next page :D {73}
# I clicked on next page :D {74}
# I clicked on next page :D {75}
# I clicked on next page :D {76}
# I clicked on next page :D {77}
# I clicked on next page :D {78}
# I clicked on next page :D {79}
# I clicked on next page :D {80}
# I clicked on next page :D {81}
# I clicked on next page :D {82}
# I clicked on next page :D {83}
# I clicked on next page :D {84}
# I clicked on next page :D {85}
# I clicked on next page :D {86}
# I clicked on next page :D {87}
# I clicked on next page :D {88}
# I clicked on next page :D {89}
# I clicked on next page :D {90}
# I clicked on next page :D {91}
# I clicked on next page :D {92}
# I clicked on next page :D {93}
# I clicked on next page :D {94}
# I clicked on next page :D {95}
# I clicked on next page :D {96}
# I clicked on next page :D {97}
# I clicked on next page :D {98}
# I clicked on next page :D {99}
# I clicked on next page :D {100}
# I clicked on next page :D {101}
# I clicked on next page :D {102}
# I clicked on next page :D {103}
# I clicked on next page :D {104}
# I clicked on next page :D {105}
# I clicked on next page :D {106}
# I clicked on next page :D {107}
# I clicked on next page :D {108}
# I clicked on next page :D {109}
# I clicked on next page :D {110}
# I clicked on next page :D {111}
# I clicked on next page :D {112}
# I clicked on next page :D {113}
# I clicked on next page :D {114}
# I clicked on next page :D {115}
# I clicked on next page :D {116}
# I clicked on next page :D {117}
# I clicked on next page :D {118}
# I clicked on next page :D {119}
# I clicked on next page :D {120}
# I clicked on next page :D {121}
# I clicked on next page :D {122}
# I clicked on next page :D {123}
# I clicked on next page :D {124}
# I clicked on next page :D {125}
# I clicked on next page :D {126}
# I clicked on next page :D {127}
# I clicked on next page :D {128}
# I clicked on next page :D {129}
# I clicked on next page :D {130}
# I clicked on next page :D {131}
# I clicked on next page :D {132}
# I clicked on next page :D {133}
# I clicked on next page :D {134}
# I clicked on next page :D {135}
# I clicked on next page :D {136}
# I clicked on next page :D {137}
# I clicked on next page :D {138}
# I clicked on next page :D {139}
# I clicked on next page :D {140}
# I clicked on next page :D {141}
# I clicked on next page :D {142}
# I clicked on next page :D {143}
# I clicked on next page :D {144}
# I clicked on next page :D {145}
# I clicked on next page :D {146}
# I clicked on next page :D {147}
# I clicked on next page :D {148}
# I clicked on next page :D {149}
# I clicked on next page :D {150}
# I clicked on next page :D {151}
# I clicked on next page :D {152}
# I clicked on next page :D {153}
# I clicked on next page :D {154}
# I clicked on next page :D {155}
# I clicked on next page :D {156}
# I clicked on next page :D {157}
# I clicked on next page :D {158}
# I clicked on next page :D {159}
# I clicked on next page :D {160}
# I clicked on next page :D {161}
# I clicked on next page :D {162}
# I clicked on next page :D {163}
# I clicked on next page :D {164}
# I clicked on next page :D {165}
# I clicked on next page :D {166}
# I clicked on next page :D {167}
# I clicked on next page :D {168}
# I clicked on next page :D {169}
# I clicked on next page :D {170}
# I clicked on next page :D {171}
# I clicked on next page :D {172}
# I clicked on next page :D {173}
# I clicked on next page :D {174}
# I clicked on next page :D {175}
# I clicked on next page :D {176}
# I clicked on next page :D {177}
# I clicked on next page :D {178}
# I clicked on next page :D {179}
# I clicked on next page :D {180}
# I clicked on next page :D {181}
# I clicked on next page :D {182}
# I clicked on next page :D {183}
# I clicked on next page :D {184}
# I clicked on next page :D {185}
# I clicked on next page :D {186}
# I clicked on next page :D {187}
# I clicked on next page :D {188}
# I clicked on next page :D {189}
# I clicked on next page :D {190}
# I clicked on next page :D {191}
# I clicked on next page :D {192}
# I clicked on next page :D {193}
# I clicked on next page :D {194}
# I clicked on next page :D {195}
# I clicked on next page :D {196}
# I clicked on next page :D {197}
# I clicked on next page :D {198}
# I clicked on next page :D {199}
# I clicked on next page :D {200}
# I clicked on next page :D {201}
# I clicked on next page :D {202}
# I clicked on next page :D {203}
# I clicked on next page :D {204}
# I clicked on next page :D {205}
# I clicked on next page :D {206}
# I clicked on next page :D {207}
# I clicked on next page :D {208}
# I clicked on next page :D {209}
# I clicked on next page :D {210}
# I clicked on next page :D {211}
# I clicked on next page :D {212}
# I clicked on next page :D {213}
# I clicked on next page :D {214}
# I clicked on next page :D {215}
# I clicked on next page :D {216}
# I clicked on next page :D {217}
# I clicked on next page :D {218}
# I clicked on next page :D {219}
# I clicked on next page :D {220}
# I clicked on next page :D {221}
# I clicked on next page :D {222}
# I clicked on next page :D {223}
# I clicked on next page :D {224}
# I clicked on next page :D {225}
# I clicked on next page :D {226}
# I clicked on next page :D {227}
# I clicked on next page :D {228}
# I clicked on next page :D {229}
# I clicked on next page :D {230}
# I clicked on next page :D {231}
# I clicked on next page :D {232}
# I clicked on next page :D {233}
# I clicked on next page :D {234}
# I clicked on next page :D {235}
# I clicked on next page :D {236}
# I clicked on next page :D {237}
# I clicked on next page :D {238}
# I clicked on next page :D {239}
# I clicked on next page :D {240}
# I clicked on next page :D {241}
# I clicked on next page :D {242}
# I clicked on next page :D {243}
# I clicked on next page :D {244}
# I clicked on next page :D {245}
# I clicked on next page :D {246}
# [{'name': ' Kendall Jackson Chardonnay Vinters Reserve',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$18.19',
#   'sale_price': '$12.99',
#   'description': '\n“From day one we have been a family-owned and family-run business. It is a distinction that is rapidly becoming a rarity in our industry. Our family culture is built on the time-honored principles of hard work, integrity, an uncompromising desire for quality and the long-term stewardship of the land.” - JESS JACKSON, Founder\n\nAt Kendall-Jackson, sustainability is key to the longevity and quality of our vineyards - we owe this to future generations. Since 2011, all of our vineyards have been third-party certified as sustainable by CCSW (Certified California Sustainable Winegrowing) and SIP (Sustainability in Practice). Responsible stewardship measures include composting, rotating cover crops, disking, integrated pest management, raptor programs and a commitment to supporting the community.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Apothic Red',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Cabernet Sauvignon,Merlot,Syrah,Zinfandel',
#   'wine_type': 'Still wine',
#   'bottle_price': '$10.99',
#   'sale_price': '$9.97',
#   'description': '\nInspired by ”Apotheca,” a mysterious place where wine was blended and stored in 13th century Europe, the wines of Apothic are truly unique in style and taste.\nOur winemaker Boyd Morrison crafts bold, captivating Apothic blends by using only the most distinctive California grapes. From vintage to vintage, Boyd lets the character and flavor of the individual varietals guide the shape of each blend.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Robert Mondavi Woodbridge Merlot',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Merlot',
#   'wine_type': 'Still wine',
#   'bottle_price': '$18.19',
#   'sale_price': '$12.99',
#   'description': '\nOur Woodbridge Merlot displays rich aromas of cherry and dark chocolate, with enticing flavors of cocoa and lightly toasted oak. This full-bodied wine possesses well-balanced acidity and beautifully integrated tannins, creating complexity and structure.\nIts soft, versatile style complements grilled meats, especially steak, lamb, pork chops, and hamburgers. Enjoy this savory wine with hearty pasta with Bolognese sauce.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': " Colosi Nero d' Avola",
#   'country': 'Italy',
#   'region': 'Sicily',
#   'sub_region': 'Sicilia',
#   'grape_varietal': "Nero d'Avola",
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$12.99',
#   'description': '\nThe Colosi family has been making wine on the beautiful island of Salina (part of the Aeolian Islands off the northern tip of Sicily) since 1987. In fact, the winery is now celebrating its 30th anniversary. The wines from Salina offer exciting value with distinct territory-driven aromas that come with the Mediterranean sea breeze and salt. You get a lot of authenticity and personality with these wines. -Monica Larner, WA (8/17)\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Coppola Diamond Chardonnay',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$14.99',
#   'sale_price': '$11.99',
#   'description': '\n”I’ve always been influenced by the idea of Tivoli Gardens in Copenhagen, which was the inspiration for ultimately all modern amusements parks. I remember the beautiful theater pavilions with the curtains painted with peacock feathers that had little ballet performances. At Tivoli, there were rides, but more important than the rides were the cafes and the refreshments, and just the sense of being in a children’s garden, a ‘pleasure garden’ for all people to enjoy - which perhaps is the best phrase to describe what we’re creating here. This vision was replicated at places on Coney Island, like Luna Park, and George C. Tilyou’s Steeplechase Park, or Palisades Park. These were basically wonderlands, and I thought Francis Ford Coppola Winery could become such a park for the family to go and enjoy, where there are things for kids to do, so they can be close to their parents who are sampling wines and foods.\nI’ve often felt that modern life tends to separate all the ages too much. In the old days, the children lived with the parents and the grandparents, and the family unit each gave one another something very valuable. So when we began to develop the idea for this winery, we thought it should be like a resort, basically a wine wonderland, a park of pleasure where people of all ages can enjoy the best things in life - food, wine, music, dancing, games, swimming and performances of all types. A place to celebrate the love of life.”\n\n- Francis Ford Coppola\n\nFor more than thirty years, we have been committed to environmentally responsible business practices. It’s been our goal to minimize our impact on the environment by seeking out innovative ways to produce and package our goods.\nAt Francis Ford Coppola Winery, all 24 planted acres are sustainably farmed and part of the California Sustainable Winegrowing Program. We try to purchase fruit from growers who farm sustainably, and some of the vineyards we source from are certified organic as well. Another benefit of participating in the California Sustainable Winegrowing Program is that we have subsequently become a learning-teaching vineyard. Every technique we implement is thoroughly documented so that we, and neighboring Sonoma winegrowers, can pinpoint the best ways to protect our land and craft the best wines from these vineyards.\nWe are also actively involved in the Fish Friendly Farming certification program. While this may seem like a matter totally unrelated to wine, watershed quality management is intrinsically connected to farming our vineyard because our property includes two blue-line creeks. These creeks are a part of the Russian River watershed that supports steelhead trout and Coho salmon populations. In conjunction with our neighbors and local, state, and federal agencies, we work diligently to promote the overall health of the Russian River watershed so that the entire ecosystem remains in balance and is preserved for generations to come.\nOur winegrowing practices involve the Integrated Pest Management program, which discusses the best practices for maintaining soil and vine health and proactively farming to reduce and treat pest pressures. Field experts provide monthly lectures concerning pest problems and solutions which we implement in our vineyard. Through our integrated pest management program, we have complemented the biodiversity of our vineyard by promoting the presence of beneficial insects, soil fauna, and owls that combat pests of grapevines.\nFinally, we recycle our grape and water waste by fertilizing with composted grape pomace and irrigating only with reclaimed winery wastewater.  In effect, we have closed the loop on our waste system in an effort to reduce our carbon footprint on the land we so love.\nOutside of the vineyard, our Francis Coppola Diamond Collection wines are packaged in 100% recycled cardboard case boxes, and all of the corks we purchase come from sustainable cork forests. Additionally, we insist that the label  ...
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' William Hill Chardonnay North Coast',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'North Coast',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$17.99',
#   'sale_price': '$12.99',
#   'description': '\nWilliam Hill Estate Winery is a special place. In 1978, visionary vineyard developer William Hill saw the incredible potential of the Silverado Bench, where he built his namesake winery. More than three decades later, our winemaker Ralf Holdenried is making modern wines that speak to the unique terroir of this virtually unknown area of southern Napa Valley.\nA confluence of characteristics makes our 140-acre estate an ideal vineyard. Set on a benchland - off the valley floor, but below the steeper slopes of the hills - with a southwestern exposure, the vines bask in abundant sunlight. The vineyard is close to the valley floor climatically, but the volcanic soil and the size and vigor of the vines means William Hill is more like a mountaintop vineyard. These elements translate to elegant, expressive red Bordeaux wines.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Barefoot Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$16.59',
#   'sale_price': '$11.99',
#   'description': '\nAlways stomps out a good time with beef, lamb and red sauce pastas.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Noble Vines 337 Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Central Valley',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$15.99',
#   'sale_price': '$11.97',
#   'description': 'N/A',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Seaglass Pinot Grigio',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Santa Barbara County',
#   'grape_varietal': 'Pinot Gris',
#   'wine_type': 'Still wine',
#   'bottle_price': '$13.69',
#   'sale_price': '$9.99',
#   'description': '\nTo preserve and enhance the snappy, clean fruit flavors and acidity, winemakers carefully craft our Pinot Grigio in a reductive style, protecting the juice from oxygen exposure. We avoid malolactic fermentation, and instead ferment the grapes in stainless steel tanks at cold temperatures to retain the grapes’ natural flavors and delicate aromas. We bottle the wine early, when the fruit flavors and aromas are at their best, and use a Stelcap closure to ensure that every glass is always fresh and delicious.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Corbett Canyon Pinot Grigio',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Pinot Gris',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$8.99',
#   'description': 'N/A',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Robert Mondavi Woodbridge Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$18.19',
#   'sale_price': '$12.99',
#   'description': '\nAromas of juicy plums marry with notes of herb and rich cedar in our elegant Woodbridge Cabernet Sauvignon. Deep flavors of blackberry and tobacco give this wine excellent balance, with oak aging adding a toasty, caramelized quality.\nWith a smooth finish, this Cabernet Sauvignon is approachable and delicious with a variety of foods. Enjoy this wine with grilled meats, barbecue ribs, or tomato-based pasta dishes.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Corbett Canyon Cabernet Sauv',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$8.99',
#   'description': 'N/A',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Cono Sur Bicicleta Sauvignon Blanc',
#   'country': 'Chile',
#   'region': 'Valle Central',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Sauvignon Blanc',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$9.99',
#   'description': '\nThis wineis an excellent choice to serve as an aperitif or next to vegetarian combinations. It also goes well with soft and fresh cheeses. A few ideas are crunchy toasts with smoked salmon and ricotta, rice cooked with grilled red peppers, chicken breast with lemon juice, and oyster soup.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Ferrari Carano Merlot',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Sonoma County',
#   'grape_varietal': 'Merlot',
#   'wine_type': 'Still wine',
#   'bottle_price': '$22.99',
#   'sale_price': '$16.97',
#   'description': '\nThe Merlot is a velvety wine with a complex nose of blueberry pie, raspberry jam, cedar, vanilla and spice. A fleshy and generous mouthfeel is followed by notes of bittersweet chocolate, clove and toffee. This wine has full, generous tannins that coat the palate, impressive length and lasting acidity.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Sycamore Lane Pinot Grigio',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Pinot Gris',
#   'wine_type': 'Still wine',
#   'bottle_price': '$5.99',
#   'sale_price': '$4.99',
#   'description': '\nAt Trinchero Family Estates, our passion for winemaking and delivering the most inspiring flavors from around the globe began more than 60 years ago. In 1947, brothers John and Mario Trinchero traveled to St. Helena, California, near the renowned Napa Valley growing region, and purchased Sutter Home Winery. With its first Sutter Home harvest in 1948, the Trinchero Family crushed three tons of grapes, beginning a long and fruitful history as one of the world’s leading producers of fine wines.\nAs the Trinchero family expanded, so too did the company. Mario’s son Bob joined the team in 1958, eventually becoming the head winemaker after his uncle John retired. Bob focused on growing his family’s efforts, and just 10 years after coming on board, he helped Sutter Home become the first north coast winery to produce commercial wine from Sierra Foothill grapes. He even developed the revolutionary White Zinfandel varietal, which he perfected through innovation, creativity, and a bit of luck in suffering through a ”stuck” fermentation in 1975. With the help of his brother Roger, his wife Evelyn, and his sister Vera, Bob was able to capitalize on the growing demand for White Zinfandel and expand Sutter Home even further.\nIn the 1980s and 1990s, the Trinchero family continued its efforts to produce high-quality, affordably priced varietal wines by purchasing several more California vineyards in areas with choice weather and soil conditions. The family has never lost sight of Sutter Home’s original philosophy to offer ”a great product for a fair price,” even as it acquired more vineyards and additional wineries.\nToday, with Roger Trinchero leading the way, Trinchero Family Estates represents over 27 brands in the United States and Australia, including Sutter Home, Little Boomey, Menage a Trois, Napa Cellars, and Trinchero Napa Valley. Sutter Home is also the proud sponsor of the Build a Better Burger contest, which pits culinary contestants in an annual burger cookoff to win cash prizes and bragging rites. In all, the last 60 years have been a period of heavy growth and exciting innovation for the Trinchero family, and we look forward to enjoying many more successful years to come.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Josh Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$19.69',
#   'sale_price': '$14.99',
#   'description': '\nTom Larson once owned this single vineyard in the mountains of the Red Hills. This Vineyard is where for the past 10 years, all grapes have been organically grown and sustainably farmed.\nThis appellation sits at the highest section between the Vaca and Mayacamas mountain ranges. The Mayacamas are famous for great Cabernet wine, due in part to ancient pyroclastic soils that contain volcanic glass. Josh Cellars North Coast Vineyards contain obsidian gravel that allows the soils to drain well, which is extremely important for growing Cabernet grapes.\nThe high elevation sunlight combined with the rich volcanic red soils and obsidian fragments produce quality grapes that are extremely unique to the Red Hills. The vineyard itself sits on an East facing slope with varying altitude from 1200 to 2000 feet. The average daytime summer temperature is 84 degrees with an average nighttime temperature of 51 degrees.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Bota Box Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$26.99',
#   'sale_price': '$19.99',
#   'description': '\nBota Box Cabernet Sauvignon is an ideal partner for barbecued meats, hearty stews or pasta served with marinara sauce.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Cupcake Chardonnay',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Monterey County',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$12.19',
#   'sale_price': '$8.99',
#   'description': '\nA big, rich wine from California’s Central Coast, our full and elegantly textured Chardonnay has decadent levels of butter, cream, bright citrus and vanilla. These layers melt into a balance of oak and subtle spice. This wine epitomizes the Central Coast’s crisp and vibrant Chardonnay character. We use a malolactic fermentation to impart rich buttery flavor, then leave the wine sur lie to achieve a full, soft body. Aging for nine months in premium American oak barrels enhances the golden color, adds creamy texture, and injects nuances of subtle toasty oak and spice.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Carnivor Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$10.99',
#   'sale_price': '$9.97',
#   'description': 'N/A',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Matua Sauvignon Blanc Marlborough',
#   'country': 'New Zealand',
#   'region': 'Marlborough',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Sauvignon Blanc',
#   'wine_type': 'Still wine',
#   'bottle_price': '$13.69',
#   'sale_price': '$9.99',
#   'description': '\nMatua Valley was founded in a tin shed in 1974 by two brothers, Bill and Ross Spence. The brothers wanted to make wine in New Zealand that was as good as any in the world.\nAs a small, family-run winery in West Auckland, Matua Valley quickly gained a reputation for innovation and producing award-winning New Zealand wines.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Pascal Jolivet Sancerre',
#   'country': 'France',
#   'region': 'Loire',
#   'sub_region': 'Central Vineyards',
#   'grape_varietal': 'Sauvignon Blanc',
#   'wine_type': 'Still wine',
#   'bottle_price': '$29.99',
#   'sale_price': '$24.99',
#   'description': '\nPascal Jolivet Sancerre Blanc is sourced from threevineyards in the heart of the appellation. The ”Les Caillottes” vineyard and it’s chalky soils makes up 50% of the blend, followed by the hillside vineyard of ”Les Terres Blanches” at 30% and the limestone and flint riddled vineyard of ”Silex” making up the remaining 20%.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Amelia Brut Rose',
#   'country': 'France',
#   'region': 'Bordeaux',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Bordeaux Blend',
#   'wine_type': 'Sparkling',
#   'bottle_price': '$20.29',
#   'sale_price': '$18.79',
#   'description': 'N/A',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' William Hill Cabernet Sauvignon North Coast',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'North Coast',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$17.99',
#   'sale_price': '$12.99',
#   'description': '\nWilliam Hill Estate Winery is a special place. In 1978, visionary vineyard developer William Hill saw the incredible potential of the Silverado Bench, where he built his namesake winery. More than three decades later, our winemaker Ralf Holdenried is making modern wines that speak to the unique terroir of this virtually unknown area of southern Napa Valley.\nA confluence of characteristics makes our 140-acre estate an ideal vineyard. Set on a benchland - off the valley floor, but below the steeper slopes of the hills - with a southwestern exposure, the vines bask in abundant sunlight. The vineyard is close to the valley floor climatically, but the volcanic soil and the size and vigor of the vines means William Hill is more like a mountaintop vineyard. These elements translate to elegant, expressive red Bordeaux wines.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Coppola Directors Cut Chardonnay Russian River',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Sonoma County',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$21.99',
#   'sale_price': '$16.99',
#   'description': '\nA full-bodied Chardonnay bursting with ripe fruit flavor and prominent oak and spice.\nUsing only Russian River Valley fruit, we crush the grapes whole-cluster and ferment entirely in French oak barrels to produce a wine with a seductive, round texture and notes of sweet vanilla. This technique also serves to highlight the green apple, honeysuckle and citrus flavors, which are the hallmark of Russian River vineyards.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': " The Palm By Whispering Angel Rose'",
#   'country': 'France',
#   'region': 'Provence',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Red Rhone Blend',
#   'wine_type': 'Still wine',
#   'bottle_price': '$15.99',
#   'sale_price': '$13.99',
#   'description': '\nThe Palm is a blend of Grenache, Cynsault and Syrahmade from grapes which are selected from the best vineyards in the appellation Coteaux d’Aix-en-Provence.\nPale pink with green hues both of which are clear & very expressive. Great aromatic freshness on the nose followed by more subtle, fruity notes on the palate. The freshness is coupled with exceptional length and roundness. Crisp and suave finish.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Robert Mondavi Private Selection Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Central Coast',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$9.97',
#   'sale_price': '$8.97',
#   'description': '\nThere’s 20 degrees difference between our northern and southern vineyards, though it’s only 40 miles. So, whether grapes like it cool or warm, like our Central Coast Cabernet Sauvignon, they all grow up delicious.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Bolla Soave',
#   'country': 'Italy',
#   'region': 'Veneto',
#   'sub_region': 'Soave',
#   'grape_varietal': 'Garganega,Trebbiano',
#   'wine_type': 'Still wine',
#   'bottle_price': '$18.49',
#   'sale_price': '$14.99',
#   'description': '\nSoave means “soft” in Italian, and the soft floral bouquet and clean pear and lemon flavors help this wine live up to its name.  A delicate almond aftertaste makes it the perfect quaff to lighter fare like grilled seafood, chicken, fish-based pastas, and entree salads. It also makes a perfect aperitif.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Santa Margherita Pinot Grigio',
#   'country': 'Italy',
#   'region': 'Trentino-Alto Adige',
#   'sub_region': 'Alto Adige',
#   'grape_varietal': 'Pinot Gris',
#   'wine_type': 'Still wine',
#   'bottle_price': '$32.99',
#   'sale_price': '$21.99',
#   'description': '\nCrafted in the Northern Italian region of Alto Adige, this crisp, elegant wine was introduced to the United States by Anthony Terlato in 1979. Thirty-six years later, Santa Margherita remains the most requested Pinot Grigio. A true classic, Santa Margherita Pinot Grigio is perfect for entertaining and pairs beautifully with a wide variety of dishes. Santa Margherita Pinot Grigio is the benchmark by which all other Pinot Grigios are judged and continues to be requested by name.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Oyster Bay Sauvignon Blanc',
#   'country': 'New Zealand',
#   'region': 'Marlborough',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Sauvignon Blanc',
#   'wine_type': 'Still wine',
#   'bottle_price': '$16.69',
#   'sale_price': '$11.99',
#   'description': '\nThroughout harvest, fruit is selected from progressively later ripening vineyard blocks, commencing with the stonier free-draining sites. Upon receipt to the winery, the grapes are destemmed and transferred to the tank presses where the free-run juice is separated and the remaining fruit lightly pressed. The juice is then clarified to a clear state, racked into stainless steel fermentation tanks and then inoculated with a select range of yeasts for added complexity and aromaticity. A slow, temperature controlled fermentation is undertaken and after a short period of yeast lees contact, the wine is racked for final blending, then bottled young to ensure that the fresh, crisp and elegant varietal characters are retained.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Rodney Strong Cabernet Sauvignon Sonoma',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Sonoma County',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$22.19',
#   'sale_price': '$17.99',
#   'description': '\nOur story begins more than 50 years ago, when a celebrated American dancer named Rod Strong settled in Sonoma County to pursue a second lifelong creative passion: winemaking. Rodney Strong Vineyards was the 13th winery bonded in the newly discovered Sonoma County wine industry. A trio of winemaking paths crossed when Rick Sayre joined the team as Winemaker in 1979, and again when the Klein Family, 4th generation California farmers, purchased the winery in 1989 and initiated a renewed commitment of modern artisan winemaking. Through the years, Rodney Strong Vineyards has earned the reputation for critically acclaimed Single Vineyard and Reserve wines, stand out Estate releases and best-in-class Sonoma County varietal wines.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Barefoot Pinot Grigio',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Pinot Gris',
#   'wine_type': 'Still wine',
#   'bottle_price': '$16.59',
#   'sale_price': '$11.99',
#   'description': '\nGreat with the three P’s: poultry, (spicy) pasta and pizza!\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' La Crema Russian River Valley Pinot Noir',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Sonoma County',
#   'grape_varietal': 'Pinot Noir',
#   'wine_type': 'Still wine',
#   'bottle_price': '$38.99',
#   'sale_price': '$29.99',
#   'description': '\nthe series: appellation series\nAt La Crema, we arerather passionate about terroir. Especially when it comes to Pinot Noir. The In general, terroir conveys the unique characteristics of a site – everything from soil, wind and temperature to the neighboring eucalyptus trees or distance from the sea. For Pinot Noir in particular, it means the subtle expressiveness and texture of one site literally cannot be duplicated elsewhere. Produced in limited quantities, our Appellation Pinot Noirs are rooted in this concept: four exceptional cool-climate growing areas offering clearly\ndifferent expressions of this alluring varietal.\nthe place: russian river valley\nPinot Noir’s temperamental and fragile nature makes it a challenge from vine to bottle. Russian River Valley offers the ideal climate for Pinot to reveal its brilliance. Cool coastal fog rolls over the vineyards each evening and the fruit ripens at a leisurely pace in the moderate climate. Concentrated, small berries literally burst with flavor, wrapped up in heady spice and plush, round texture. For this release, our winemaker focuses on creating a complex, layered blend that marries the particular flavors, aromas, and structural characteristics of different vineyard sites within the appellation.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Peter Vella Bg/Bx Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$25.69',
#   'sale_price': '$17.99',
#   'description': '\nPeter Vella combines award-winning flavor and an innovative box design to craft quality wines that maintain a lasting freshness. Winemaker Peter Vella pours 40 years of winemaking expertise into his smooth, easy to enjoy wines at a surprisingly affordable price. These wines stand apart, thanks to richly flavored grapes grown in the warm days and cool nights of California’s celebrated vineyards. Peter Vella recently added a range of delectable beverage wines to its portfolio in three light-bodied, fruit-filled flavors: Delicious White, Delicious Red and Delicious Blush. Hints of ripe berries and red jam combine with the natural fruit flavors to create a light-bodied, refreshing taste that offers consumers a way to explore options beyond the ordinary.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Chateau Bernadotte Haut Medoc 2016',
#   'country': 'France',
#   'region': 'Bordeaux',
#   'sub_region': 'Haut Medoc',
#   'grape_varietal': 'Bordeaux Blend',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$19.99',
#   'description': 'N/A',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Freixenet Brut Cordon Negro',
#   'country': 'Spain',
#   'region': 'Catalunya',
#   'sub_region': 'Cava',
#   'grape_varietal': 'Macabeo,Parellada,Xarel.Lo',
#   'wine_type': 'Sparkling',
#   'bottle_price': '$15.19',
#   'sale_price': '$10.99',
#   'description': '\nHarvested by hand, the selection of ripening grapes in Freixenet’s vineyards reaches across the span of several months. From the end of August for the harvest of the warm weather Macabeu grapes, through the beginning of October for the higher elevation Parellada variety, our winemaker awaits the perfect time to gather each bunch, letting the vines tell him when they are ready. The first fermentation is nurtured in stainless steel tanks at controlled temperatures between 57°- 60°F. Exclusively initiated from our own Freixenet cultures, the first fermentation is introduced into the tanks. After 10 to 12 days, the wine is racked and clarified as the blend is readied for bottling. The secondary fermentation finds the bottles of Cordon Negro cradled in the perfectly chilled caves for up to 18 months\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Barefoot Chardonnay',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$16.59',
#   'sale_price': '$11.99',
#   'description': '\nBarefoot Chardonnay combines a big, bold flavor with a medium body and smooth finish. Tempting notes of crisp green apples, sweet peaches, and hints of vanilla.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Kikusakari Taru Sake',
#   'country': 'Japan',
#   'region': 'Ibaraki',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Rice',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$25.99',
#   'description': '\nRice polishing rate: 65%\nRice: Japanese Sake Rice\n\nYeast: original\nShubo (yeast starter): Sokujo\nAlcohol volume: 15%\nSake meter value (nihonshudo): +3\nAcidity: 1.6\nAmino acidity: 1.0\nReccomended way to drink: room temperature\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' 14 Hands Hot To Trot White',
#   'country': 'United States',
#   'region': 'Washington',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Non-Varietal White Blend',
#   'wine_type': 'Still wine',
#   'bottle_price': '$13.69',
#   'sale_price': '$9.98',
#   'description': '\nThe inspiration for 14 Hands wines recalls a time when wild mustangs once freely roamed the hills of eastern Washington State. These small horses, measuring a scant 14 hands high - a “hand” being equivalent to a man’s palm width and how horses were measured then - would travel down from the hills every day to drink from the mighty Columbia River and graze upon the luscious waist high grasses along the riverbank, and then retreat back up into the hills to cool off at night. Strong and tenacious, these little horses became known for their endurance and were revered around the world.\nThis unique and beautiful landscape that gave these unbridled horses their spirit and tenacity now feeds our vines. With loamy-sand and gravel soils, these hills require a strong and determined grapevine, and our 14 Hands vines revel in this unique and world class terroir. With the fruit from these tenacious vines, 14 Hands wines are handcrafted into big, bold, juicy fruit forward reds and crisp, fruit forward white wines that are laced with the unbridled spirit and legend of the region.\n14 Hands celebrates the spirit of these wild horses, and the rich and unique history of Washington wines not only in our wines, but also in the vibrant colors and images on our popular varietal labels and our new Hot to Trot red and white blend wines. Whether you enjoy 14 Hands by the glass in your favorite restaurant, or share a bottle with family or friends, our wines are the quintessential Washington wine experience – fruit-forward, easily enjoyable with any meal or on any occasion, and delivering a superb value for the price. Bringing this bottle of wine to the party is more than bringing just a wine – it’s a delicious wine with a unique story that’s sure to spark up a memorable conversation.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Rombauer Chardonnay',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Carneros',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$52.69',
#   'sale_price': '$36.03',
#   'description': '\nRombauer Vineyards began producing Chardonnay in 1982. In 1990, the family made their first Chardonnay from the Carneros region, where San Pablo Bay meets the southern end of Napa and Sonoma valleys. There, the cool climate and clay soils offer ideal conditions for growing superior Chardonnay with the Rombauer hallmarks - intense fruit flavors balanced by fresh acidity.\nVINEYARDS\nThe fruit for this wine comes from vineyards in the Carneros region owned by the Rombauer family and select growers including the Sangiacomo family, long-term grower partners who have farmed this land for three generations.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Bota Box Chardonnay',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$26.99',
#   'sale_price': '$19.99',
#   'description': '\nEnjoy Bota Box Chardonnay as an aperitif or as a complement to angel hair pasta with scallops, fish and chips or grilled chicken Caesar Salad. Serve chilled.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Beringer White Zinfandel',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Zinfandel',
#   'wine_type': 'Still wine',
#   'bottle_price': '$13.49',
#   'sale_price': '$10.99',
#   'description': '\nAt Beringer we know that part of making great wines is caring for the land, animals, and people that make those wines possible. We have had sustainable practices in place since long before sustainable farming become fashionable. All of our owned and leased vineyards are certified sustainable by third parties, and we provide our external growers with the resources they need to achieve sustainable farming practices.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Dark Horse Merlot',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Merlot',
#   'wine_type': 'Still wine',
#   'bottle_price': '$10.69',
#   'sale_price': '$7.98',
#   'description': '\nAt Darkhorse wines, we challenge the belief that premium tasting wines must be premium priced.\nWe search throughout the world’s best growing areas for vineyards that help us achieve the unexpected: To create great wines for the price of good.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Kendall Jackson Chardonnay Grand Reserve',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Chardonnay',
#   'wine_type': 'Still wine',
#   'bottle_price': '$19.99',
#   'sale_price': '$14.99',
#   'description': '\nGrand Reserve is a winemaker’s blend of our mountain, ridge, hillside and benchland grapes grown along California’s cool coastal appellations. We select grapes from our best estate vineyards and then monitor, taste and guide each individual lot throughout the winemaking process. Each lot is kept separate, barrel-aged and crafted-boutique winery style. Our winemakers have an\nunmatched palette of flavors, toast levels and terroir nuances from which they masterfully blend these exemplary rich, deep and complex wines.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' La Crema Pinot Noir Sonoma',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Sonoma County',
#   'grape_varietal': 'Pinot Noir',
#   'wine_type': 'Still wine',
#   'bottle_price': '$26.99',
#   'sale_price': '$19.99',
# ...
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Buena Vista Chateau Buena Vista Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Napa County',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$44.99',
#   'sale_price': '$34.99',
#   'description': '\nIn the 1860’s Buena Vista covered more than 6,000 acres that ran up into the foothills and into Napa County. In 1861, our founder, Count Haraszthy, journeyed to Europe to procure the finest grapevines. While in Bordeaux, he declared “Cabernet Sauvignon is its unsurpassed grape; the wine made of it possesses splendid color and an exquisite bouquet.’ Bringing choice cuttings back to California, he propagated them at Buena Vista and bringing Cabernet Sauvignon to the Napa Valley. We celebrate Buena Vista’s historic contribution to Napa wine by offering this rich, dense and opulent Napa Valley Cabernet Sauvignon.\nThe inaugural release of the Chateau Buena Vista Cabernet Sauvignon celebrates and honors Buena Vista’s indelible presence and significant contributions to the California wine world. Buena Vista has returned to Napa Valley, where Cabernet is the King, if not the Count. Sourced from vineyards from Yountville to St. Helena, the wine was aged for 28 months before being racked and aged an additional four months in French oak barrels, 40% new, for final aging. It was then bottled unfiltered.\nThe wine hails from vineyards throughout the Napa Valley, and is a rich and opulent Napa red wine with intensity, structure and power. It opens with rich aromas of black cherry and cardamom with a touch of black licorice. Spreading across the palate are flavors of red plum, black currant and cherry. The fine-grained tannins are silky and soft with a full-bodied mouthfeel and a long, lingering finish.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Robert Mondavi Private Selection Pinot Noir',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Central Coast',
#   'grape_varietal': 'Pinot Noir',
#   'wine_type': 'Still wine',
#   'bottle_price': '$12.49',
#   'sale_price': '$8.99',
#   'description': '\nUnlike other reds, Pinot Noir grapes prefer the cool northern Central Coast over the warm southern region. Fussy grape, unfussy wine.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Lindemans Pinot Noir Bin 99',
#   'country': 'Australia',
#   'region': 'South Eastern Australia',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Pinot Noir',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$5.99',
#   'description': '\nLindeman’s wines contain the spirit and passion of its founder, Dr. Henry J. Lindeman, whose philosophy was to craft wines for everyday enjoyment.\nIn 1843, Dr. Lindeman planted his first vineyard on his 330-acre property ‘Cawarra’ in the Hunter Valley of New South Wales. One hundred years later, the Lindeman’s Wine Company became a public listed company.\nBy cellaring wines and not releasing them for sale until they had properly matured, Dr. Lindeman earned a reputation for producing wine of the highest quality. In 1973, the Lindeman’s Winery at Karadoc was built to cater for the increasing consumer demand for Lindeman’s wines around the world.\nLindeman’s Bin 65 Chardonnay was first crafted for the Canadian market and launched in 1985 in response to the popularity of the Lindeman’s style of wines in the northern hemisphere. Following its success in Canada and the United States, Lindeman’s Bin 65 was ‘brought home’ to Australia in 1991.\nThe winemaking team of nine is spread across Victoria and South Australia. Wayne Falkenberg and his team at the Lindeman’s Karadoc Winery produce wines for the Cawarra, Bin Series and Premier Selection labels, whilst the team based in the Coonawarra produce the Reserve and Coonawarra Trio wines.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' 14 Hands Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'Washington',
#   'sub_region': 'Columbia Valley',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$15.19',
#   'sale_price': '$10.99',
#   'description': '\nThe inspiration for 14 Hands wines recalls a time when wild mustangs once freely roamed the hills of eastern Washington State. These small horses, measuring a scant 14 hands high - a “hand” being equivalent to a man’s palm width and how horses were measured then - would travel down from the hills every day to drink from the mighty Columbia River and graze upon the luscious waist high grasses along the riverbank, and then retreat back up into the hills to cool off at night. Strong and tenacious, these little horses became known for their endurance and were revered around the world.\nThis unique and beautiful landscape that gave these unbridled horses their spirit and tenacity now feeds our vines. With loamy-sand and gravel soils, these hills require a strong and determined grapevine, and our 14 Hands vines revel in this unique and world class terroir. With the fruit from these tenacious vines, 14 Hands wines are handcrafted into big, bold, juicy fruit forward reds and crisp, fruit forward white wines that are laced with the unbridled spirit and legend of the region.\n14 Hands celebrates the spirit of these wild horses, and the rich and unique history of Washington wines not only in our wines, but also in the vibrant colors and images on our popular varietal labels and our new Hot to Trot red and white blend wines. Whether you enjoy 14 Hands by the glass in your favorite restaurant, or share a bottle with family or friends, our wines are the quintessential Washington wine experience – fruit-forward, easily enjoyable with any meal or on any occasion, and delivering a superb value for the price. Bringing this bottle of wine to the party is more than bringing just a wine – it’s a delicious wine with a unique story that’s sure to spark up a memorable conversation.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Ecco Domani Pinot Grigio',
#   'country': 'Italy',
#   'region': 'Veneto',
#   'sub_region': 'delle Venezie',
#   'grape_varietal': 'Pinot Gris',
#   'wine_type': 'Still wine',
#   'bottle_price': '$9.99',
#   'sale_price': '$9.99',
#   'description': '\nWhile much of Italy celebrates its past, northern Italy and Milan look to the future. This is where the style-setters create their art, whether it is high fashion, industrial and commercial design, cutting-edge furniture or a lighter, fresher, innovative style of cuisine. Ecco Domani, which means ”here’s tomorrow,” is part of this movement.\nDistinctly Italian varietals, Ecco Domani wines are contemporary in style and taste. They are easy-to-drink, well-balanced wines concentrating on the best qualities of the fruit and the regions in which they are grown, rather than on excessive winemaker influence or oak aging.\nYoung Italian winemaker Fabrizio Gatto and his colleagues scour Italy’s premier growing regions for wines that express the best characteristics of the areas, creating wines that exhibit the best that Italy has to offer. The wines are fashioned into final blends and bottled in a stunning state-of-the-art facility in Trento, Italy. ”By choosing the very best grapes from the finest regions of Italy, it is possible for us to craft exquisite wines with marvelous complexity. The intricate fruit flavors which result in the finished wines are unsurpassed, and marry well with a variety of superb cuisines,” says Fabrizio Gatto.\nSince Ecco Domani’s debut in 1996, it has become the leading premium Imported brand in the United States. Impact Magazine named Ecco Domani as a ”Hot Brand” for six consecutive years. The wines are currently sold in the United States, Canada and Northern Europe.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': None,
#   'country': None,
#   'region': None,
#   'sub_region': None,
#   'grape_varietal': None,
#   'wine_type': None,
#   'bottle_price': None,
#   'sale_price': None,
#   'description': None,
#   'merchant': None,
#   'address': None},
#  {'name': ' Catena Malbec',
#   'country': 'Argentina',
#   'region': 'Cuyo',
#   'sub_region': 'Mendoza',
#   'grape_varietal': 'Malbec',
#   'wine_type': 'Still wine',
#   'bottle_price': '$21.99',
#   'sale_price': '$16.99',
#   'description': '\nI devoted nearly a full day to tasting at the Catena Zapata winery in Agrelo as Argentina’s #1 producer offers excellent to otherworldly wines at a range of price points-and that’s not even including the superb wines made by Nicolas Catena’s daughter Laura and son Ernesto, and the Bodega Aleanna label of his own multi-talented winemaker Alejandro Vigil. - From Argentina’s Wines Enter the World Stage (Jul 2018) by Stephen Tanzer\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Ruffino Chianti Superiore',
#   'country': 'Italy',
#   'region': 'Tuscany',
#   'sub_region': 'Chianti',
#   'grape_varietal': 'Sangiovese',
#   'wine_type': 'Still wine',
#   'bottle_price': '$13.99',
#   'sale_price': '$9.97',
#   'description': '\nWith its long history , Ruffino is a living symbol of the quality progress which the entire Italian wine sector has undertaken through the twentieth century.\nRuffino’s production philosophy is based on two leading concepts: The quality of its wines and the expression of the territories where these wines are produced - a winemaking art which Ruffino has refined throughout the decades.\nWith the desire to bring the best quality the Tuscan territory has to offer to wine lovers all over the world, Ruffino has contributed significantly to the creation of the fine image which Italian winemaking holds on the international wine scene today.\nChianti Ruffino, followed by Riserva Ducale, was one of the very first wines to cross the Italian border and introduce Italian wine to the world.\nPresent in over 85 countries covering 5 continents, Ruffino is an international leader of great wines ”Made in Italy!\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Cook S        Brut',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Champagne Blend',
#   'wine_type': 'Sparkling',
#   'bottle_price': '$12.19',
#   'sale_price': '$8.99',
#   'description': 'N/A',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Dry Sack Sherry',
#   'country': 'Spain',
#   'region': 'Jerez - Xeres - Sherry',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Palomino,Pedro Ximenez',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$18.99',
#   'description': '\nA distinctive blend of Palomino and Pedro Ximenez grapes. Aged in oak casks for 6 years in the traditional Solera method.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Castellare Chianti Classico DOCG',
#   'country': 'Italy',
#   'region': 'Tuscany',
#   'sub_region': 'Chianti',
#   'grape_varietal': 'Sangiovese',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$23.99',
#   'description': '\nCastellare is one of the many Chianti Classico estates that flies under the radar. Readers will find much to admire in these classically inspired wines, including a terrific edition of the flagship I Sodi di San Niccolo, which remains one of the most iconic pure Sangioveses in Tuscany. This is a strong lineup from proprietor Paolo Panerai and winemaker Alessandro Cellai.\n\n- From Chianti Classico 2015 & 2016: Right Place, Right Time (Feb 2019) by Antonio Galloni\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Cloudline Pinot Noir',
#   'country': 'United States',
#   'region': 'Oregon',
#   'sub_region': 'Willamette Valley',
#   'grape_varietal': 'Pinot Noir',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$19.99',
#   'description': '\nPinot Noir is well-suited to pair with poultry, beef, fish, ham, lamb and pork. It will play well with creamy sauces, spicy seasonings and may just be one of the world’s most versatile food wines.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Decoy Cabernet Sauvignon',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'Sonoma County',
#   'grape_varietal': 'Cabernet Sauvignon',
#   'wine_type': 'Still wine',
#   'bottle_price': '$19.99',
#   'sale_price': '$16.97',
#   'description': '\nCo-founded by Dan and Margaret Duckhorn in 1976, Duckhorn Vineyards has spent more than 30 years establishing itself as one of North America’s premier producers of Bordeaux varietal wines. From its modest inaugural vintage of 800 cases of Cabernet Sauvignon and 800 cases of Merlot in 1978, to its addition of Sauvignon Blanc in 1982, Duckhorn Vineyards has crafted a tradition of quality and excellence that continues today.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Chateau Lamartine Cahors Prestige du Malbec',
#   'country': 'France',
#   'region': 'South West France',
#   'sub_region': 'Cahors',
#   'grape_varietal': 'Malbec',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$15.99',
#   'description': '\nBorn in the Chateau itself, the current winemaker/owner, Alain Gayraud, took over from his grandparents in 1975. Encompassing 28 hectares of vines that range in age from 20 to 120 years old, the Domaine is in the westernmost reaches of the Cahor appellation, making Chateau Lamartine the only Cahors domaine that benefits from the influence of the Atlantic. Here, the vineyards occupy the best micro-climate along the Lot River, all with southern exposure on the oldest terraces in the appellation, where the soil consists of a limestone base with a plethora of stones.\nAt Chateau Lamartine, Gayraud farms lutte raisonnee and spends 2,000 hours per vintage green harvesting, to attain the naturally low yields he seeks. The roots express great depth, so the vines are rarely over stressed, yielding balanced wines, even in the hottest of years.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': " Illuminati Cerssuolo d'Abruzzo Campirosa",
#   'country': 'Italy',
#   'region': 'Abruzzo',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Montepulciano',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$9.99',
#   'description': '\nAlcohol 12.80 % vol.\nTotal Acidity 6.00 g/l\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Walter Hansel Estate Chardonnay Russian River Sonoma',
#   'country': 'United States',
#   'region': 'N/A',
#   'sub_region': 'N/A',
#   'grape_varietal': 'N/A',
#   'wine_type': 'Still wine',
#   'bottle_price': '',
#   'sale_price': '$29.99',
#   'description': 'N/A',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  {'name': ' Dark Horse Pinot Noir',
#   'country': 'United States',
#   'region': 'California',
#   'sub_region': 'N/A',
#   'grape_varietal': 'Pinot Noir',
#   'wine_type': 'Still wine',
#   'bottle_price': '$10.69',
#   'sale_price': '$7.99',
#   'description': '\nAt Darkhorse wines, we challenge the belief that premium tasting wines must be premium priced.\nWe search throughout the world’s best growing areas for vineyards that help us achieve the unexpected: To create great wines for the price of good.\n',
#   'merchant': 'Petrocks Liquors',
#   'address': '419 Amwell Road Hillsborough, NJ 08844'},
#  ...]

# %%
wine_list_df = pd.DataFrame(wine_list)
wine_list_df
# Out:
#                                                    name        country  \
# 0            Kendall Jackson Chardonnay Vinters Reserve  United States
# 1                                           Apothic Red  United States
# 2                      Robert Mondavi Woodbridge Merlot  United States
# 3                                  Colosi Nero d' Avola          Italy
# 4                            Coppola Diamond Chardonnay  United States
# ...                                                 ...            ...
# 4688   Buena Vista Chateau Buena Vista Cabernet Sauv...  United States
# 4689        Robert Mondavi Private Selection Pinot Noir  United States
# 4690                        Lindemans Pinot Noir Bin 99      Australia
# 4691                        14 Hands Cabernet Sauvignon  United States
# 4692                           Ecco Domani Pinot Grigio          Italy
#
#                        region       sub_region  \
# 0                  California              N/A
# 1                  California              N/A
# 2                  California              N/A
# 3                      Sicily          Sicilia
# 4                  California              N/A
# ...                       ...              ...
# 4688               California      Napa County
# 4689               California    Central Coast
# 4690  South Eastern Australia              N/A
# 4691               Washington  Columbia Valley
# 4692                   Veneto    delle Venezie
#
#                                  grape_varietal   wine_type bottle_price  \
# 0                                    Chardonnay  Still wine       $18.19
# 1     Cabernet Sauvignon,Merlot,Syrah,Zinfandel  Still wine       $10.99
# 2                                        Merlot  Still wine       $18.19
# 3                                  Nero d'Avola  Still wine
# 4                                    Chardonnay  Still wine       $14.99
# ...                                         ...         ...          ...
# 4688                         Cabernet Sauvignon  Still wine       $44.99
# 4689                                 Pinot Noir  Still wine       $12.49
# 4690                                 Pinot Noir  Still wine
# 4691                         Cabernet Sauvignon  Still wine       $15.19
# 4692                                 Pinot Gris  Still wine        $9.99
#
#      sale_price                                        description  \
# 0        $12.99  \n“From day one we have been a family-owned an...
# 1         $9.97  \nInspired by ”Apotheca,” a mysterious place w...
# 2        $12.99  \nOur Woodbridge Merlot displays rich aromas o...
# 3        $12.99  \nThe Colosi family has been making wine on th...
# 4        $11.99  \n”I’ve always been influenced by the idea of ...
# ...         ...                                                ...
# 4688     $34.99  \nIn the 1860’s Buena Vista covered more than ...
# 4689      $8.99  \nUnlike other reds, Pinot Noir grapes prefer ...
# 4690      $5.99  \nLindeman’s wines contain the spirit and pass...
# 4691     $10.99  \nThe inspiration for 14 Hands wines recalls a...
# 4692      $9.99  \nWhile much of Italy celebrates its past, nor...
#
#               merchant                                 address
# 0     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 1     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 2     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 3     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# ...                ...                                     ...
# 4688  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4689  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4690  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4691  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4692  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
#
# [4693 rows x 11 columns]

# %%
wine_list_df["description"].replace("\n", "", regex=True, inplace=True)

# %%
wine_list_df
# Out:
#                                                    name        country  \
# 0            Kendall Jackson Chardonnay Vinters Reserve  United States
# 1                                           Apothic Red  United States
# 2                      Robert Mondavi Woodbridge Merlot  United States
# 3                                  Colosi Nero d' Avola          Italy
# 4                            Coppola Diamond Chardonnay  United States
# ...                                                 ...            ...
# 4688   Buena Vista Chateau Buena Vista Cabernet Sauv...  United States
# 4689        Robert Mondavi Private Selection Pinot Noir  United States
# 4690                        Lindemans Pinot Noir Bin 99      Australia
# 4691                        14 Hands Cabernet Sauvignon  United States
# 4692                           Ecco Domani Pinot Grigio          Italy
#
#                        region       sub_region  \
# 0                  California              N/A
# 1                  California              N/A
# 2                  California              N/A
# 3                      Sicily          Sicilia
# 4                  California              N/A
# ...                       ...              ...
# 4688               California      Napa County
# 4689               California    Central Coast
# 4690  South Eastern Australia              N/A
# 4691               Washington  Columbia Valley
# 4692                   Veneto    delle Venezie
#
#                                  grape_varietal   wine_type bottle_price  \
# 0                                    Chardonnay  Still wine       $18.19
# 1     Cabernet Sauvignon,Merlot,Syrah,Zinfandel  Still wine       $10.99
# 2                                        Merlot  Still wine       $18.19
# 3                                  Nero d'Avola  Still wine
# 4                                    Chardonnay  Still wine       $14.99
# ...                                         ...         ...          ...
# 4688                         Cabernet Sauvignon  Still wine       $44.99
# 4689                                 Pinot Noir  Still wine       $12.49
# 4690                                 Pinot Noir  Still wine
# 4691                         Cabernet Sauvignon  Still wine       $15.19
# 4692                                 Pinot Gris  Still wine        $9.99
#
#      sale_price                                        description  \
# 0        $12.99  “From day one we have been a family-owned and ...
# 1         $9.97  Inspired by ”Apotheca,” a mysterious place whe...
# 2        $12.99  Our Woodbridge Merlot displays rich aromas of ...
# 3        $12.99  The Colosi family has been making wine on the ...
# 4        $11.99  ”I’ve always been influenced by the idea of Ti...
# ...         ...                                                ...
# 4688     $34.99  In the 1860’s Buena Vista covered more than 6,...
# 4689      $8.99  Unlike other reds, Pinot Noir grapes prefer th...
# 4690      $5.99  Lindeman’s wines contain the spirit and passio...
# 4691     $10.99  The inspiration for 14 Hands wines recalls a t...
# 4692      $9.99  While much of Italy celebrates its past, north...
#
#               merchant                                 address
# 0     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 1     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 2     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 3     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4     Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# ...                ...                                     ...
# 4688  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4689  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4690  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4691  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4692  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
#
# [4693 rows x 11 columns]

# %%
wine_list_df.to_csv("petrocks_finalllll4k.csv", index= False)

# %%
#Dependencies
import pandas as pd
import requests
import json
import datetime
import numpy as np

# %%
file_path = "petrocks_finalllll4k.csv"
wine_df = pd.read_csv(file_path, encoding='ISO-8859-1')
wine_df.head(25)
# Out:
#                                                name        country  \
# 0        Kendall Jackson Chardonnay Vinters Reserve  United States
# 1                                       Apothic Red  United States
# 2                  Robert Mondavi Woodbridge Merlot  United States
# 3                              Colosi Nero d' Avola          Italy
# 4                        Coppola Diamond Chardonnay  United States
# 5               William Hill Chardonnay North Coast  United States
# 6                       Barefoot Cabernet Sauvignon  United States
# 7                Noble Vines 337 Cabernet Sauvignon  United States
# 8                             Seaglass Pinot Grigio  United States
# 9                       Corbett Canyon Pinot Grigio  United States
# 10     Robert Mondavi Woodbridge Cabernet Sauvignon  United States
# 11                     Corbett Canyon Cabernet Sauv  United States
# 12               Cono Sur Bicicleta Sauvignon Blanc          Chile
# 13                            Ferrari Carano Merlot  United States
# 14                       Sycamore Lane Pinot Grigio  United States
# 15                          Josh Cabernet Sauvignon  United States
# 16                      Bota Box Cabernet Sauvignon  United States
# 17                               Cupcake Chardonnay  United States
# 18                      Carnivor Cabernet Sauvignon  United States
# 19                Matua Sauvignon Blanc Marlborough    New Zealand
# 20                          Pascal Jolivet Sancerre         France
# 21                                 Amelia Brut Rose         France
# 22      William Hill Cabernet Sauvignon North Coast  United States
# 23   Coppola Directors Cut Chardonnay Russian River  United States
# 24               The Palm By Whispering Angel Rose'         France
#
#            region            sub_region  \
# 0      California                   NaN
# 1      California                   NaN
# 2      California                   NaN
# 3          Sicily               Sicilia
# 4      California                   NaN
# 5      California           North Coast
# 6      California                   NaN
# 7      California        Central Valley
# 8      California  Santa Barbara County
# 9      California                   NaN
# 10     California                   NaN
# 11     California                   NaN
# 12  Valle Central                   NaN
# 13     California         Sonoma County
# 14     California                   NaN
# 15     California                   NaN
# 16     California                   NaN
# 17     California       Monterey County
# 18     California                   NaN
# 19    Marlborough                   NaN
# 20          Loire     Central Vineyards
# 21       Bordeaux                   NaN
# 22     California           North Coast
# 23     California         Sonoma County
# 24       Provence                   NaN
#
#                                grape_varietal   wine_type bottle_price  \
# 0                                  Chardonnay  Still wine       $18.19
# 1   Cabernet Sauvignon,Merlot,Syrah,Zinfandel  Still wine       $10.99
# 2                                      Merlot  Still wine       $18.19
# 3                                Nero d'Avola  Still wine          NaN
# 4                                  Chardonnay  Still wine       $14.99
# 5                                  Chardonnay  Still wine       $17.99
# 6                          Cabernet Sauvignon  Still wine       $16.59
# 7                          Cabernet Sauvignon  Still wine       $15.99
# 8                                  Pinot Gris  Still wine       $13.69
# 9                                  Pinot Gris  Still wine          NaN
# 10                         Cabernet Sauvignon  Still wine       $18.19
# 11                         Cabernet Sauvignon  Still wine          NaN
# 12                            Sauvignon Blanc  Still wine          NaN
# 13                                     Merlot  Still wine       $22.99
# 14                                 Pinot Gris  Still wine        $5.99
# 15                         Cabernet Sauvignon  Still wine       $19.69
# 16                         Cabernet Sauvignon  Still wine       $26.99
# 17                                 Chardonnay  Still wine       $12.19
# 18                         Cabernet Sauvignon  Still wine       $10.99
# 19                            Sauvignon Blanc  Still wine       $13.69
# 20                            Sauvignon Blanc  Still wine       $29.99
# 21                             Bordeaux Blend   Sparkling       $20.29
# 22                         Cabernet Sauvignon  Still wine       $17.99
# 23                                 Chardonnay  Still wine       $21.99
# 24                            Red Rhone Blend  Still wine       $15.99
#
#    sale_price                                        description  \
# 0      $12.99  âFrom day one we have been a family-owned an...
# 1       $9.97  Inspired by âApotheca,â a mysterious place...
# 2      $12.99  Our Woodbridge Merlot displays rich aromas of ...
# 3      $12.99  The Colosi family has been making wine on the ...
# 4      $11.99  âIâve always been influenced by the idea o...
# 5      $12.99  William Hill Estate Winery is a special place....
# 6      $11.99  Always stomps out a good time with beef, lamb ...
# 7      $11.97                                                NaN
# 8       $9.99  To preserve and enhance the snappy, clean frui...
# 9       $8.99                                                NaN
# 10     $12.99  Aromas of juicy plums marry with notes of herb...
# 11      $8.99                                                NaN
# 12      $9.99  This wineis an excellent choice to serve as an...
# 13     $16.97  The Merlot is a velvety wine with a complex no...
# 14      $4.99  At Trinchero Family Estates, our passion for w...
# 15     $14.99  Tom Larson once owned this single vineyard in ...
# 16     $19.99  Bota Box Cabernet Sauvignon is an ideal partne...
# 17      $8.99  A big, rich wine from Californiaâs Central C...
# 18      $9.97                                                NaN
# 19      $9.99  Matua Valley was founded in a tin shed in 1974...
# 20     $24.99  Pascal Jolivet Sancerre Blanc is sourced from ...
# 21     $18.79                                                NaN
# 22     $12.99  William Hill Estate Winery is a special place....
# 23     $16.99  A full-bodied Chardonnay bursting with ripe fr...
# 24     $13.99  The Palm is a blend of Grenache, Cynsault and ...
#
#             merchant                                 address
# 0   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 1   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 2   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 3   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 4   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 5   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 6   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 7   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 8   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 9   Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 10  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 11  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 12  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 13  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 14  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 15  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 16  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 17  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 18  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 19  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 20  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 21  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 22  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 23  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844
# 24  Petrocks Liquors  419 Amwell Road Hillsborough, NJ 08844

# %%
#renaming the columns to matc with everyone
wine_df.rename(columns = {'region':'state'}, inplace = True) 
wine_df.rename(columns = {'sub_region':'region'}, inplace = True)
wine_df.rename(columns = {'grape_varietal':'varietal'}, inplace = True) 
wine_df.rename(columns = {'sale_price':'price'}, inplace = True)

# %%
#dropping unwanted columns
#wine_df.drop(columns = {'region':'state'}, inplace = True) 
wine_df = wine_df.drop(['wine_type','bottle_price',], axis='columns')

# %%
#droppinig the empty rows
wine_df = wine_df.dropna(how = "all")
wine_df
# Out:
#                                                    name        country  \
# 0            Kendall Jackson Chardonnay Vinters Reserve  United States
# 1                                           Apothic Red  United States
# 2                      Robert Mondavi Woodbridge Merlot  United States
# 3                                  Colosi Nero d' Avola          Italy
# 4                            Coppola Diamond Chardonnay  United States
# ...                                                 ...            ...
# 4688   Buena Vista Chateau Buena Vista Cabernet Sauv...  United States
# 4689        Robert Mondavi Private Selection Pinot Noir  United States
# 4690                        Lindemans Pinot Noir Bin 99      Australia
# 4691                        14 Hands Cabernet Sauvignon  United States
# 4692                           Ecco Domani Pinot Grigio          Italy
#
#                         state           region  \
# 0                  California              NaN
# 1                  California              NaN
# 2                  California              NaN
# 3                      Sicily          Sicilia
# 4                  California              NaN
# ...                       ...              ...
# 4688               California      Napa County
# 4689               California    Central Coast
# 4690  South Eastern Australia              NaN
# 4691               Washington  Columbia Valley
# 4692                   Veneto    delle Venezie
#
#                                        varietal   price  \
# 0                                    Chardonnay  $12.99
# 1     Cabernet Sauvignon,Merlot,Syrah,Zinfandel   $9.97
# 2                                        Merlot  $12.99
# 3                                  Nero d'Avola  $12.99
# 4                                    Chardonnay  $11.99
# ...                                         ...     ...
# 4688                         Cabernet Sauvignon  $34.99
# 4689                                 Pinot Noir   $8.99
# 4690                                 Pinot Noir   $5.99
# 4691                         Cabernet Sauvignon  $10.99
# 4692                                 Pinot Gris   $9.99
#
#                                             description          merchant  \
# 0     âFrom day one we have been a family-owned an...  Petrocks Liquors
# 1     Inspired by âApotheca,â a mysterious place...  Petrocks Liquors
# 2     Our Woodbridge Merlot displays rich aromas of ...  Petrocks Liquors
# 3     The Colosi family has been making wine on the ...  Petrocks Liquors
# 4     âIâve always been influenced by the idea o...  Petrocks Liquors
# ...                                                 ...               ...
# 4688  In the 1860âs Buena Vista covered more than ...  Petrocks Liquors
# 4689  Unlike other reds, Pinot Noir grapes prefer th...  Petrocks Liquors
# 4690  Lindemanâs wines contain the spirit and pass...  Petrocks Liquors
# 4691  The inspiration for 14 Hands wines recalls a t...  Petrocks Liquors
# 4692  While much of Italy celebrates its past, north...  Petrocks Liquors
#
#                                      address
# 0     419 Amwell Road Hillsborough, NJ 08844
# 1     419 Amwell Road Hillsborough, NJ 08844
# 2     419 Amwell Road Hillsborough, NJ 08844
# 3     419 Amwell Road Hillsborough, NJ 08844
# 4     419 Amwell Road Hillsborough, NJ 08844
# ...                                      ...
# 4688  419 Amwell Road Hillsborough, NJ 08844
# 4689  419 Amwell Road Hillsborough, NJ 08844
# 4690  419 Amwell Road Hillsborough, NJ 08844
# 4691  419 Amwell Road Hillsborough, NJ 08844
# 4692  419 Amwell Road Hillsborough, NJ 08844
#
# [4450 rows x 9 columns]

# %%
len(wine_df)
# Out:
# 4450

# %%
wine_df.to_csv("petrocks_clean_final.csv", index= False)
