# %%
import pandas as pd
import numpy as np

# %%
# Save path to data set in a variable
data_file_1 = "garys_wine_real2.csv"
data_file_2 = "chathambuyritecleaned.csv"
data_file_3 = "petrocks_wine_final.csv"

# %%
# Use Pandas to read data:
garys_df = pd.read_csv(data_file_1)
bottleking_df = pd.read_csv(data_file_2)
petrocks_df = pd.read_csv(data_file_3)

# %%
#gives you the top 5 rows of the file
garys_df.head()
# Out:
#                                              name        country  \
# 0               Angels Landing Cabernet Sauvignon  United States
# 1                      Angels Landing Merlot Napa  United States
# 2                             Antale Veneto Rosso          Italy
# 3       Articulate Cabernet Sauvignon Walla Walla  United States
# 4  Baus Family Cabernet Sauvignon Private Reserve  United States
#
#                region       state            varietal  price  \
# 0         Napa Valley  California  Cabernet Sauvignon  22.99
# 1         Napa Valley  California              Merlot  16.99
# 2              Veneto      Veneto             Corvina  11.99
# 3  Walla Walla Valley  Washington  Cabernet Sauvignon  14.99
# 4    Alexander Valley  California  Cabernet Sauvignon  16.99
#
#                                          description      merchant  \
# 0  This Cabernet has it all. Ripe dark fruit, str...  Gary's Wayne
# 1  A rich mix of black fruit, hints of dark choco...  Gary's Wayne
# ...

# %%
#gives you the top 5 rows of the file
bottleking_df.head()
# Out:
#    Unnamed: 0                          name        country region  \
# 0           0            Twisted Chardonnay  United States    NaN
# 1           1     Long Barn Pinot Noir 2018  United States    NaN
# 2           2    Oyster Bay Sauvignon Blanc    New Zealand    NaN
# 3           3  Kim Crawford Sauvignon Blanc    New Zealand    NaN
# 4           4          Josh Sauvignon Blanc  United States    NaN
#
#          state         varietal   price  \
# 0   California       Chardonnay   $8.99
# 1   California       Pinot Noir  $12.99
# 2  Marlborough  Sauvignon Blanc  $15.99
# 3  Marlborough  Sauvignon Blanc  $17.99
# 4   California  Sauvignon Blanc  $16.99
#
#                                          description            merchant  \
# 0  Twisted is about having fun and enjoying the w...  Chatham BottleKing
# 1  One of the holy grail's of wine is finding a k...  Chatham BottleKing
# 2  The philosophy of Oyster Bay Marlborough is to...  Chatham BottleKing
# ...

# %%
#From below you can play with the list to reorganize the columns(Wine Table)
bottleking_df = bottleking_df[["name", "country", "region", "state", "varietal", "price", "description","merchant","address"]]
bottleking_df.head()
# Out:
#                            name        country region        state  \
# 0            Twisted Chardonnay  United States    NaN   California
# 1     Long Barn Pinot Noir 2018  United States    NaN   California
# 2    Oyster Bay Sauvignon Blanc    New Zealand    NaN  Marlborough
# 3  Kim Crawford Sauvignon Blanc    New Zealand    NaN  Marlborough
# 4          Josh Sauvignon Blanc  United States    NaN   California
#
#           varietal   price                                        description  \
# 0       Chardonnay   $8.99  Twisted is about having fun and enjoying the w...
# 1       Pinot Noir  $12.99  One of the holy grail's of wine is finding a k...
# 2  Sauvignon Blanc  $15.99  The philosophy of Oyster Bay Marlborough is to...
# 3  Sauvignon Blanc  $17.99  Kim Crawford Wines started out in a small Auck...
# 4  Sauvignon Blanc  $16.99  \nJoseph Carr was an award winning Sommelier a...
#
#              merchant                              address
# ...

# %%
#Find all instances of a value and replace
bottleking_df["price"] = bottleking_df["price"].str.replace("$", "").astype(float)

# %%
#gives you the top 5 rows of the file
petrocks_df.head()
# Out:
#                                           name        country       state  \
# 0   Kendall Jackson Chardonnay Vinters Reserve  United States  California
# 1                                  Apothic Red  United States  California
# 2             Robert Mondavi Woodbridge Merlot  United States  California
# 3                         Colosi Nero d' Avola          Italy      Sicily
# 4                   Coppola Diamond Chardonnay  United States  California
#
#     region                                   varietal   price  \
# 0      NaN                                 Chardonnay  $12.99
# 1      NaN  Cabernet Sauvignon,Merlot,Syrah,Zinfandel   $9.97
# 2      NaN                                     Merlot  $12.99
# 3  Sicilia                               Nero d'Avola  $12.99
# 4      NaN                                 Chardonnay  $11.99
#
#                                          description          merchant  \
# 0  âFrom day one we have been a family-owned an...  Petrocks Liquors
# ...

# %%
petrocks_df = petrocks_df[["name", "country", "region", "state", "varietal", "price", "description","merchant","address"]]
petrocks_df.head()
petrocks_df["price"] = petrocks_df["price"].str.replace("$", "").astype(float)

# %%
petrocks_df.head()
# Out:
#                                           name        country   region  \
# 0   Kendall Jackson Chardonnay Vinters Reserve  United States      NaN
# 1                                  Apothic Red  United States      NaN
# 2             Robert Mondavi Woodbridge Merlot  United States      NaN
# 3                         Colosi Nero d' Avola          Italy  Sicilia
# 4                   Coppola Diamond Chardonnay  United States      NaN
#
#         state                                   varietal  price  \
# 0  California                                 Chardonnay  12.99
# 1  California  Cabernet Sauvignon,Merlot,Syrah,Zinfandel   9.97
# 2  California                                     Merlot  12.99
# 3      Sicily                               Nero d'Avola  12.99
# 4  California                                 Chardonnay  11.99
#
#                                          description          merchant  \
# 0  âFrom day one we have been a family-owned an...  Petrocks Liquors
# ...

# %%
wineall_df=garys_df.append(bottleking_df,ignore_index=True)
wineall_df=wineall_df.append(petrocks_df,ignore_index=True)
wineall_df=wineall_df.replace(np.nan,'na')
wineall_df
# Out:
#                                                  name        country  \
# 0                   Angels Landing Cabernet Sauvignon  United States
# 1                          Angels Landing Merlot Napa  United States
# 2                                 Antale Veneto Rosso          Italy
# 3           Articulate Cabernet Sauvignon Walla Walla  United States
# 4      Baus Family Cabernet Sauvignon Private Reserve  United States
# ...                                               ...            ...
# 6088                     Candoni Pinot Grigio Organic          Italy
# 6089                                      Canei Peach          Italy
# 6090           Kendall Jackson Cabernet Grand Reserve  United States
# 6091                       Bacchus Cabernet Sauvignon  United States
# 6092   M Chapoutier Chateauneuf-Du-Pape La Bernardine         France
#
#                   region       state            varietal  price  \
# 0            Napa Valley  California  Cabernet Sauvignon  22.99
# ...

# %%
wineall_df.dtypes
# Out:
# name           object
# country        object
# region         object
# state          object
# varietal       object
# price          object
# description    object
# merchant       object
# address        object
# dtype: object

# %%
wineall_df.to_csv('allwine.csv',index=False)
