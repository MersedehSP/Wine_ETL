# %%
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import pandas as pd
import time
from webdriver_manager.chrome import ChromeDriverManager
from urllib.request import urlopen
import re

# %%
executable_path = {"executable_path": ChromeDriverManager().install()}
browser = Browser("chrome", **executable_path, headless=False)

url= "https://garyswine.com/shop/?category=Wine"

browser.visit(url)
    
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\brega\.wdm\drivers\chromedriver\win32\87.0.4280.20\chromedriver.exe] found in cache
# <html lang="en-US"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7COpen+Sans%7CRoboto:100,100i,300,300i,400,400i,500,500i,700,700i,900,900i%7CHeebo:100,300,400,500,700,800,900&amp;display=swap" id="ao_optimized_gfonts" media="all" onload="this.onload=null;this.media='all';" rel="stylesheet"/><link href="https://gmpg.org/xfn/11" rel="profile"/>
# ...

# %%
#browser.find_by_xpath('//h1')

# %%
with browser.get_iframe('city-hive-age-verification-iframe') as iframe:
    x = iframe.find_by_text('Yes').click()
    #x.find_by_text("Yes").click()
    
           
                          
                          
#<div class="view-type-section"><!----><div ng-repeat="style in ctrl.itemStyles" class="container"><button stop-event="click" class="button button-icon item-style-button" ng-click="ctrl.styleChanged(style.type)"><i class="icon fa fa-th-large"></i></button> <span ng-hide="$last" class="separator ch-primary-color">|</span></div><!----><div ng-repeat="style in ctrl.itemStyles" class="container"><button stop-event="click" class="button button-icon item-style-button" ng-click="ctrl.styleChanged(style.type)"><i class="icon fa fa-th-list"></i></button> <span ng-hide="$last" class="separator ch-primary-color ng-hide">|</span></div><!----></div>

# %%
product_list=[]
with browser.get_iframe('city-hive-store-front-iframe') as iframe:
    x= iframe.find_by_tag('div[class="view-type-section"]')
    
    y= x.find_by_tag('div')[1]
    
    y.click()
    time.sleep(5)
    info_container = iframe.find_by_tag('div[class="product-item-container"]')
    
    
    for name in info_container:
        bn=name.find_by_tag('div[class="product-name"]')
        bottle_name = name.text;

        info_data = name.find_by_tag('div[class="product-characteristics"]')
        bottle_data = info_data.text
        
        
        
        
        
        product_list.append({"name" : bottle_name,
                    "bottle_data" : bottle_data})
print(product_list)
# Out:
# [{'name': "Angels Landing Cabernet Sauvignon\ntype: wine, subtype: red, country: United States, \nGary's Direct\nAdd to Favorites\n2 reviews\n$22.99\nSize\n750ml\nVintage\n2016\nAdd to Cart", 'bottle_data': 'type: wine, subtype: red, country: United States, '}, {'name': "Antale Veneto Rosso\ntype: wine, subtype: blend, red, country: Italy, state: Veneto\nGary's Direct\nAdd to Favorites\n3 reviews\n$11.99\nSize\n750ml\nVintage\n2018\nAdd to Cart", 'bottle_data': 'type: wine, subtype: blend, red, country: Italy, state: Veneto'}, {'name': "Articulate Cabernet Sauvignon Walla Walla\ntype: wine, subtype: red, country: United States, \nGary's Direct\nAdd to Favorites\n$14.99\nSize\n750ml\nVintage\n2018\nAdd to Cart", 'bottle_data': 'type: wine, subtype: red, country: United States, '}, {'name': "Baus Family Cabernet Sauvignon Private Reserve\ntype: wine, subtype: red, country: United States, \nGary's Direct\nAdd to Favorites\n4 reviews\n$16.99\nSize\n750ml\nVintage\n2017\nAdd to Cart", 'bo
# ...

# %%
product_list=[]
with browser.get_iframe('city-hive-store-front-iframe') as iframe:
    x= iframe.find_by_tag('div[class="view-type-section"]')
    
    y= x.find_by_tag('div')[1]
    
    y.click()
    time.sleep(5)
    info_container = iframe.find_by_tag('div[class="product-item-container"]')
    
    
    for name in info_container:
        bn=name.find_by_tag('div[class="product-name"]')
        bottle_name = name.text;
        
        info_data = name.find_by_tag('div[class="product-characteristics"]')
        text_wine_data = info_data.find_by_tag('span')
        for data in text_wine_data:
            print(data)
        
        bottle_data = text_wine_data.text
        data = bottle_data.split()
        #type_is= "type:"
        
        #s = "this is a sentense"
        target = "type:"
        #words = s.split()
        for i,w in enumerate(data):
            if w == target:
                # next word
                type1= data[i+1]
            else:
                type1= 'NA'
        
        
        
    
        
        #product_list.append({"name" : bottle_name,
                    #"bottle_data" : bottle_data})
        print(type1)
        print(bottle_data)
#print(product_list)
# Out:
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,
# ...
# NA
# type: wine,

# %%
with browser.get_iframe('city-hive-store-front-iframe') as iframe:
    x= iframe.find_by_tag('div[class="view-type-section"]')
    
    y= x.find_by_tag('div')[1]
    
    y.click()
    time.sleep(5)

# %%
url2= "https://widget.cityhive.net/store_front.html#/widget/5963aaf8155cb61a06cfe5de/search?query_params=%7B%22views%22%3A%5B%22Wine%22%5D%7D&nav_path=%5B%7B%22title%22%3A%22Wine%22%2C%22query%22%3A%7B%22views%22%3A%5B%22Wine%22%5D%7D%2C%22id%22%3A%22Wine%22%7D%5D"

# %%
html = browser.html
res = BeautifulSoup(html, "html5lib")
tag = res.find("iframe")

url2 = tag['src']

browser.visit(url2)
    
html2 = browser.html
soup2 = BeautifulSoup(html2, 'html.parser')

# %%
#ind_by_tag('div[class="product-name"]')
test = soup2.find('div', class_='products-list')
print(test)
# Out:
# None

# %%
testa = soup2.find('body', id='city-hive-store-front')
print(testa)
testb = testa.find_all('div', class_='product-name')

print(testb)


#soup2
# Out:
# <body class="grade-a platform-browser platform-win32 platform-ready" id="city-hive-store-front" style="position: relative; overflow-y: visible;">
# <div class="spinner" id="ch-loader" style="z-index: 99999; position: absolute; right: 0px; left: 0px; margin: auto; top: 25%; text-align: center; stroke: rgb(0, 0, 0); fill: rgb(0, 0, 0); display: none;">
# <svg style="width: 50px; height: 50px; stroke: #000000; fill: #000000;" viewbox="0 0 64 64">
# <g fill="none" fill-rule="evenodd" stroke-width="3">
# <circle cx="32" cy="32" r="12.0076">
# <animate attributename="r" begin="0s" calcmode="spline" dur="2s" keysplines="0.1,0.2,0.3,1" keytimes="0;1" repeatcount="indefinite" values="0;24"></animate>
# <animate attributename="stroke-opacity" begin="0s" dur="2s" repeatcount="indefinite" values=".2;1;.2;0"></animate>
# </circle>
# <circle cx="32" cy="32" r="22.915">
# ...
