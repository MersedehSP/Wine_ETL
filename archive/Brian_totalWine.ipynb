# %%
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import pandas as pd
import time
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {"executable_path": ChromeDriverManager().install()}
browser = Browser("chrome", **executable_path, headless=False)

url= "https://www.totalwine.com/wine/c/c0020?viewall=true&pageSize=24&sort=price-asc"

browser.visit(url)
    
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\brega\.wdm\drivers\chromedriver\win32\87.0.4280.20\chromedriver.exe] found in cache
# <html lang="en"><head at-action-key="allpage" class="at-element-marker" profile="http://www.w3.org/2005/10/profile">
# ...

# %%
#grid = browser.find_by_tag('div[class="titleRatingsHolder__1TZlqhxF"]')

#productCard__2nWxIKmi
#counter = 0
#for x in grid:
    #list_of_bottles = browser.find_by_tag('div[class="titleRatingsHolder__1TZlqhxF"]')
    #page_bottle_list =[]
    #for x in list_of_bottles:
        #h2= x.find_by_tag('h2')
        #a_tag=h2.find_by_tag('a')
        #page_bottle_list.append(a_tag)
    

    #page_bottle_list[counter].click()
    #counter = counter + 1
    #time.sleep(3)
    #browser.back()


#bottle_name = browser.find_by_tag('div[class="productCardInfoWrapper__3zELn1xQ"]')

#for x in bottle_name:
        #page_bottle_list.append(x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-ccc9ba0269a9> in <module>
#       4 counter = 0
#       5 for x in grid:
# ----> 6     list_of_bottles = browser.find_by_tag('div[class="titleRatingsHolder__1TZlqhxF"]')
#       7     page_bottle_list =[]
#       8     for x in list_of_bottles:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by_tag(self, tag, wait_time)
#     534             self.driver.find_elements_by_tag_name,
#     535             tag,
# --> 536             wait_time=wait_time,
#     537     )
#     538
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by(self, finder, selector, original_find, original_query, wait_time)
#     245
#     246         while time.time() < end_time:
# --> 247             elem_list = _find(self, finder, selector)
#     248
# ...
