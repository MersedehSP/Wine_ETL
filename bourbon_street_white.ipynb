# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import os
import pandas as pd
import numpy as np
from urllib.request import urlopen
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from urllib.request import urlopen
import seaborn as sns

# %%
# URL of page to be scraped
url = 'https://www.bourbonstreetwineandspirits.com/search/categories/Wine/sort/title%20asc/categories/White%20Wine/result_size/25'

# %%
# Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="search-categories-Wine-sort-title-asc-categories-White-Wine-result_size" lang="en" prefix="og: http://ogp.me/ns#">
#  <head>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-154648458-1">
#   </script>
#   <script>
#    window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments);}gtag('js',new Date());gtag('config','UA-154648458-1',{'cookie_domain':'.bourbonstreetwineandspirits.com','cookie_flags':'Secure'});gtag('config','UA-10281907-5',{'cookie_domain':'.bourbonstreetwineandspirits.com','cookie_flags':'Secure'});
#   </script>
#   <title>
#    Bourbon Street Wine &amp; Spirits
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="DPR, Width, Viewport-Width" http-equiv="Accept-CH"/>
#   <meta content="843FB0E228AF1435883AC2EE098A12F1" name="msvalidate.01">
#    <meta content="false" property="ix:autoInit"/>
#    <meta content="Largest selection of single barrel bourbons and spirits" name="description">
#     <meta content="Bourbon Street Wine &amp;amp; Spirits" property="og:title">
#      <meta content="website" property="og:type">
#       <meta content="https://www.bourbonstreetwineandspirits.com/search/categories/Wine/sort/title asc/categories/White Wine/result_size/25" property="og:url">
#        <meta content="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=1200&amp;h=630&amp;fit=fillmax&amp;bg=3d5b43" property="og:image"/>
#        <meta content="en_US" property="og:locale"/>
#        <meta content="Bourbon Street Wine &amp; Spirits" property="og:site_name"/>
#        <style>
#         @font-face {
#   font-family: 'Source Sans Pro';
#   font-style: normal;
#   font-weight: 400;
#   src: url(https://fonts.gstatic.com/s/sourcesanspro/v14/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7g.ttf) format('truetype');
# }
#        </style>
#        <link href="https://netdna.bootstrapcdn.com/font-awesome/4.6.0/css/font-awesome.css" rel="stylesheet"/>
#        <link href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.css" rel="stylesheet" type="text/css">
#         <link href="https://cdn.jsdelivr.net/npm/summernote@0.8.16/dist/summernote-bs4.min.css" rel="stylesheet"/>
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/tempusdominus-bootstrap-4/5.1.2/css/tempusdominus-bootstrap-4.min.css" rel="stylesheet" type="text/css">
#          <link href="https://cdnjs.cloudflare.com/ajax/libs/dropzone/5.7.2/min/dropzone.min.css" rel="stylesheet" type="text/css"/>
#          <link href="https://unpkg.com/bootstrap-table@1.16.0/dist/bootstrap-table.min.css" rel="stylesheet"/>
#          <link href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-touchspin/3.1.1/jquery.bootstrap-touchspin.min.css" rel="stylesheet"/>
#          <link href="https://cdn.bottlenose-wine.com/bourbonstreetwineandspirits.com/styles-1607008644.css" rel="stylesheet" type="text/css">
#           <link href="https://www.bourbonstreetwineandspirits.com/search/categories/White Wine/tag/http://www.bourbonstreetwineandspirits.com/search/categories/Wine/sort/title%20asc/categories/White%20Wine/result_size/25" rel="canonical">
#            <script>
#             document.createElement("picture");
#            </script>
#            <!-- <script src="https://cdnjs.cloudflare.com/ajax/libs/turbolinks/5.2.0/turbolinks.js" defer></script> -->
#            <script async="" src="https://cdnjs.cloudflare.com/ajax/libs/picturefill/3.0.3/picturefill.min.js">
#            </script>
#            <script crossorigin="anonymous" integrity="sha256-CSXorXvZcTkaix6Yvo6HppcZGetbYMGWSFlBw8HfCJo=" src="https://code.jquery.com/jquery-3.4.1.min.js">
#            </script>
#            <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js">
#            </script>
#            <script crossorigin="anonymous" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js">
#            </script>
#            <script crossorigin="anonymous" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js">
#            </script>
#            <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.22.0/moment.min.js">
#            </script>
#            <script src="https://cdn.bottlenose.wine/js/imgix-3.4.2.min.js">
#            </script>
#            <script async="" src="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.1.1/lazysizes.min.js">
#            </script>
#            <script defer="" src="https://cdn.bottlenose.wine/js/modernizr-custom-3.5.0.min.js">
#            </script>
#            <script crossorigin="anonymous" data-auto-replace-svg="nest" defer="" src="https://kit.fontawesome.com/2e80d28318.js">
#            </script>
#            <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/1000hz-bootstrap-validator/0.11.9/validator.min.js">
#            </script>
#            <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/dropzone/5.7.2/min/dropzone.min.js">
#            </script>
#            <script defer="" src="https://cdn.jsdelivr.net/npm/summernote@0.8.16/dist/summernote-bs4.min.js">
#            </script>
#            <script defer="" src="/javascripts/summernote-image-attributes.js.pagespeed.jm.XXyyuz29vC.js">
#            </script>
#            <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/tempusdominus-bootstrap-4/5.1.2/js/tempusdominus-bootstrap-4.min.js">
#            </script>
#            <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/raphael/2.2.0/raphael-min.js">
#            </script>
#            <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-touchspin/3.1.1/jquery.bootstrap-touchspin.min.js">
#            </script>
#            <script defer="" src="/javascripts/ecommerce.js.pagespeed.jm.Q965lw0i76.js">
#            </script>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=57&amp;h=57&amp;fit=crop&amp;crop=left" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=114&amp;h=114&amp;fit=crop&amp;crop=left" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=72&amp;h=72&amp;fit=crop&amp;crop=left" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=144&amp;h=144&amp;fit=crop&amp;crop=left" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=60&amp;h=60&amp;fit=crop&amp;crop=left" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=120&amp;h=120&amp;fit=crop&amp;crop=left" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=76&amp;h=76&amp;fit=crop&amp;crop=left" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=152&amp;h=152&amp;fit=crop&amp;crop=left" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=196&amp;h=196&amp;fit=crop&amp;crop=left" rel="icon" sizes="196x196" type="image/png"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=96&amp;h=96&amp;fit=crop&amp;crop=left" rel="icon" sizes="96x96" type="image/png"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=32&amp;h=32&amp;fit=crop&amp;crop=left" rel="icon" sizes="32x32" type="image/png"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=16&amp;h=16&amp;fit=crop&amp;crop=left" rel="icon" sizes="16x16" type="image/png"/>
#            <link href="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?w=128&amp;h=128&amp;fit=crop&amp;crop=left" rel="icon" sizes="128x128" type="image/png"/>
#           </link>
#          </link>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="bourbonstreetwineandspirits-com">
#   <header>
#    <nav class="navbar navbar-expand-lg d-flex flex-row brand-background align-items-center" id="main-navbar">
#     <a class="navbar-brand px-2" href="/">
#      <img alt="Bourbon Street Wine &amp; Spirits" class="img-fluid" ix-src="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png" sizes="(min-width: 1200px) 300px, (min-width: 576px) 200px, 33vw"/>
#     </a>
#     <ul class="nav flex-row d-lg-none">
#      <li class="nav-item">
#       <a class="nav-link" href="/account">
#        <i aria-hidden="true" class="fas fa-user fa-lg">
#        </i>
#       </a>
#      </li>
#      <li class="nav-item">
#       <a class="nav-link" href="/cart">
#        <i aria-hidden="true" class="fas fa-shopping-cart fa-lg">
#        </i>
#       </a>
#      </li>
#      <li class="nav-item">
#       <a aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="nav-link" data-target=".main-navbar-collapse" data-toggle="collapse" href="#">
#        <i class="fas fa-bars fa-lg">
#        </i>
#       </a>
#      </li>
#     </ul>
#     <div class="d-lg-none w-100 p-2">
#      <form action="/search/" class="search-form ui-front" role="search">
#       <div class="input-group">
#        <div class="input-group-prepend">
#         <span class="input-group-text">
#          Search
#         </span>
#        </div>
#        <label class="sr-only" for="search-suggest">
#         Search
#        </label>
#        <input autocomplete="off" class="form-control search-suggest" id="search-suggest" name="term" spellcheck="false" type="text" value=""/>
#        <div class="input-group-append">
#         <button aria-label="Search" class="btn btn-primary" type="submit">
#          <span class="fas fa-search">
#          </span>
#         </button>
#        </div>
#       </div>
#      </form>
#     </div>
#     <div class="collapse navbar-collapse main-navbar-collapse p-2" id="main-nav">
#      <ul class="navbar-nav">
#       <li class="nav-item">
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="wine-dropdown">
#         Wine
#        </a>
#        <div aria-labelledby="wine-dropdown" class="dropdown-menu" data-name="wine" role="menu">
#         <div class="container-fluid shop-panel">
#          <div class="row">
#           <div class="col-6 col-md-2">
#            <h5>
#             By Varietal/Type
#            </h5>
#            <ul class="list-unstyled product-types">
#             <li>
#              <a href="/search/categories/Red Wine">
#               Red Wine
#              </a>
#              <ul class="list-unstyled varietals ml-3">
#               <li>
#                <a href="/search/varietal/Cabernet Sauvignon">
#                 Cabernet Sauvignon
#                </a>
#               </li>
#               <li>
#                <a href="/search/varietal/Merlot">
#                 Merlot
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="/search/categories/White Wine">
#               White Wine
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-6 col-md-2">
#            <h5>
#             By Region
#            </h5>
#            <ul class="list-unstyled">
#             <li>
#              <a href="/search/category/Wine/country/California">
#               California
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Wine/country/United States">
#               United States
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Wine/country/Italy">
#               Italy
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-6 col-md-8 d-none d-sm-block">
#            <h5>
#             Recommendations
#            </h5>
#            <div class="card-deck">
#             <div class="product card bg-light mb-2" data-id="9296898">
#              <a class="card-body" href="/products/9296898/dansk-mjod-klapojster-mjod">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Dansk Mjod Klapøjster Mjød" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/558935.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="9296898" data-sku="13679">
#                 Dansk Mjod Klapøjster Mjød
#                 <div class="price text-right">
#                  $29.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="9203459">
#              <a class="card-body" href="/products/9203459/sterling-vintner-s-collection-cabernet-sauvignon">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Sterling Vintner's Collection Cabernet Sauvignon  " class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/585707.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="9203459" data-sku="7807">
#                 Sterling Vintner's Collection Cabernet Sauvignon
#                 <div class="price text-right">
#                  $14.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="9296899">
#              <a class="card-body" href="/products/9296899/dansk-mjod-viking-gl">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Dansk Mjod Viking Gl" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/572183.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="9296899" data-sku="13680">
#                 Dansk Mjod Viking Gl
#                 <div class="price text-right">
#                  $29.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="9203461">
#              <a class="card-body" href="/products/9203461/sterling-vintner-s-collection-merlot">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Sterling Vintner's Collection Merlot" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/556325.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="9203461" data-sku="7809">
#                 Sterling Vintner's Collection Merlot
#                 <div class="price text-right">
#                  $14.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="9203469">
#              <a class="card-body" href="/products/9203469/sterling-vintner-s-collection-pinot-grigio">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Sterling Vintner's Collection Pinot Grigio" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/562518.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="9203469" data-sku="11365">
#                 Sterling Vintner's Collection Pinot Grigio
#                 <div class="price text-right">
#                  $10.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="9203471">
#              <a class="card-body" href="/products/9203471/sterling-vintner-s-collection-sauvignon-blanc">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Sterling Vintner's Collection Sauvignon Blanc" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/562519.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="9203471" data-sku="10052">
#                 Sterling Vintner's Collection Sauvignon Blanc
#                 <div class="price text-right">
#                  $10.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="9203217">
#              <a class="card-body" href="/products/9203217/costa-al-sole-montepulciano-d-abruzzo">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Costa al Sole Montepulciano d'Abruzzo" class="img-fluid" ix-src="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?monochrome=adb5bd&amp;border=5,adb5bd&amp;pad=20&amp;bg=e9ecef" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="9203217" data-sku="12754">
#                 Costa al Sole Montepulciano d'Abruzzo
#                 <div class="price text-right">
#                  $10.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="9203218">
#              <a class="card-body" href="/products/9203218/costa-al-sole-nero-d-avola">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Costa al Sole Nero d'Avola" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/169469.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="9203218" data-sku="12755">
#                 Costa al Sole Nero d'Avola
#                 <div class="price text-right">
#                  $10.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13350932">
#              <a class="card-body" href="/products/13350932/dansk-mjod-vikingernes">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Dansk Mjod Vikingernes" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/196114.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13350932" data-sku="14254">
#                 Dansk Mjod Vikingernes
#                 <div class="price text-right">
#                  $29.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10284308">
#              <a class="card-body" href="/products/10284308/valenzano-cranberry-wine">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Valenzano Cranberry Wine" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/92783.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10284308" data-sku="15442">
#                 Valenzano Cranberry Wine
#                 <div class="price text-right">
#                  $9.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13350933">
#              <a class="card-body" href="/products/13350933/dansk-mjod-ribe-mjod-mead">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Dansk Mjod Ribe Mjod Mead" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/503677.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13350933" data-sku="20400">
#                 Dansk Mjod Ribe Mjod Mead
#                 <div class="price text-right">
#                  $29.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13350934">
#              <a class="card-body" href="/products/13350934/dansk-mjod-viking-blod">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Dansk Mjod Viking Blod" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/316267.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13350934" data-sku="13681">
#                 Dansk Mjod Viking Blod
#                 <div class="price text-right">
#                  $29.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="nav-item">
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="beer-dropdown">
#         Beer
#        </a>
#        <div aria-labelledby="beer-dropdown" class="dropdown-menu" data-name="beer" role="menu">
#         <div class="container-fluid shop-panel">
#          <div class="row">
#           <div class="col-6 col-md-2">
#            <h5>
#             Type
#            </h5>
#            <ul class="list-unstyled product-types">
#             <li>
#              <a href="/search/categories/Ale">
#               Ale
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Stout">
#               Stout
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Barley%20Wine">
#               Barley Wine
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Fruit%20Beer">
#               Fruit Beer
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-6 col-md-2">
#            <h5>
#             Breweries
#            </h5>
#            <ul class="list-unstyled">
#             <li>
#              <a href="/search/category/Beer/brand/Abbaye%20de%20Rocs">
#               Abbaye de Rocs
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Allagash">
#               Allagash
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Brasserie%20Dupont">
#               Brasserie Dupont
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Brasserie%20d'Achouffe">
#               Brasserie d'Achouffe
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Brewery%20de%20Konigshoeven">
#               Brewery de Konigshoeven
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Brouwerij%20Lindemans">
#               Brouwerij Lindemans
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Chimay">
#               Chimay
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Corsendonk">
#               Corsendonk
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Dansk%20Mjod">
#               Dansk Mjod
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Delirium%20Brewery">
#               Delirium
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/J.W.%20Lees">
#               J.W. Lees
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Kwak">
#               Kwak
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/La%20Trappe">
#               La Trappe
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Lone%20Eagle%20Brewing">
#               Lone Eagle
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Tripel%20Karmeliet">
#               Tripel Karmeliet
#              </a>
#             </li>
#             <li>
#              <a href="/search/category/Beer/brand/Van%20Honsebrouck">
#               Van Honsebrouck
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-6 col-md-8 d-none d-sm-block">
#            <h5>
#             Recommendations
#            </h5>
#            <div class="card-deck">
#             <div class="product card bg-light mb-2" data-id="13342716">
#              <a class="card-body" href="/products/13342716/lone-eagle-brewing-bsws-collab-kcbs-rye-barrel-aged-breakfast-stout">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Lone Eagle Brewing BSWS COLLAB KCBS RYE BARREL-AGED BREAKFAST STOUT 16 oz." class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/549719.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13342716" data-sku="29871">
#                 Lone Eagle Brewing BSWS COLLAB KCBS RYE BARREL-AGED BREAKFAST STOUT 16 oz.
#                 <div class="price text-right">
#                  $11.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13342717">
#              <a class="card-body" href="/products/13342717/lone-eagle-brewing-bsws-collab-kcbs-bourbon-barrel-aged-breakfast-stout">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Lone Eagle Brewing BSWS COLLAB KCBS BOURBON BARREL-AGED BREAKFAST STOUT 16 oz." class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/549715.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13342717" data-sku="29870">
#                 Lone Eagle Brewing BSWS COLLAB KCBS BOURBON BARREL-AGED BREAKFAST STOUT 16 oz.
#                 <div class="price text-right">
#                  $11.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13342718">
#              <a class="card-body" href="/products/13342718/lone-eagle-brewing-bsws-collab-and-the-creek-don-t-ryes-rye-pale-ale">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Lone Eagle Brewing BSWS COLLAB AND THE CREEK DON'T RYES RYE PALE ALE 16 oz." class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/549717.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13342718" data-sku="29524">
#                 Lone Eagle Brewing BSWS COLLAB AND THE CREEK DON'T RYES RYE PALE ALE 16 oz.
#                 <div class="price text-right">
#                  $10.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10284303">
#              <a class="card-body" href="/products/10284303/chimay-anniversary-cinq-cents">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Chimay Anniversary Cinq Cents 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/573716.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10284303" data-sku="18199">
#                 Chimay Anniversary Cinq Cents 750ml
#                 <div class="price text-right">
#                  $29.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13350931">
#              <a class="card-body" href="/products/13350931/dansk-mjod-old-danish-braggot">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Dansk Mjod Old Danish Braggot 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/161608.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13350931" data-sku="17523">
#                 Dansk Mjod Old Danish Braggot 750ml
#                 <div class="price text-right">
#                  $17.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10040387">
#              <a class="card-body" href="/products/10040387/abbaye-de-rocs-brune">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Abbaye de Rocs Brune 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?monochrome=adb5bd&amp;border=5,adb5bd&amp;pad=20&amp;bg=e9ecef" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10040387" data-sku="13054">
#                 Abbaye de Rocs Brune 750ml
#                 <div class="price text-right">
#                  $10.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10040388">
#              <a class="card-body" href="/products/10040388/abbaye-de-rocs-grand-cru">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Abbaye de Rocs Grand Cru 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?monochrome=adb5bd&amp;border=5,adb5bd&amp;pad=20&amp;bg=e9ecef" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10040388" data-sku="13053">
#                 Abbaye de Rocs Grand Cru 750ml
#                 <div class="price text-right">
#                  $10.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10040389">
#              <a class="card-body" href="/products/10040389/abbaye-de-rocs-imperial-triple">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Abbaye de Rocs Imperial Triple 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png?monochrome=adb5bd&amp;border=5,adb5bd&amp;pad=20&amp;bg=e9ecef" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10040389" data-sku="1455">
#                 Abbaye de Rocs Imperial Triple 750ml
#                 <div class="price text-right">
#                  $10.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10040390">
#              <a class="card-body" href="/products/10040390/brasserie-d-achouffe-la-chouffe">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Brasserie d'Achouffe La Chouffe 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/548102.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10040390" data-sku="7756">
#                 Brasserie d'Achouffe La Chouffe 750ml
#                 <div class="price text-right">
#                  $11.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10040393">
#              <a class="card-body" href="/products/10040393/allagash-dubbel-reserve">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Allagash Dubbel Reserve 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/530492.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10040393" data-sku="191">
#                 Allagash Dubbel Reserve 750ml
#                 <div class="price text-right">
#                  $9.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10040394">
#              <a class="card-body" href="/products/10040394/allagash-tripel">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Allagash Tripel 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/548088.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10040394" data-sku="2471">
#                 Allagash Tripel 750ml
#                 <div class="price text-right">
#                  $9.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="10040397">
#              <a class="card-body" href="/products/10040397/chimay-grande-reserve-blue">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Chimay Grande Reserve Blue 750ml" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/310516.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="10040397" data-sku="5403">
#                 Chimay Grande Reserve Blue 750ml
#                 <div class="price text-right">
#                  $12.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="nav-item">
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="spirits-dropdown">
#         Spirits
#        </a>
#        <div aria-labelledby="spirits-dropdown" class="dropdown-menu" data-name="spirits" role="menu">
#         <div class="container-fluid shop-panel">
#          <div class="row">
#           <div class="col-6 col-md-2">
#            <h5>
#             Spirit Types
#            </h5>
#            <ul class="list-unstyled">
#             <li>
#              <a href="/search/categories/Whiskey">
#               Whiskey
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Vodka">
#               Vodka
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Liqueurs%20%26%20Cordials">
#               Liqueurs &amp; Cordials
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Tequila">
#               Tequila
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Rum">
#               Rum
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Gin">
#               Gin
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Brandy">
#               Brandy
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Cognac">
#               Cognac
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Ap%C3%A9ritif">
#               Apéritif
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Mezcal">
#               Mezcal
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Schnapps">
#               Schnapps
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Prepared%20Cocktails">
#               Prepared Cocktails
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Limoncello">
#               Limoncello
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Absinthe">
#               Absinthe
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Amaretto">
#               Amaretto
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Sambuca">
#               Sambuca
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Armagnac">
#               Armagnac
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Blue%20Curacao">
#               Blue Curacao
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Dark%20Creme%20de%20Cacao">
#               Dark Creme de Cacao
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Light%20Creme%20de%20Cacao">
#               Light Creme de Cacao
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Arak">
#               Arak
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Grappa">
#               Grappa
#              </a>
#             </li>
#             <li>
#              <a href="/search/categories/Akvavit">
#               Akvavit
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-6 col-md-2">
#            <h5>
#             By Brand
#            </h5>
#            <ul class="list-unstyled">
#             <li>
#              <a href="/search/brand/Smirnoff">
#               Smirnoff
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Hiram%20Walker">
#               Hiram Walker
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/The%20Glenlivet">
#               The Glenlivet
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Highland%20Park">
#               Highland Park
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Jim%20Beam">
#               Jim Beam
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Johnnie%20Walker">
#               Johnnie Walker
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Kavalan">
#               Kavalan
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Balvenie">
#               Balvenie
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Knob%20Creek">
#               Knob Creek
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Macallan">
#               Macallan
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Glenmorangie">
#               Glenmorangie
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Jameson">
#               Jameson
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Nikka">
#               Nikka
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/The%20Game%20of%20Thrones%20Whisky%20Collection">
#               The Game of Thrones Whisky Collection
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Crown%20Royal">
#               Crown Royal
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Evan%20Williams">
#               Evan Williams
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Jack%20Daniel's">
#               Jack Daniel's
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Laphroaig">
#               Laphroaig
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Woodford%20Reserve">
#               Woodford Reserve
#              </a>
#             </li>
#             <li>
#              <a href="/search/brand/Aberlour">
#               Aberlour
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-6 col-md-8 d-none d-sm-block">
#            <h5>
#             Recommendations
#            </h5>
#            <div class="card-deck">
#             <div class="product card bg-light mb-2" data-id="13443584">
#              <a class="card-body" href="/products/13443584/barrel-bandit-high-rye-bourbon-single-barrel-5">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Barrel Bandit High Rye Bourbon Single Barrel #5" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/580427.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13443584" data-sku="494635">
#                 Barrel Bandit High Rye Bourbon Single Barrel #5
#                 <div class="price text-right">
#                  $49.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13445888">
#              <a class="card-body" href="/products/13445888/michter-s-us-1-original-sour-mash-whiskey">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Michter's US*1 Original Sour Mash Whiskey" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/523367.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13445888" data-sku="18599">
#                 Michter's US*1 Original Sour Mash Whiskey
#                 <div class="price text-right">
#                  $49.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13387008">
#              <a class="card-body" href="/products/13387008/skyy-vodka">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Skyy Vodka" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/428100.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13387008" data-sku="1738">
#                 Skyy Vodka
#                 <div class="price text-right">
#                  $15.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13386753">
#              <a class="card-body" href="/products/13386753/chivas-regal-blended-scotch-whisky-12-year-old">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Chivas Regal Blended Scotch Whisky 12 year old" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/551580.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13386753" data-sku="267">
#                 Chivas Regal Blended Scotch Whisky 12 year old
#                 <div class="price text-right">
#                  $29.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13387009">
#              <a class="card-body" href="/products/13387009/smirnoff-vodka-100-proof">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Smirnoff Vodka 100 Proof" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/347757.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13387009" data-sku="736">
#                 Smirnoff Vodka 100 Proof
#                 <div class="price text-right">
#                  $19.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13443586">
#              <a class="card-body" href="/products/13443586/maker-s-mark-private-select-store-pick-barrel-6">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Maker's Mark Private Select &quot;Store Pick&quot; Barrel #6" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/580678.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13443586" data-sku="254646">
#                 Maker's Mark Private Select "Store Pick" Barrel #6
#                 <div class="price text-right">
#                  $69.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13387010">
#              <a class="card-body" href="/products/13387010/smirnoff-blueberry-vodka">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Smirnoff Blueberry Vodka" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/549340.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13387010" data-sku="12435">
#                 Smirnoff Blueberry Vodka
#                 <div class="price text-right">
#                  $14.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13443587">
#              <a class="card-body" href="/products/13443587/maker-s-mark-private-select-store-pick-barrel-7">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Maker's Mark Private Select &quot;Store Pick&quot; Barrel #7 " class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/580679.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13443587" data-sku="254647">
#                 Maker's Mark Private Select "Store Pick" Barrel #7
#                 <div class="price text-right">
#                  $69.99
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="product card bg-light mb-2" data-id="13386755">
#              <a class="card-body" href="/products/13386755/dewar-s-caribbean-smooth-rum-cask-finish-blended-scotch-whisky-8-year-old">
#               <div class="row">
#                <div class="col-3 image center-block">
#                 <img alt="Dewar's Caribbean Smooth Rum Cask Finish Blended Scotch Whisky 8 year old" class="img-fluid" ix-src="https://icdn.bottlenose.wine/images/full/536767.jpg" sizes="50px"/>
#                </div>
#                <div class="col-9 product-name" data-product-id="13386755" data-sku="8354">
# ...
#             Sterling Vintner's Collection was conceived to offer distinctive, well-made wines that are varietal…
#            </div>
#            <div class="d-flex icons mt-1 mb-2">
#            </div>
#            <div class="d-flex product-icons">
#             <div class="mx-1" data-placement="bottom" data-toggle="tooltip" title="white-wine">
#              <i class="fas fa-wine-glass-alt fa-2x" style="color:#E5DB80;">
#              </i>
#             </div>
#            </div>
#           </div>
#           <div class="col-md-3 card-footer">
#            <div class="prices">
#             <div class="on-sale">
#              <s class="regular-price">
#               $13.99
#              </s>
#              <span class="savings">
#               Save $3.00 (21%)
#              </span>
#              <span class="sale-price">
#               $10.99
#              </span>
#             </div>
#            </div>
#            <div class="buy-button-wrapper">
#             <a class="btn btn-buy btn-sm" href="/products/9203471/sterling-vintner-s-collection-sauvignon-blanc">
#              Buy
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="col mb-3" data-price="9.99">
#         <div class="card h-100 pg-2978">
#          <div class="row">
#           <div class="col-md-3 card-header">
#            <a class="product-link" href="/products/9548786/valenzano-shamong-white">
#             <img alt="Valenzano Shamong White" class="mx-auto d-block mt-2" ix-src="https://icdn.bottlenose.wine/images/full/92785.jpg?fit=fillmax&amp;fill=solid&amp;w=140&amp;h=140" sizes="(min-width: 768px) 120px, 25vw"/>
#            </a>
#           </div>
#           <div class="col-md-6 card-body" data-href="/products/9548786/valenzano-shamong-white">
#            <a class="product-name">
#             <div class="product-name" data-brandid="25940" data-itemid="246401" data-product-id="9548786" data-sku="15441">
#              Valenzano Shamong White
#             </div>
#            </a>
#            <div class="synopsis">
#             A Niagara from New Jersey.
#            </div>
#            <div class="brief-description">
#             A light, fruity and easy to drink white wine made from niagara grapes. Styled after the Shamong Red…
#            </div>
#            <div class="d-flex icons mt-1 mb-2">
#            </div>
#            <div class="d-flex product-icons">
#             <div class="mx-1" data-placement="bottom" data-toggle="tooltip" title="white-wine">
#              <i class="fas fa-wine-glass-alt fa-2x" style="color:#E5DB80;">
#              </i>
#             </div>
#            </div>
#           </div>
#           <div class="col-md-3 card-footer">
#            <div class="prices">
#             <div class="not-on-sale">
#              <span class="price">
#               $9.99
#              </span>
#             </div>
#            </div>
#            <div class="buy-button-wrapper">
#             <a class="btn btn-buy btn-sm" href="/products/9548786/valenzano-shamong-white">
#              Buy
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer id="footer">
#    <div class="bar">
#     <div class="container">
#      <div class="d-flex flex-wrap justify-content-between align-items-center">
#       <form class="form-inline email-signup-form needs-validation" novalidate="" role="form">
#        <div class="form-group">
#         <label class="mr-2" for="email">
#          Receive special offers
#         </label>
#         <div class="input-group">
#          <input class="form-control" id="email" name="email" placeholder="Enter your email address" required="required" type="email">
#           <div class="input-group-append">
#            <button class="btn btn-default" type="submit">
#             Sign up!
#            </button>
#           </div>
#          </input>
#         </div>
#        </div>
#       </form>
#       <div class="d-flex align-items-center justify-content-center" id="social-links">
#        <span>
#         <strong>
#          Follow Us:
#         </strong>
#        </span>
#        <a alt="Check Us Out on Facebook!" href="https://www.facebook.com/bourbonstreetwineandspirits" target="_blank">
#         <i class="fab fa-facebook fa-2x mx-2">
#         </i>
#        </a>
#        <a alt="Check Us Out on Twitter!" href="https://twitter.com/Bourbonstwine" target="_blank">
#         <i class="fab fa-twitter fa-2x mx-2">
#         </i>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="bar2">
#     <div class="container">
#      <div class="row">
#       <div class="col-6 col-md-3 col-lg">
#        <h5>
#         Wine
#        </h5>
#        <ul class="list-unstyled">
#         <li>
#          <a href="/search/categories/Red%20Wine">
#           Red Wine
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/White%20Wine">
#           White Wine
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Mead">
#           Mead
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Fruit%20Wine">
#           Fruit Wine
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Dessert%20Wine">
#           Dessert Wine
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Ros%C3%A9%20Wine">
#           Rosé Wine
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Sangria">
#           Sangria
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-6 col-md-3 col-lg">
#        <h5>
#         Beer
#        </h5>
#        <ul class="list-unstyled">
#         <li>
#          <a href="/search/categories/Ale">
#           Ale
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Stout">
#           Stout
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Barley%20Wine">
#           Barley Wine
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Fruit%20Beer">
#           Fruit Beer
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-6 col-md-3 col-lg">
#        <h5>
#         Spirits
#        </h5>
#        <ul class="list-unstyled">
#         <li>
#          <a href="/search/categories/Liqueurs%20%26%20Cordials">
#           Liqueurs &amp; Cordials
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Whiskey">
#           Whiskey
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Rum">
#           Rum
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Vodka">
#           Vodka
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Gin">
#           Gin
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Brandy">
#           Brandy
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Cognac">
#           Cognac
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Tequila">
#           Tequila
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Mezcal">
#           Mezcal
#          </a>
#         </li>
#         <li>
#          <a href="/search/categories/Ap%C3%A9ritif">
#           Apéritif
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-6 col-md-3 col-lg">
#        <h5>
#         Store Info
#        </h5>
#        <ul class="list-unstyled">
#         <li>
#          <a href="/contact">
#           Contact Us
#          </a>
#         </li>
#         <li>
#          <a class="shipping-policy" href="/shipping-policy">
#           Delivery Information
#          </a>
#         </li>
#         <li>
#          <a href="/privacy-policy">
#           Privacy Policy
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-6 col-md-4 text-right" id="locations">
#        <div class="location">
#         <address>
#          <div class="company">
#           Bourbon Street Wine &amp; Spirits
#          </div>
#          <div class="street-address">
#           1217 Route 22 West
#          </div>
#          <div class="city-state-zip">
#           <span class="city">
#            Phillipsburg
#           </span>
#           <span class="state">
#            NJ
#           </span>
#           <span class="zip">
#            08865
#           </span>
#          </div>
#          <a class="phone" href="tel:908-387-9463">
#           <span class="fas fa-phone">
#           </span>
#           908-387-9463
#          </a>
#          <div class="directions">
#           <a href="/directions/118">
#            <span class="fas fa-map-marker-alt">
#            </span>
#            Directions
#           </a>
#          </div>
#         </address>
#        </div>
#        <div class="store-hours">
#         <strong>
#          Hours
#         </strong>
#         <br>
#          Mon - Sat: 9am - 10pm
#          <br/>
#          Sun: 9am - 9pm
#          <br/>
#          <p>
#           <br/>
#          </p>
#         </br>
#        </div>
#        <h5 class="mt-3">
#         <a href="/locations">
#          View all locations
#         </a>
#        </h5>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="security-and-payments">
#      <div class="row">
#       <div class="col col-sm-6">
#       </div>
#       <div class="col-12 col-sm-6 text-right">
#        <div class="d-flex flex-row-reverse">
#         <i class="fab fa-cc-visa fa-3x ml-2 text-muted">
#         </i>
#         <i class="fab fa-cc-mastercard fa-3x ml-2 text-muted">
#         </i>
#         <i class="fab fa-cc-amex fa-3x ml-2 text-muted">
#         </i>
#         <i class="fab fa-cc-discover fa-3x ml-2 text-muted">
#         </i>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="d-flex justify-content-between mb-3 align-items-start copyright-and-credit">
#      <div class="copyright">
#       <div class="copyright">
#        <div>
#         © Copyright 2020
#        </div>
#        <address>
#         <div class="company">
#          Bourbon Street Wine &amp; Spirits
#         </div>
#         <div class="street-address">
#          1217 Route 22 West
#         </div>
#         <div class="city-state-zip">
#          <span class="city">
#           Phillipsburg
#          </span>
#          <span class="state">
#           NJ
#          </span>
#          <span class="zip">
#           08865
#          </span>
#         </div>
#         <a class="phone" href="tel:908-387-9463">
#          <span class="fas fa-phone">
#          </span>
#          908-387-9463
#         </a>
#        </address>
#       </div>
#      </div>
#      <div class="text-right">
#       Powered by
#       <a href="https://www.bottlenose.wine/">
#        Bottlenose
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script type="text/javascript">
#    document.addEventListener('DOMContentLoaded',function(){imgix.init({srcAttribute:'data-src',srcsetAttribute:'data-srcset',sizesAttribute:'data-sizes'});jQuery('img[data-srcset]').addClass('lazyload');function update_search_view(search_view){if(search_view){jQuery("#product-list").data("product-list-view",search_view)}else{search_view=jQuery("#product-list").data("product-list-view");}jQuery.ajax({url:'/set-session',method:'POST',data:{search_view:search_view}}).fail(function(xhr,status,error){document.open();document.write(xhr.responseText);document.close();});var $products=jQuery("#product-list");if(search_view=="list"){$products.removeClass('grid row-cols-md-3').addClass('list');}else{$products.removeClass('list').addClass('grid row-cols-md-3');}}if(jQuery("#product-list-view-buttons").length>0){update_search_view();}jQuery("#grid").click(function(event){update_search_view("grid");});jQuery("#list").click(function(event){update_search_view("list");});jQuery("#search-header select[name='sort']").change(function(){window.location.href=jQuery("#search").data("base-url")+"/sort/"+jQuery(this).val();});jQuery("select[name='result_size']").change(function(){window.location.href=jQuery("#search").data("base-url")+"/result_size/"+jQuery(this).val();});gtag('event','view_item_list',{"items":[{"id":"11390","name":"14 Hands Chardonnay","brand":"14 Hands","category":"Wine/White Wine","list_name":"White Wine","quantity":1,"price":10.99},{"id":"18062","name":"90+ Cellars Lot 130 Chardonnay  ","brand":"90+ Cellars","category":"Wine/White Wine","list_name":"White Wine","list_position":1,"quantity":1,"price":16.99},{"id":"22060","name":"90+ Cellars Lot 152 Chardonnay  ","brand":"90+ Cellars","category":"Wine/White Wine","list_name":"White Wine","list_position":2,"quantity":1,"price":9.99},{"id":"22069","name":"90+ Cellars Lot 153 Sauvignon Blanc Vin Du France","brand":"90+ Cellars","category":"Wine/White Wine","list_name":"White Wine","list_position":3,"quantity":1,"price":9.99},{"id":"16322","name":"90+ Cellars Lot 166 Sauvignon Blanc  ","brand":"90+ Cellars","category":"Wine/White Wine","list_name":"White Wine","list_position":4,"quantity":1,"price":9.99},{"id":"8185","name":"90+ Cellars Lot 2 Sauvignon Blanc  ","brand":"90+ Cellars","category":"Wine/White Wine","list_name":"White Wine","list_position":5,"quantity":1,"price":9.99},{"id":"17340","name":"90+ Cellars Lot 42 Pinot Grigio  ","brand":"90+ Cellars","category":"Wine/White Wine","list_name":"White Wine","list_position":6,"quantity":1,"price":9.99},{"id":"18457","name":"90+ Cellars Lot 66 Riesling  ","brand":"90+ Cellars","category":"Wine/White Wine","list_name":"White Wine","list_position":7,"quantity":1,"price":9.99},{"id":"5000","name":"Alba Vineyard Riesling","brand":"Alba Vineyard","category":"Wine/White Wine","list_name":"White Wine","list_position":8,"quantity":1,"price":13.99},{"id":"19052","name":"Bliss Chardonnay","brand":"Bliss","category":"Wine/White Wine","list_name":"White Wine","list_position":9,"quantity":1,"price":12.99},{"id":"19054","name":"Bliss Sauvignon Blanc","brand":"Bliss","category":"Wine/White Wine","list_name":"White Wine","list_position":10,"quantity":1,"price":12.99},{"id":"1685","name":"Bogle Chardonnay  ","brand":"Bogle","category":"Wine/White Wine","list_name":"White Wine","list_position":11,"quantity":1,"price":10.99},{"id":"5176","name":"Concha y Toro Casillero Del Diablo Sauvignon Blanc  ","brand":"Concha y Toro","category":"Wine/White Wine","list_name":"White Wine","list_position":12,"quantity":1,"price":9.99},{"id":"5177","name":"Concha y Toro Casillero del Diablo Chardonnay  ","brand":"Concha y Toro","category":"Wine/White Wine","list_name":"White Wine","list_position":13,"quantity":1,"price":9.99},{"id":"15253","name":"Cupcake Chardonnay","brand":"Cupcake","category":"Wine/White Wine","list_name":"White Wine","list_position":14,"quantity":1,"price":9.99},{"id":"14698","name":"Cupcake Pinot Grigio","brand":"Cupcake","category":"Wine/White Wi ...
#   </script>
#   <div class="modal fade" id="age-verify" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-dialog-centered">
#     <div class="modal-content">
#      <div class="modal-header brand-background">
#       <img class="img-fluid ml-auto mr-auto" ix-src="https://icdn.bottlenose.wine/bourbonstreetwineandspirits.com/logo.png" sizes="(min-width: 768px) 255px, 90vw"/>
#      </div>
#      <div class="modal-body">
#       <h1>
#        Are you 21 years old, or older?
#       </h1>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary" id="age_verified" type="button">
#        Yes
#       </button>
#       <a class="btn btn-default" href="http://lmgtfy.com/?q=sparkling+juice">
#        No
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    document.addEventListener('DOMContentLoaded',function(){var $age_verify=jQuery('#age-verify');if($age_verify.length){jQuery.ajax({method:'GET',url:'/get-session/age_verified'}).fail(function(data){$age_verify.modal({show:true,backdrop:'static',keyboard:false});});$age_verify.find('#age_verified').on('click',function(){$age_verify.modal('hide');jQuery.ajax({url:'/set-session',method:'POST',data:{'age_verified':1}}).fail(function(xhr,status,error){document.open();document.write(xhr.responseText);document.close();});});}});
#   </script>
#  </body>
# </html>

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
url = "https://www.bourbonstreetwineandspirits.com/search/categories/Wine/sort/title%20asc/categories/White%20Wine/result_size/25"
browser.visit(url)
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\palak\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache

# %%
wine_list = []
wine = {}

html = browser.html
soup = BeautifulSoup(html, 'html.parser')

links=soup.find_all('a', class_='product-link')
for link in links:
    urls= 'https://www.bourbonstreetwineandspirits.com'+(link.get('href'))
    #print(urls)
    #for detail_url in urls:
     #   print (detail_url)
    detail_html=urlopen(urls)
    soup_detail = BeautifulSoup(detail_html, 'lxml')
    #print(soup_detail)
    details= soup_detail.find_all(class_={'product-name mb-0','btn btn-outline-primary btn-block update-quantity-input', 'row bg-light py-3 mb-3'})
    #print(details)
             
    name = soup_detail.find('h1', class_="product-name").text        
    #print(name)

    try:
        price = soup_detail.find('button', class_="btn btn-outline-primary btn-block update-quantity-input")["data-price"]
    except TypeError:
        price = "N/A"
    #print(price)
    
    region = soup_detail.find("table").find_all('a')[3].text
    #print(region)
    
    wine_type = soup_detail.find("table").find_all('a')[0].text
    #print(wine_type)
    
    varietal = soup_detail.find("table").find_all('a')[1].text
    #print(varietal)
    
    country = soup_detail.find("table").find_all('a')[2].text
    #print(country)
    
    merchant = "bourbon Street Wine and Spirits"
    address = "1217 Route 22 West, Phillipsburg NJ 08865"
    
    wine={
        "name":name,
        "price":price,
        "region":region,
        "wine_type":wine_type,
        "varietal":varietal,
        "country":country,
        "merchant":merchant,
        "address":address
    }
    
    wine_list.append(wine)

wine_list
# Out:
# [{'name': '14 Hands Chardonnay',
#   'price': '10.99',
#   'region': 'Washington',
#   'wine_type': 'White Wine',
#   'varietal': 'Chardonnay',
#   'country': 'United States',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': '90+ Cellars Lot 130 Chardonnay ',
#   'price': '16.99',
#   'region': 'Sonoma County',
#   'wine_type': 'White Wine',
#   'varietal': 'Chardonnay',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': '90+ Cellars Lot 152 Chardonnay ',
#   'price': '9.99',
#   'region': '90+ Cellars',
#   'wine_type': 'White Wine',
#   'varietal': 'Chardonnay',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': '90+ Cellars Lot 153 Sauvignon Blanc Vin Du France',
#   'price': '9.99',
#   'region': '90+ Cellars',
#   'wine_type': 'White Wine',
#   'varietal': 'Sauvignon Blanc',
#   'country': 'France',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': '90+ Cellars Lot 166 Sauvignon Blanc ',
#   'price': '9.99',
#   'region': '90+ Cellars',
#   'wine_type': 'White Wine',
#   'varietal': 'Sauvignon Blanc',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': '90+ Cellars Lot 2 Sauvignon Blanc ',
#   'price': '9.99',
#   'region': 'Marlborough',
#   'wine_type': 'White Wine',
#   'varietal': 'Sauvignon Blanc',
#   'country': 'New Zealand',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': '90+ Cellars Lot 42 Pinot Grigio ',
#   'price': '9.99',
#   'region': 'Trentino-Alto Adige',
#   'wine_type': 'White Wine',
#   'varietal': 'Pinot Grigio',
#   'country': 'Italy',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': '90+ Cellars Lot 66 Riesling ',
#   'price': '9.99',
#   'region': 'Mosel',
#   'wine_type': 'White Wine',
#   'varietal': 'Riesling',
#   'country': 'Germany',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Alba Vineyard Riesling',
#   'price': '13.99',
#   'region': 'New Jersey',
#   'wine_type': 'White Wine',
#   'varietal': 'Riesling',
#   'country': 'United States',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Bliss Chardonnay',
#   'price': '12.99',
#   'region': 'North Coast',
#   'wine_type': 'White Wine',
#   'varietal': 'Chardonnay',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Bliss Sauvignon Blanc',
#   'price': '12.99',
#   'region': 'North Coast',
#   'wine_type': 'White Wine',
#   'varietal': 'Sauvignon Blanc',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Bogle Chardonnay ',
#   'price': '10.99',
#   'region': 'Bogle',
#   'wine_type': 'White Wine',
#   'varietal': 'Chardonnay',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Concha y Toro Casillero Del Diablo Sauvignon Blanc ',
#   'price': '9.99',
#   'region': 'Concha y Toro',
#   'wine_type': 'White Wine',
#   'varietal': 'Chile',
#   'country': 'Casablanca Valley',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Concha y Toro Casillero del Diablo Chardonnay ',
#   'price': '9.99',
#   'region': 'Valle Central',
#   'wine_type': 'White Wine',
#   'varietal': 'Chardonnay',
#   'country': 'Chile',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Cupcake Chardonnay',
#   'price': '9.99',
#   'region': 'Central Coast',
#   'wine_type': 'White Wine',
#   'varietal': 'Chardonnay',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Cupcake Pinot Grigio',
#   'price': '9.99',
#   'region': 'Veneto',
#   'wine_type': 'White Wine',
#   'varietal': 'Pinot Grigio',
#   'country': 'Italy',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Cupcake Sauvignon Blanc',
#   'price': '9.99',
#   'region': 'Marlborough',
#   'wine_type': 'White Wine',
#   'varietal': 'Sauvignon Blanc',
#   'country': 'New Zealand',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Gnarly Head Chardonnay',
#   'price': '9.99',
#   'region': 'Central Coast',
#   'wine_type': 'White Wine',
#   'varietal': 'Chardonnay',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Gnarly Head Pinot Grigio',
#   'price': '9.99',
#   'region': 'Central Valley',
#   'wine_type': 'White Wine',
#   'varietal': 'Pinot Grigio',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Kim Crawford Sauvignon Blanc',
#   'price': '13.99',
#   'region': 'Marlborough',
#   'wine_type': 'White Wine',
#   'varietal': 'Sauvignon Blanc',
#   'country': 'New Zealand',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Nobilo Regional Collection Sauvignon Blanc',
#   'price': '11.99',
#   'region': 'Marlborough',
#   'wine_type': 'White Wine',
#   'varietal': 'Sauvignon Blanc',
#   'country': 'New Zealand',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Santa Martina Pinot Grigio',
#   'price': '9.99',
#   'region': 'Veneto',
#   'wine_type': 'White Wine',
#   'varietal': 'Pinot Grigio',
#   'country': 'Italy',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': "Sterling Vintner's Collection Pinot Grigio",
#   'price': '10.99',
#   'region': 'Central Coast',
#   'wine_type': 'White Wine',
#   'varietal': 'Pinot Grigio',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': "Sterling Vintner's Collection Sauvignon Blanc",
#   'price': '10.99',
#   'region': 'Central Coast',
#   'wine_type': 'White Wine',
#   'varietal': 'Sauvignon Blanc',
#   'country': 'California',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'},
#  {'name': 'Valenzano Shamong White',
#   'price': '9.99',
#   'region': 'New Jersey',
#   'wine_type': 'White Wine',
#   'varietal': 'Niagara',
#   'country': 'United States',
#   'merchant': 'bourbon Street Wine and Spirits',
#   'address': '1217 Route 22 West, Phillipsburg NJ 08865'}]
