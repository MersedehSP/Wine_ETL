# %%
#Dependencies
import pandas as pd
import requests
import json
import datetime
import numpy as np

# %%
file_path = "chathambuyrite.csv"
wine_df = pd.read_csv(file_path, encoding='ISO-8859-1')
wine_df.head(25)
# Out:
#     Unnamed: 0    sku                                          name  \
# 0            0  39759                  Kim Crawford Sauvignon Blanc
# 1            1  55121                            Twisted Chardonnay
# 2            2  64910                     Long Barn Pinot Noir 2018
# 3            3  30380                    Oyster Bay Sauvignon Blanc
# 4            4  69211                          Josh Sauvignon Blanc
# 5            5  21016                            Cavit Pinot Grigio
# 6            6  70412                             Butter Chardonnay
# 7            7  20566  Kendall-Jackson Vintner's Reserve Chardonnay
# 8            8  54614                       Josh Cabernet Sauvignon
# 9            9  32576               Santa Silvana Pinot Grigio 2019
# 10          10  45495              Deloach Central Coast Pinot Noir
# 11          11  20537                    Bogle Vineyards Chardonnay
# 12          12  22138              Frei Brothers Cabernet Sauvignon
# ...

# %%
wine_df = wine_df.reset_index()

# %%
wine_df
# Out:
#       index  Unnamed: 0    sku                           name bottlesize  \
# 0         0           0  39759   Kim Crawford Sauvignon Blanc      750ML
# 1         1           1  55121             Twisted Chardonnay      750ML
# 2         2           2  64910      Long Barn Pinot Noir 2018      750ML
# 3         3           3  30380     Oyster Bay Sauvignon Blanc      750ML
# 4         4           4  69211           Josh Sauvignon Blanc      750ML
# ...     ...         ...    ...                            ...        ...
# 2100   2100        2100  73376           La Bete Noire Cahors      750ML
# 2101   2101        2101  73399                El Nido El Nido      750ML
# 2102   2102        2102  73469               Champy Echezeaux      750ML
# 2103   2103        2103  73470       Champy Volnay Taillpieds      750ML
# 2104   2104        2104  73507  Haut Brion Rouge Pess Leog 15      750ML
#
#       regprice saleprice                                        description  \
# ...
