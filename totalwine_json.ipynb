# %%
import requests
import json
import pandas as pd
import time

# %%
url = "https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page=1&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&batch=true&_br_uid_2=uid%3D711505870994%3Av%3D12.0%3Ats%3D1606923004355%3Ahc%3D2"

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}
response = requests.get(url, headers=headers)
response
#Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36
#print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# <Response [200]>

# %%
data = response.json()
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "autoCorrect": {},
#     "categoryBreadcrumbs": [
#         {
#             "categoryCode": "c0020",
#             "name": "Wine",
#             "url": "/Wine/c/c0020"
#         }
#     ],
#     "categoryName": "c0020",
#     "facets": [
#         {
#             "id": "price",
#             "multiSelect": true,
#             "name": "Price Range",
#             "priority": 9999,
#             "values": [
#                 {
#                     "count": 1183,
#                     "id": "up-to-10",
#                     "name": "Up to $10",
#                     "priority": 1,
#                     "selected": false
#                 },
#                 {
#                     "count": 3031,
#                     "id": "-10-to-20",
#                     "name": "$10 to $20",
#                     "priority": 2,
#                     "selected": false
#                 },
#                 {
#                     "count": 1034,
#                     "id": "-20-to-30",
#                     "name": "$20 to $30",
#                     "priority": 3,
#                     "selected": false
#                 },
#                 {
#                     "count": 565,
#                     "id": "-30-to-40",
#                     "name": "$30 to $40",
#                     "priority": 4,
#                     "selected": false
#                 },
#                 {
#                     "count": 407,
#                     "id": "-40-to-50",
#                     "name": "$40 to $50",
#                     "priority": 5,
#                     "selected": false
#                 },
#                 {
#                     "count": 2191,
#                     "id": "-50-above",
#                     "name": "$50 and Above",
#                     "priority": 6,
#                     "selected": false
#                 }
#             ]
#         },
#         {
#             "id": "brand",
#             "multiSelect": true,
#             "name": "Brand",
#             "priority": 9998,
#             "values": [
#                 {
#                     "count": 84,
#                     "id": "Barefoot",
#                     "name": "Barefoot",
#                     "priority": 1,
#                     "selected": false
#                 },
#                 {
#                     "count": 39,
#                     "id": "Beringer",
#                     "name": "Beringer",
#                     "priority": 2,
#                     "selected": false
#                 },
#                 {
#                     "count": 38,
#                     "id": "Yellow Tail",
#                     "name": "Yellow Tail",
#                     "priority": 3,
#                     "selected": false
#                 },
#                 {
#                     "count": 37,
#                     "id": "Chapoutier",
#                     "name": "Chapoutier",
#                     "priority": 4,
#                     "selected": false
#                 },
#                 {
#                     "count": 37,
#                     "id": "Sutter Home",
#                     "name": "Sutter Home",
#                     "priority": 5,
#                     "selected": false
#                 },
#                 {
#                     "count": 35,
#                     "id": "Gaja",
#                     "name": "Gaja",
#                     "priority": 6,
#                     "selected": false
#                 },
#                 {
#                     "count": 33,
#                     "id": "Stella Rosa",
#                     "name": "Stella Rosa",
#                     "priority": 7,
#                     "selected": false
#                 },
#                 {
#                     "count": 30,
#                     "id": "Franzia",
#                     "name": "Franzia",
#                     "priority": 8,
#                     "selected": false
#                 },
#                 {
#                     "count": 29,
#                     "id": "Chateau Ste. Michelle",
#                     "name": "Chateau Ste. Michelle",
#                     "priority": 9,
#                     "selected": false
#                 },
#                 {
#                     "count": 29,
#                     "id": "Delas",
#                     "name": "Delas",
#                     "priority": 10,
#                     "selected": false
#                 },
#                 {
#                     "count": 28,
#                     "id": "Coppola",
#                     "name": "Coppola",
#                     "priority": 11,
#                     "selected": false
#                 },
#                 {
#                     "count": 27,
#                     "id": "Big Sipper",
#                     "name": "Big Sipper",
#                     "priority": 12,
#                     "selected": false
#                 },
#                 {
#                     "count": 27,
#                     "id": "Quinta das Carvalhas",
#                     "name": "Quinta das Carvalhas",
#                     "priority": 13,
#                     "selected": false
#                 },
#                 {
#                     "count": 26,
#                     "id": "Duckhorn",
#                     "name": "Duckhorn",
#                     "priority": 14,
#                     "selected": false
#                 },
#                 {
#                     "count": 24,
#                     "id": "Martin Ray",
#                     "name": "Martin Ray",
#                     "priority": 15,
#                     "selected": false
#                 },
#                 {
#                     "count": 23,
#                     "id": "Bota Box",
#                     "name": "Bota Box",
#                     "priority": 16,
#                     "selected": false
#                 },
#                 {
#                     "count": 23,
#                     "id": "Woodbridge",
#                     "name": "Woodbridge",
#                     "priority": 17,
#                     "selected": false
#                 },
#                 {
#                     "count": 22,
#                     "id": "Mascota Vineyards",
#                     "name": "Mascota Vineyards",
#                     "priority": 18,
#                     "selected": false
#                 },
#                 {
#                     "count": 22,
#                     "id": "Paul Hobbs",
#                     "name": "Paul Hobbs",
#                     "priority": 19,
#                     "selected": false
#                 },
#                 {
#                     "count": 21,
#                     "id": "Bellini",
#                     "name": "Bellini",
#                     "priority": 20,
#                     "selected": false
#                 },
#                 {
#                     "count": 21,
#                     "id": "Carlo Rossi",
#                     "name": "Carlo Rossi",
#                     "priority": 21,
#                     "selected": false
#                 },
#                 {
#                     "count": 21,
#                     "id": "Concha Y Toro",
#                     "name": "Concha Y Toro",
#                     "priority": 22,
#                     "selected": false
#                 },
#                 {
#                     "count": 21,
#                     "id": "Gallo Family Vineyards",
#                     "name": "Gallo Family Vineyards",
#                     "priority": 23,
#                     "selected": false
#                 },
#                 {
#                     "count": 20,
#                     "id": "Albino Armani",
#                     "name": "Albino Armani",
#                     "priority": 24,
#                     "selected": false
#                 },
#                 {
#                     "count": 20,
#                     "id": "Au Pied du Mont Chauve",
#                     "name": "Au Pied du Mont Chauve",
#                     "priority": 25,
#                     "selected": false
#                 },
#                 {
#                     "count": 20,
#                     "id": "Canyon Oaks",
#                     "name": "Canyon Oaks",
#                     "priority": 26,
#                     "selected": false
#                 },
#                 {
#                     "count": 20,
#                     "id": "Cupcake",
#                     "name": "Cupcake",
#                     "priority": 27,
#                     "selected": false
#                 },
#                 {
#                     "count": 20,
#                     "id": "Jean-Claude Debeaune",
#                     "name": "Jean-Claude Debeaune",
#                     "priority": 28,
#                     "selected": false
#                 },
#                 {
#                     "count": 20,
#                     "id": "Pio Cesare",
#                     "name": "Pio Cesare",
#                     "priority": 29,
#                     "selected": false
#                 },
#                 {
#                     "count": 20,
#                     "id": "Valenzano",
#                     "name": "Valenzano",
#                     "priority": 30,
#                     "selected": false
#                 },
#                 {
#                     "count": 19,
#                     "id": "Louis Jadot",
#                     "name": "Louis Jadot",
#                     "priority": 31,
#                     "selected": false
#                 },
#                 {
#                     "count": 19,
#                     "id": "Menage a Trois",
#                     "name": "Menage a Trois",
#                     "priority": 32,
#                     "selected": false
#                 },
#                 {
#                     "count": 18,
#                     "id": "Amici",
#                     "name": "Amici",
#                     "priority": 33,
#                     "selected": false
#                 },
#                 {
#                     "count": 18,
#                     "id": "Famille Bougrier",
#                     "name": "Famille Bougrier",
#                     "priority": 34,
#                     "selected": false
#                 },
#                 {
#                     "count": 18,
#                     "id": "Josh Cellars",
#                     "name": "Josh Cellars",
#                     "priority": 35,
#                     "selected": false
#                 },
#                 {
#                     "count": 18,
#                     "id": "Mailly",
#                     "name": "Mailly",
#                     "priority": 36,
#                     "selected": false
#                 },
#                 {
#                     "count": 18,
#                     "id": "Ruffino",
#                     "name": "Ruffino",
#                     "priority": 37,
#                     "selected": false
#                 },
#                 {
#                     "count": 18,
#                     "id": "Sandrone",
#                     "name": "Sandrone",
#                     "priority": 38,
#                     "selected": false
#                 },
#                 {
#                     "count": 17,
#                     "id": "Black Box",
#                     "name": "Black Box",
#                     "priority": 39,
#                     "selected": false
#                 },
#                 {
#                     "count": 17,
#                     "id": "Dr Heidemanns-Bergweiler",
#                     "name": "Dr Heidemanns-Bergweiler",
#                     "priority": 40,
#                     "selected": false
#                 },
#                 {
#                     "count": 17,
#                     "id": "Spier",
#                     "name": "Spier",
#                     "priority": 41,
#                     "selected": false
#                 },
#                 {
#                     "count": 16,
#                     "id": "Baron Herzog",
#                     "name": "Baron Herzog",
#                     "priority": 42,
#                     "selected": false
#                 },
#                 {
#                     "count": 16,
#                     "id": "Joto",
#                     "name": "Joto",
#                     "priority": 43,
#                     "selected": false
#                 },
#                 {
#                     "count": 16,
#                     "id": "Oak Grove",
#                     "name": "Oak Grove",
#                     "priority": 44,
#                     "selected": false
#                 },
#                 {
#                     "count": 16,
#                     "id": "Porta",
#                     "name": "Porta",
#                     "priority": 45,
#                     "selected": false
#                 },
#                 {
#                     "count": 16,
#                     "id": "Taylor Fladgate",
#                     "name": "Taylor Fladgate",
#                     "priority": 46,
#                     "selected": false
#                 },
#                 {
#                     "count": 16,
#                     "id": "Vistamar",
#                     "name": "Vistamar",
#                     "priority": 47,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Banfi",
#                     "name": "Banfi",
#                     "priority": 48,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Capriccio",
#                     "name": "Capriccio",
#                     "priority": 49,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Chateau D'Yquem",
#                     "name": "Chateau D'Yquem",
#                     "priority": 50,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Cloud Break",
#                     "name": "Cloud Break",
#                     "priority": 51,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "De Venoge",
#                     "name": "De Venoge",
#                     "priority": 52,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Manischewitz",
#                     "name": "Manischewitz",
#                     "priority": 53,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Montresor",
#                     "name": "Montresor",
#                     "priority": 54,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Robert Mondavi Private Selection",
#                     "name": "Robert Mondavi Private Selection",
#                     "priority": 55,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Ropiteau",
#                     "name": "Ropiteau",
#                     "priority": 56,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Vega Sicilia",
#                     "name": "Vega Sicilia",
#                     "priority": 57,
#                     "selected": false
#                 },
#                 {
#                     "count": 15,
#                     "id": "Williams-Selyem",
#                     "name": "Williams-Selyem",
#                     "priority": 58,
#                     "selected": false
#                 },
#                 {
#                     "count": 14,
#                     "id": "Anne de K",
#                     "name": "Anne de K",
#                     "priority": 59,
#                     "selected": false
#                 },
#                 {
#                     "count": 14,
#                     "id": "Antinori",
#                     "name": "Antinori",
#                     "priority": 60,
#                     "selected": false
#                 },
#                 {
#                     "count": 14,
#                     "id": "Cavit",
#                     "name": "Cavit",
#                     "priority": 61,
#                     "selected": false
#                 },
#                 {
#                     "count": 14,
#                     "id": "Courtney Benham",
#                     "name": "Courtney Benham",
#                     "priority": 62,
#                     "selected": false
#                 },
#                 {
#                     "count": 14,
#                     "id": "Kendall Jackson",
#                     "name": "Kendall Jackson",
#                     "priority": 63,
#                     "selected": false
#                 },
#                 {
#                     "count": 14,
#                     "id": "Korbel",
#                     "name": "Korbel",
#                     "priority": 64,
#                     "selected": false
#                 },
#                 {
#                     "count": 14,
#                     "id": "Mauro Sebaste",
#                     "name": "Mauro Sebaste",
#                     "priority": 65,
#                     "selected": false
#                 },
#                 {
#                     "count": 14,
#                     "id": "Mendoza Station",
#                     "name": "Mendoza Station",
#                     "priority": 66,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "Bogle",
#                     "name": "Bogle",
#                     "priority": 67,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "Columbia Crest",
#                     "name": "Columbia Crest",
#                     "priority": 68,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "Graham's",
#                     "name": "Graham's",
#                     "priority": 69,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "Louis Latour",
#                     "name": "Louis Latour",
#                     "priority": 70,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "Luc Pirlet",
#                     "name": "Luc Pirlet",
#                     "priority": 71,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "Phebus",
#                     "name": "Phebus",
#                     "priority": 72,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "River Road",
#                     "name": "River Road",
#                     "priority": 73,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "Stag's Leap",
#                     "name": "Stag's Leap",
#                     "priority": 74,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "The Prisoner Wine Company",
#                     "name": "The Prisoner Wine Company",
#                     "priority": 75,
#                     "selected": false
#                 },
#                 {
#                     "count": 13,
#                     "id": "Verdi",
#                     "name": "Verdi",
#                     "priority": 76,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "19 Crimes",
#                     "name": "19 Crimes",
#                     "priority": 77,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Anakena",
#                     "name": "Anakena",
#                     "priority": 78,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Angeline",
#                     "name": "Angeline",
#                     "priority": 79,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Barkan Classic",
#                     "name": "Barkan Classic",
#                     "priority": 80,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Billecart Salmon",
#                     "name": "Billecart Salmon",
#                     "priority": 81,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Chateau Haut Brion",
#                     "name": "Chateau Haut Brion",
#                     "priority": 82,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Chateau Los Boldos",
#                     "name": "Chateau Los Boldos",
#                     "priority": 83,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Chateau Mouton Rothschild",
#                     "name": "Chateau Mouton Rothschild",
#                     "priority": 84,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Dark Horse",
#                     "name": "Dark Horse",
#                     "priority": 85,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Hess",
#                     "name": "Hess",
#                     "priority": 86,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Layer Cake",
#                     "name": "Layer Cake",
#                     "priority": 87,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Mauro Veglio",
#                     "name": "Mauro Veglio",
#                     "priority": 88,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Nickel & Nickel",
#                     "name": "Nickel & Nickel",
#                     "priority": 89,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Penfolds",
#                     "name": "Penfolds",
#                     "priority": 90,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Peter Vella",
#                     "name": "Peter Vella",
#                     "priority": 91,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Reserve St Martin",
#                     "name": "Reserve St Martin",
#                     "priority": 92,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Rodney Strong",
#                     "name": "Rodney Strong",
#                     "priority": 93,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Sobon",
#                     "name": "Sobon",
#                     "priority": 94,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Tsarine",
#                     "name": "Tsarine",
#                     "priority": 95,
#                     "selected": false
#                 },
#                 {
#                     "count": 12,
#                     "id": "Valdicava",
#                     "name": "Valdicava",
#                     "priority": 96,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Baldacci",
#                     "name": "Baldacci",
#                     "priority": 97,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Chateau La Mission Haut Brion",
#                     "name": "Chateau La Mission Haut Brion",
#                     "priority": 98,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Clos Saint Michel",
#                     "name": "Clos Saint Michel",
#                     "priority": 99,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Clos du Bois",
#                     "name": "Clos du Bois",
#                     "priority": 100,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Cruz Alta",
#                     "name": "Cruz Alta",
#                     "priority": 101,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "D'Autrefois",
#                     "name": "D'Autrefois",
#                     "priority": 102,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Firebrand",
#                     "name": "Firebrand",
#                     "priority": 103,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "House Wine",
#                     "name": "House Wine",
#                     "priority": 104,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "J Lohr",
#                     "name": "J Lohr",
#                     "priority": 105,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Joseph Drouhin",
#                     "name": "Joseph Drouhin",
#                     "priority": 106,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Lindemans",
#                     "name": "Lindemans",
#                     "priority": 107,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Mallee Point",
#                     "name": "Mallee Point",
#                     "priority": 108,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Moone Tsai",
#                     "name": "Moone Tsai",
#                     "priority": 109,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Patrick Javillier",
#                     "name": "Patrick Javillier",
#                     "priority": 110,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Renieri",
#                     "name": "Renieri",
#                     "priority": 111,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Robert Mondavi",
#                     "name": "Robert Mondavi",
#                     "priority": 112,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Sheridan",
#                     "name": "Sheridan",
#                     "priority": 113,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Sterling",
#                     "name": "Sterling",
#                     "priority": 114,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Valserrano",
#                     "name": "Valserrano",
#                     "priority": 115,
#                     "selected": false
#                 },
#                 {
#                     "count": 11,
#                     "id": "Veuve Clicquot",
#                     "name": "Veuve Clicquot",
#                     "priority": 116,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Bartenura",
#                     "name": "Bartenura",
#                     "priority": 117,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Catena",
#                     "name": "Catena",
#                     "priority": 118,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Chalk Hill",
#                     "name": "Chalk Hill",
#                     "priority": 119,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Chateau Pichon Baron",
#                     "name": "Chateau Pichon Baron",
#                     "priority": 120,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Conte Priola",
#                     "name": "Conte Priola",
#                     "priority": 121,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Domaine Chevillon Chezeaux",
#                     "name": "Domaine Chevillon Chezeaux",
#                     "priority": 122,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "E. Guigal",
#                     "name": "E. Guigal",
#                     "priority": 123,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Fontodi",
#                     "name": "Fontodi",
#                     "priority": 124,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Hectare",
#                     "name": "Hectare",
#                     "priority": 125,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Iter",
#                     "name": "Iter",
#                     "priority": 126,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Joseph Phelps",
#                     "name": "Joseph Phelps",
#                     "priority": 127,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "K Vintners",
#                     "name": "K Vintners",
#                     "priority": 128,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "La Crema",
#                     "name": "La Crema",
#                     "priority": 129,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Liberty Creek",
#                     "name": "Liberty Creek",
#                     "priority": 130,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Livingston Cellars",
#                     "name": "Livingston Cellars",
#                     "priority": 131,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Louis Bouillot",
#                     "name": "Louis Bouillot",
#                     "priority": 132,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Mondavi",
#                     "name": "Mondavi",
#                     "priority": 133,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Pacific Peak",
#                     "name": "Pacific Peak",
#                     "priority": 134,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Ramey",
#                     "name": "Ramey",
#                     "priority": 135,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Ridge",
#                     "name": "Ridge",
#                     "priority": 136,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Sandeman",
#                     "name": "Sandeman",
#                     "priority": 137,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Tesoro della Regina",
#                     "name": "Tesoro della Regina",
#                     "priority": 138,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Turning Leaf",
#                     "name": "Turning Leaf",
#                     "priority": 139,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Wagner",
#                     "name": "Wagner",
#                     "priority": 140,
#                     "selected": false
#                 },
#                 {
#                     "count": 10,
#                     "id": "Yalumba",
#                     "name": "Yalumba",
#                     "priority": 141,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Almaden",
#                     "name": "Almaden",
#                     "priority": 142,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Bevan cellars",
#                     "name": "Bevan cellars",
#                     "priority": 143,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Bolla",
#                     "name": "Bolla",
#                     "priority": 144,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Canalicchio Sopra",
#                     "name": "Canalicchio Sopra",
#                     "priority": 145,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Casa Sant Orsola",
#                     "name": "Casa Sant Orsola",
#                     "priority": 146,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Champagne Lallier",
#                     "name": "Champagne Lallier",
#                     "priority": 147,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Chateau Cheval Blanc",
#                     "name": "Chateau Cheval Blanc",
#                     "priority": 148,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Chateau Cos D'Estournel",
#                     "name": "Chateau Cos D'Estournel",
#                     "priority": 149,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Chateau Ducru Beaucaillou",
#                     "name": "Chateau Ducru Beaucaillou",
#                     "priority": 150,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Chateau La Conseillante",
#                     "name": "Chateau La Conseillante",
#                     "priority": 151,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Chateau Lafite Rothschild",
#                     "name": "Chateau Lafite Rothschild",
#                     "priority": 152,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Chateau Leoville Las Cases",
#                     "name": "Chateau Leoville Las Cases",
#                     "priority": 153,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Chateau Pape Clement",
#                     "name": "Chateau Pape Clement",
#                     "priority": 154,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Domaine Julie Belland",
#                     "name": "Domaine Julie Belland",
#                     "priority": 155,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Dow's",
#                     "name": "Dow's",
#                     "priority": 156,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Ferrari-Carano",
#                     "name": "Ferrari-Carano",
#                     "priority": 157,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Frank Family",
#                     "name": "Frank Family",
#                     "priority": 158,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Freixenet",
#                     "name": "Freixenet",
#                     "priority": 159,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Hermes",
#                     "name": "Hermes",
#                     "priority": 160,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "J Vineyards",
#                     "name": "J Vineyards",
#                     "priority": 161,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "La Vieille Ferme",
#                     "name": "La Vieille Ferme",
#                     "priority": 162,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Matrot",
#                     "name": "Matrot",
#                     "priority": 163,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Mollydooker",
#                     "name": "Mollydooker",
#                     "priority": 164,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Orin Swift",
#                     "name": "Orin Swift",
#                     "priority": 165,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Osborne",
#                     "name": "Osborne",
#                     "priority": 166,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Papi",
#                     "name": "Papi",
#                     "priority": 167,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Rivata",
#                     "name": "Rivata",
#                     "priority": 168,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Rocca Felice",
#                     "name": "Rocca Felice",
#                     "priority": 169,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Saladini Pilastri",
#                     "name": "Saladini Pilastri",
#                     "priority": 170,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Teperberg",
#                     "name": "Teperberg",
#                     "priority": 171,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "The Calling",
#                     "name": "The Calling",
#                     "priority": 172,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Two Hands",
#                     "name": "Two Hands",
#                     "priority": 173,
#                     "selected": false
#                 },
#                 {
#                     "count": 9,
#                     "id": "Winzer Krems",
#                     "name": "Winzer Krems",
#                     "priority": 174,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Amalthea Winery",
#                     "name": "Amalthea Winery",
#                     "priority": 175,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Andre",
#                     "name": "Andre",
#                     "priority": 176,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Apothic",
#                     "name": "Apothic",
#                     "priority": 177,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Arbor Mist",
#                     "name": "Arbor Mist",
#                     "priority": 178,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Arraigo Benegas",
#                     "name": "Arraigo Benegas",
#                     "priority": 179,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Beaulieu Vineyards",
#                     "name": "Beaulieu Vineyards",
#                     "priority": 180,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Beso Del Sol",
#                     "name": "Beso Del Sol",
#                     "priority": 181,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Cardiff",
#                     "name": "Cardiff",
#                     "priority": 182,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Caymus",
#                     "name": "Caymus",
#                     "priority": 183,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Charles Smith",
#                     "name": "Charles Smith",
#                     "priority": 184,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Chateau Giscours",
#                     "name": "Chateau Giscours",
#                     "priority": 185,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Corbett Canyon",
#                     "name": "Corbett Canyon",
#                     "priority": 186,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Donnachiara",
#                     "name": "Donnachiara",
#                     "priority": 187,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Federalist",
#                     "name": "Federalist",
#                     "priority": 188,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Fonseca",
#                     "name": "Fonseca",
#                     "priority": 189,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Gambino",
#                     "name": "Gambino",
#                     "priority": 190,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Gnarly Head",
#                     "name": "Gnarly Head",
#                     "priority": 191,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Hakutsuru",
#                     "name": "Hakutsuru",
#                     "priority": 192,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Hansel",
#                     "name": "Hansel",
#                     "priority": 193,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Joel Gott",
#                     "name": "Joel Gott",
#                     "priority": 194,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "La Delizia",
#                     "name": "La Delizia",
#                     "priority": 195,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Latitud 42",
#                     "name": "Latitud 42",
#                     "priority": 196,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Low Hanging Fruit",
#                     "name": "Low Hanging Fruit",
#                     "priority": 197,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Montaudon",
#                     "name": "Montaudon",
#                     "priority": 198,
#                     "selected": false
#                 },
#                 {
#                     "count": 8,
#                     "id": "Offley",
#                     "name": "Offley",
#                     "priority": 199,
#                     "selected": false
#                 }
#             ]
#         },
#         {
#             "id": "varietaltype",
#             "multiSelect": true,
#             "name": "Varietal & Type",
#             "priority": 9997,
#             "values": [
#                 {
#                     "count": 1221,
#                     "id": "Cabernet Sauvignon",
#                     "name": "Cabernet Sauvignon",
#                     "priority": 1,
#                     "selected": false
#                 },
#                 {
#                     "count": 804,
# ...
#                     "type": "MIXSIX"
#                 }
#             ],
#             "productUrl": "/wine/deals/red-wine/pinot-noir/kudos-pinot-noir-willamette/p/107654750",
#             "rating": 0,
#             "review": "Willamette Valley, Oregon, US- Made from select vineyard sites, this is a handcrafted blend that celebrates the bounty of Oregon. This wine starts with the taste of bright cherry preserves followed by red plums, and ends with a complex and round finish. Enjoy with all kinds of food!",
#             "salesStrategy": {
#                 "name": "Winery Direct"
#             },
#             "shoppingOptions": [
#                 {
#                     "eligible": true,
#                     "location": "US-NJ",
#                     "selected": false,
#                     "type": "SHIPPING"
#                 },
#                 {
#                     "eligible": true,
#                     "location": "Cherry Hill, NJ",
#                     "selected": true,
#                     "type": "INSTORE_PICKUP"
#                 },
#                 {
#                     "eligible": true,
#                     "location": "Cherry Hill, NJ",
#                     "selected": false,
#                     "type": "DELIVERY"
#                 }
#             ],
#             "skuId": "107654750-1",
#             "stockLevel": [
#                 {
#                     "purchaseLimit": 6,
#                     "stock": 22
#                 }
#             ],
#             "storeDistance": 0.00023338888,
#             "storeId": "301",
#             "storeName": "Cherry Hill",
#             "transactional": true,
#             "type": "PRODUCT",
#             "volume": ""
#         },
#         {
#             "brand": {
#                 "id": "Wildhaven",
#                 "name": "Wildhaven"
#             },
#             "categories": [
#                 {
#                     "id": "000282",
#                     "name": "Columbia Valley",
#                     "storefrontUrl": "/wine/washington/columbia-valley/c/000282",
#                     "type": "REGION",
#                     "url": "https://www.totalwine.com/wine/washington/columbia-valley/c/000282"
#                 },
#                 {
#                     "id": "000009",
#                     "name": "Red Wine",
#                     "storefrontUrl": "/wine/red-wine/c/000009",
#                     "type": "PRODUCT_TYPE",
#                     "url": "https://www.totalwine.com/wine/red-wine/c/000009"
#                 },
#                 {
#                     "id": "000019",
#                     "name": "Merlot",
#                     "storefrontUrl": "/wine/red-wine/merlot/c/000019",
#                     "type": "VARIETAL_TYPE",
#                     "url": "https://www.totalwine.com/wine/red-wine/merlot/c/000019"
#                 }
#             ],
#             "containerType": "Bottle",
#             "customerAverageRating": 4.3,
#             "customerReviewsCount": 47,
#             "department": "c0020",
#             "directType": "Winery Direct",
#             "id": "123221750",
#             "images": [
#                 {
#                     "altText": "Wildhaven Merlot Columbia Valley",
#                     "imageType": "DEFAULT",
#                     "mobileOptimizedUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hd9/hef/13287139901470.png",
#                     "thumbnailUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hd9/hef/13287139901470.png",
#                     "url": "https://www.totalwine.com/media/sys_master/twmmedia/hd9/hef/13287139901470.png",
#                     "zoomImageUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hd9/hef/13287139901470.png"
#                 }
#             ],
#             "itemBody": "Medium-bodied",
#             "itemStyle": "Intense",
#             "itemTasteProfile": "Cherry, Blueberry, Cedar",
#             "name": "Wildhaven Merlot Columbia Valley",
#             "packageDescription": "750ml",
#             "packageValue": "Single",
#             "price": [
#                 {
#                     "price": 13.99,
#                     "type": "EDLP"
#                 },
#                 {
#                     "price": 12.59,
#                     "toolTip": "What is Mix 6? Receive a special discount when you buy six or more of any bottles with the Mix 6 tag! Savings automatically applied in cart.",
#                     "type": "MIXSIX"
#                 }
#             ],
#             "productUrl": "/wine/deals/red-wine/merlot/wildhaven-merlot-columbia-valley/p/123221750",
#             "rating": 0,
#             "review": "Columbia Valley, Washington- Bursting with aromas of blueberry, blackberry and a hint of cedar. Berry fruits continue on the palate rounded out with juicy cherries and integrated oak.",
#             "salesStrategy": {
#                 "name": "Winery Direct"
#             },
#             "shoppingOptions": [
#                 {
#                     "eligible": true,
#                     "location": "US-NJ",
#                     "selected": false,
#                     "type": "SHIPPING"
#                 },
#                 {
#                     "eligible": false,
#                     "location": "River Edge, NJ",
#                     "message": [
#                         "Item not available in your area"
#                     ],
#                     "selected": true,
#                     "type": "INSTORE_PICKUP"
#                 },
#                 {
#                     "eligible": false,
#                     "location": "River Edge, NJ",
#                     "message": [
#                         "Item not available in your area"
#                     ],
#                     "selected": false,
#                     "type": "DELIVERY"
#                 }
#             ],
#             "skuId": "123221750-1",
#             "stockLevel": [
#                 {
#                     "purchaseLimit": 6,
#                     "stock": 33
#                 }
#             ],
#             "storeDistance": 84.662254,
#             "storeId": "303",
#             "storeName": "River Edge",
#             "transactional": false,
#             "type": "PRODUCT",
#             "volume": ""
#         },
#         {
#             "brand": {
#                 "id": "Radius",
#                 "name": "Radius"
#             },
#             "categories": [
#                 {
#                     "id": "000009",
#                     "name": "Red Wine",
#                     "storefrontUrl": "/wine/red-wine/c/000009",
#                     "type": "PRODUCT_TYPE",
#                     "url": "https://www.totalwine.com/wine/red-wine/c/000009"
#                 },
#                 {
#                     "id": "000011",
#                     "name": "Cabernet Sauvignon",
#                     "storefrontUrl": "/wine/red-wine/cabernet-sauvignon/c/000011",
#                     "type": "VARIETAL_TYPE",
#                     "url": "https://www.totalwine.com/wine/red-wine/cabernet-sauvignon/c/000011"
#                 }
#             ],
#             "containerType": "Bottle",
#             "customerAverageRating": 4.1,
#             "customerReviewsCount": 455,
#             "department": "c0020",
#             "directType": "Winery Direct",
#             "id": "109682750",
#             "images": [
#                 {
#                     "altText": "Radius Cabernet",
#                     "imageType": "DEFAULT",
#                     "mobileOptimizedUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hf9/h03/13287132528670.png",
#                     "thumbnailUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hf9/h03/13287132528670.png",
#                     "url": "https://www.totalwine.com/media/sys_master/twmmedia/hf9/h03/13287132528670.png",
#                     "zoomImageUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hf9/h03/13287132528670.png"
#                 }
#             ],
#             "itemBody": "Medium-bodied",
#             "itemStyle": "Fresh",
#             "itemTasteProfile": "Black Cherry, Chocolate",
#             "name": "Radius Cabernet",
#             "packageDescription": "750ml",
#             "packageValue": "Single",
#             "price": [
#                 {
#                     "price": 12.99,
#                     "type": "EDLP"
#                 },
#                 {
#                     "price": 11.69,
#                     "toolTip": "What is Mix 6? Receive a special discount when you buy six or more of any bottles with the Mix 6 tag! Savings automatically applied in cart.",
#                     "type": "MIXSIX"
#                 }
#             ],
#             "productUrl": "/wine/deals/red-wine/cabernet-sauvignon/radius-cabernet/p/109682750",
#             "rating": 0,
#             "review": "Columbia Valley, WA -  This delicious Cabernet greets you with aromas of red jammy fruits and black cherry.  Hints of toasty oak lead to a delightful finish.  A true crowd-pleaser, this is great for entertaining and pairs well with hors d'oeuvres.",
#             "salesStrategy": {
#                 "name": "Winery Direct"
#             },
#             "shoppingOptions": [
#                 {
#                     "eligible": true,
#                     "location": "US-NJ",
#                     "selected": false,
#                     "type": "SHIPPING"
#                 },
#                 {
#                     "eligible": true,
#                     "location": "Cherry Hill, NJ",
#                     "selected": true,
#                     "type": "INSTORE_PICKUP"
#                 },
#                 {
#                     "eligible": true,
#                     "location": "Cherry Hill, NJ",
#                     "selected": false,
#                     "type": "DELIVERY"
#                 }
#             ],
#             "skuId": "109682750-1",
#             "stockLevel": [
#                 {
#                     "purchaseLimit": 6,
#                     "stock": 845
#                 }
#             ],
#             "storeDistance": 0.00023338888,
#             "storeId": "301",
#             "storeName": "Cherry Hill",
#             "transactional": true,
#             "type": "PRODUCT",
#             "volume": ""
#         },
#         {
#             "brand": {
#                 "id": "Carmen",
#                 "name": "Carmen"
#             },
#             "categories": [
#                 {
#                     "id": "000338",
#                     "name": "Maipo Valley",
#                     "storefrontUrl": "/wine/chile/maipo-valley/c/000338",
#                     "type": "REGION",
#                     "url": "https://www.totalwine.com/wine/chile/maipo-valley/c/000338"
#                 },
#                 {
#                     "id": "000009",
#                     "name": "Red Wine",
#                     "storefrontUrl": "/wine/red-wine/c/000009",
#                     "type": "PRODUCT_TYPE",
#                     "url": "https://www.totalwine.com/wine/red-wine/c/000009"
#                 },
#                 {
#                     "id": "000011",
#                     "name": "Cabernet Sauvignon",
#                     "storefrontUrl": "/wine/red-wine/cabernet-sauvignon/c/000011",
#                     "type": "VARIETAL_TYPE",
#                     "url": "https://www.totalwine.com/wine/red-wine/cabernet-sauvignon/c/000011"
#                 }
#             ],
#             "containerType": "Bottle",
#             "customerAverageRating": 3.6,
#             "customerReviewsCount": 315,
#             "department": "c0020",
#             "directType": "Winery Direct",
#             "id": "213696750",
#             "images": [
#                 {
#                     "altText": "Carmen Gran Reserva Cabernet Sauvignon, 2018",
#                     "imageType": "DEFAULT",
#                     "mobileOptimizedUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hd1/hc2/12306910511134.png",
#                     "thumbnailUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hd1/hc2/12306910511134.png",
#                     "url": "https://www.totalwine.com/media/sys_master/twmmedia/hd1/hc2/12306910511134.png",
#                     "zoomImageUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hd1/hc2/12306910511134.png"
#                 }
#             ],
#             "itemBody": "Full-bodied",
#             "itemStyle": "Elegant",
#             "itemTasteProfile": "Black Currant, Blackberry, Spice",
#             "name": "Carmen Gran Reserva Cabernet Sauvignon, 2018",
#             "packageDescription": "750ml",
#             "packageValue": "Single",
#             "price": [
#                 {
#                     "price": 17.99,
#                     "type": "EDLP"
#                 },
#                 {
#                     "price": 16.19,
#                     "toolTip": "What is Mix 6? Receive a special discount when you buy six or more of any bottles with the Mix 6 tag! Savings automatically applied in cart.",
#                     "type": "MIXSIX"
#                 }
#             ],
#             "productUrl": "/wine/new-arrivals/red-wine/cabernet-sauvignon/carmen-gran-reserva-cabernet-sauvignon/p/213696750",
#             "rating": 92,
#             "ratingSource": "James Suckling",
#             "review": "James Suckling-Maipo Valley, Chile- \"Blackberries with undertones of black chocolate and flowers. Medium body, tight and firm tannins and a flavorful finish. Lightly chewy...\" Drink now or cellar.",
#             "salesStrategy": {
#                 "name": "Winery Direct"
#             },
#             "shoppingOptions": [
#                 {
#                     "eligible": true,
#                     "location": "US-NJ",
#                     "selected": false,
#                     "type": "SHIPPING"
#                 },
#                 {
#                     "eligible": true,
#                     "location": "Cherry Hill, NJ",
#                     "selected": true,
#                     "type": "INSTORE_PICKUP"
#                 },
#                 {
#                     "eligible": true,
#                     "location": "Cherry Hill, NJ",
#                     "selected": false,
#                     "type": "DELIVERY"
#                 }
#             ],
#             "skuId": "213696750-1",
#             "stockLevel": [
#                 {
#                     "purchaseLimit": 6,
#                     "stock": 143
#                 }
#             ],
#             "storeDistance": 0.00023338888,
#             "storeId": "301",
#             "storeName": "Cherry Hill",
#             "transactional": true,
#             "type": "PRODUCT",
#             "volume": ""
#         }
#     ],
#     "redirectionUrl": "/wine/c/c0020",
#     "searchAllStores": false,
#     "searchText": "c0020",
#     "seoMetaData": [
#         {
#             "content": "Wine",
#             "name": "H1"
#         },
#         {
#             "content": "Total Wine & More offers more than 8,000 wines: red, white, sparkling and ros\u00e9 wines, from winemakers big and small. Shop our collection now. We are offering contact-less curbside pick up and delivery. Order your favorites online today!",
#             "name": "description"
#         },
#         {
#             "content": "",
#             "name": "H2"
#         },
#         {
#             "content": "Online wine shop, wine delivery | Total Wine & More",
#             "name": "title"
#         },
#         {
#             "content": "Wine",
#             "name": "dynamicH1"
#         }
#     ],
#     "sorts": [
#         {
#             "id": "relevance",
#             "name": "Relevance",
#             "selected": true
#         },
#         {
#             "id": "expert-ratings",
#             "name": "Expert Ratings",
#             "selected": false
#         },
#         {
#             "id": "customer-ratings",
#             "name": "Customer Ratings",
#             "selected": false
#         },
#         {
#             "id": "price-desc",
#             "name": "Price (highest first)",
#             "selected": false
#         },
#         {
#             "id": "price-asc",
#             "name": "Price (lowest first)",
#             "selected": false
#         },
#         {
#             "id": "name-asc",
#             "name": "Name (A-Z)",
#             "selected": false
#         },
#         {
#             "id": "name-desc",
#             "name": "Name (Z-A)",
#             "selected": false
#         }
#     ]
# }

# %%
productsurl = data["products"][0]
print(json.dumps(productsurl, indent=4, sort_keys=True))
# Out:
# {
#     "brand": {
#         "id": "Renieri",
#         "name": "Renieri"
#     },
#     "categories": [
#         {
#             "id": "000466",
#             "name": "Tuscany",
#             "storefrontUrl": "/wine/italy/tuscany/c/000466",
#             "type": "REGION",
#             "url": "https://www.totalwine.com/wine/italy/tuscany/c/000466"
#         },
#         {
#             "id": "000009",
#             "name": "Red Wine",
#             "storefrontUrl": "/wine/red-wine/c/000009",
#             "type": "PRODUCT_TYPE",
#             "url": "https://www.totalwine.com/wine/red-wine/c/000009"
#         },
#         {
#             "id": "000012",
#             "name": "Red Blend",
#             "storefrontUrl": "/wine/red-wine/red-blend/c/000012",
#             "type": "VARIETAL_TYPE",
#             "url": "https://www.totalwine.com/wine/red-wine/red-blend/c/000012"
#         }
#     ],
#     "containerType": "Bottle",
#     "customerAverageRating": 3.8,
#     "customerReviewsCount": 218,
#     "department": "c0020",
#     "directType": "Winery Direct",
#     "id": "113710750",
#     "images": [
#         {
#             "altText": "Renieri Invetro, 2016",
#             "imageType": "DEFAULT",
#             "mobileOptimizedUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png",
#             "thumbnailUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png",
#             "url": "https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png",
#             "zoomImageUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png"
#         }
#     ],
#     "itemBody": "Medium-bodied",
#     "itemStyle": "Elegant",
#     "itemTasteProfile": "Cherry, Plum",
#     "name": "Renieri Invetro, 2016",
#     "packageDescription": "750ml",
#     "packageValue": "Single",
#     "price": [
#         {
#             "price": 17.99,
#             "type": "EDLP"
#         },
#         {
#             "price": 16.19,
#             "toolTip": "What is Mix 6? Receive a special discount when you buy six or more of any bottles with the Mix 6 tag! Savings automatically applied in cart.",
#             "type": "MIXSIX"
#         }
#     ],
#     "productUrl": "/wine/deals/red-wine/red-blend/renieri-invetro/p/113710750",
#     "rating": 92,
#     "ratingSource": "James Suckling",
#     "review": "James Suckling-Tuscany, Italy (Sangiovese, Merlot and Cabernet Sauvignon) - \"Glazed red cherries, tobacco and cedar with hints of dried leaves. Medium to full body, juicy tannins and a succulent finish. Sangiovese, merlot and cabernet sauvignon.\"",
#     "salesStrategy": {
#         "name": "Winery Direct"
#     },
#     "shoppingOptions": [
#         {
#             "eligible": true,
#             "location": "US-NJ",
#             "selected": false,
#             "type": "SHIPPING"
#         },
#         {
#             "eligible": true,
#             "location": "Cherry Hill, NJ",
#             "selected": true,
#             "type": "INSTORE_PICKUP"
#         },
#         {
#             "eligible": true,
#             "location": "Cherry Hill, NJ",
#             "selected": false,
#             "type": "DELIVERY"
#         }
#     ],
#     "skuId": "113710750-1",
#     "stockLevel": [
#         {
#             "purchaseLimit": 6,
#             "stock": 964
#         }
#     ],
#     "storeDistance": 0.00023338888,
#     "storeId": "301",
#     "storeName": "Cherry Hill",
#     "topSeller": {
#         "badgeText": "#1 Wine of 2020"
#     },
#     "transactional": true,
#     "type": "PRODUCT",
#     "volume": ""
# }

# %%
products1 = data["products"][0]
print(json.dumps(products1, indent=4, sort_keys=True))
# Out:
# {
#     "brand": {
#         "id": "Renieri",
#         "name": "Renieri"
#     },
#     "categories": [
#         {
#             "id": "000466",
#             "name": "Tuscany",
#             "storefrontUrl": "/wine/italy/tuscany/c/000466",
#             "type": "REGION",
#             "url": "https://www.totalwine.com/wine/italy/tuscany/c/000466"
#         },
#         {
#             "id": "000009",
#             "name": "Red Wine",
#             "storefrontUrl": "/wine/red-wine/c/000009",
#             "type": "PRODUCT_TYPE",
#             "url": "https://www.totalwine.com/wine/red-wine/c/000009"
#         },
#         {
#             "id": "000012",
#             "name": "Red Blend",
#             "storefrontUrl": "/wine/red-wine/red-blend/c/000012",
#             "type": "VARIETAL_TYPE",
#             "url": "https://www.totalwine.com/wine/red-wine/red-blend/c/000012"
#         }
#     ],
#     "containerType": "Bottle",
#     "customerAverageRating": 3.8,
#     "customerReviewsCount": 218,
#     "department": "c0020",
#     "directType": "Winery Direct",
#     "id": "113710750",
#     "images": [
#         {
#             "altText": "Renieri Invetro, 2016",
#             "imageType": "DEFAULT",
#             "mobileOptimizedUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png",
#             "thumbnailUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png",
#             "url": "https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png",
#             "zoomImageUrl": "https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png"
#         }
#     ],
#     "itemBody": "Medium-bodied",
#     "itemStyle": "Elegant",
#     "itemTasteProfile": "Cherry, Plum",
#     "name": "Renieri Invetro, 2016",
#     "packageDescription": "750ml",
#     "packageValue": "Single",
#     "price": [
#         {
#             "price": 17.99,
#             "type": "EDLP"
#         },
#         {
#             "price": 16.19,
#             "toolTip": "What is Mix 6? Receive a special discount when you buy six or more of any bottles with the Mix 6 tag! Savings automatically applied in cart.",
#             "type": "MIXSIX"
#         }
#     ],
#     "productUrl": "/wine/deals/red-wine/red-blend/renieri-invetro/p/113710750",
#     "rating": 92,
#     "ratingSource": "James Suckling",
#     "review": "James Suckling-Tuscany, Italy (Sangiovese, Merlot and Cabernet Sauvignon) - \"Glazed red cherries, tobacco and cedar with hints of dried leaves. Medium to full body, juicy tannins and a succulent finish. Sangiovese, merlot and cabernet sauvignon.\"",
#     "salesStrategy": {
#         "name": "Winery Direct"
#     },
#     "shoppingOptions": [
#         {
#             "eligible": true,
#             "location": "US-NJ",
#             "selected": false,
#             "type": "SHIPPING"
#         },
#         {
#             "eligible": true,
#             "location": "Cherry Hill, NJ",
#             "selected": true,
#             "type": "INSTORE_PICKUP"
#         },
#         {
#             "eligible": true,
#             "location": "Cherry Hill, NJ",
#             "selected": false,
#             "type": "DELIVERY"
#         }
#     ],
#     "skuId": "113710750-1",
#     "stockLevel": [
#         {
#             "purchaseLimit": 6,
#             "stock": 964
#         }
#     ],
#     "storeDistance": 0.00023338888,
#     "storeId": "301",
#     "storeName": "Cherry Hill",
#     "topSeller": {
#         "badgeText": "#1 Wine of 2020"
#     },
#     "transactional": true,
#     "type": "PRODUCT",
#     "volume": ""
# }

# %%
productsid = data["products"][0]["skuId"]
print(json.dumps(productsid, indent=4, sort_keys=True))

# %%
productapi = f"https://www.totalwine.com/product/api/product/product-detail/v1/getProduct/{productsid}?shoppingMethod=INSTORE_PICKUP&state=US-NJ&storeId=301"
response2 = requests.get(productapi, headers=headers)
response2
data2 = response2.json()
print(json.dumps(data2, indent=4, sort_keys=True))
# Out:
# {
#     "alcoholPercentage": 13.5,
#     "brand": {
#         "departmentCode": "c0020",
#         "id": "carmen",
#         "name": "Carmen"
#     },
#     "breadCrumbs": [
#         {
#             "name": "Home",
#             "url": "/"
#         },
#         {
#             "name": "Wine",
#             "url": "/wine/c/c0020"
#         },
#         {
#             "name": "Red Wine",
#             "url": "/wine/red-wine/c/000009"
#         },
#         {
#             "name": "Cabernet Sauvignon",
#             "url": "/wine/red-wine/cabernet-sauvignon/c/000011"
#         },
#         {
#             "name": "Carmen Gran Reserva Cabernet Sauvignon, 2018"
#         }
#     ],
#     "canonicalUrl": "/wine/red-wine/cabernet-sauvignon/carmen-gran-reserva-cabernet-sauvignon/p/213696750",
#     "categories": [
#         {
#             "id": "000009",
#             "name": "Red Wine",
#             "type": "PRODUCT_TYPE"
#         },
#         {
#             "id": "000011",
#             "name": "Cabernet Sauvignon",
#             "type": "VARIETAL_TYPE"
#         },
#         {
#             "id": "000271",
#             "name": "Chile",
#             "type": "COUNTRY_STATE"
#         },
#         {
#             "id": "000338",
#             "name": "Maipo Valley",
#             "type": "REGION"
#         }
#     ],
#     "customerAverageRating": 3.6,
#     "customerReviewsCount": 304,
#     "department": "c0020",
#     "directType": "Winery Direct",
#     "id": "213696750",
#     "images": [
#         {
#             "imageType": "DEFAULT",
#             "mobileOptimizedUrl": "https://www.totalwine.com/dynamic/102x/media/sys_master/twmmedia/h99/h79/12306862702622.png",
#             "thumbnailUrl": "https://www.totalwine.com/media/sys_master/twmmedia/h99/h79/12306862702622.png",
#             "url": "https://www.totalwine.com/media/sys_master/twmmedia/h99/h79/12306862702622.png",
#             "zoomImageUrl": "https://www.totalwine.com/media/sys_master/twmmedia/h99/h79/12306862702622.png"
#         }
#     ],
#     "itemCharacteristics": [
#         {
#             "attributeName": "Product Type",
#             "categoryId": "000009",
#             "type": "PRODUCT_TYPE",
#             "value": "Red Wine"
#         },
#         {
#             "attributeName": "Varietal Type",
#             "categoryId": "000011",
#             "type": "VARIETAL_TYPE",
#             "value": "Cabernet Sauvignon"
#         },
#         {
#             "attributeName": "Country State",
#             "categoryId": "000271",
#             "type": "COUNTRY_STATE",
#             "value": "Chile"
#         },
#         {
#             "attributeName": "Region",
#             "categoryId": "000338",
#             "type": "REGION",
#             "value": "Maipo Valley"
#         },
#         {
#             "attributeName": "Taste",
#             "type": "TASTE1",
#             "value": "Black Currant"
#         },
#         {
#             "attributeName": "Taste",
#             "type": "TASTE2",
#             "value": "Blackberry"
#         },
#         {
#             "attributeName": "Taste",
#             "type": "TASTE3",
#             "value": "Spice"
#         },
#         {
#             "attributeName": "Body",
#             "type": "BODY",
#             "value": "Full-bodied"
#         },
#         {
#             "attributeName": "Style",
#             "type": "STYLE",
#             "value": "Elegant"
#         }
#     ],
#     "location": "Aisle 06, Left",
#     "metaDescription": "Shop Carmen Gran Reserva Cabernet Sauvignon at the best prices. Explore thousands of wines, spirits and beers, and shop online for delivery or pickup in a store near you.",
#     "name": "Carmen Gran Reserva Cabernet Sauvignon, 2018",
#     "packageDescription": "750ml",
#     "packageValue": "Single",
#     "price": [
#         {
#             "price": 17.99,
#             "type": "EDLP"
#         },
#         {
#             "price": 16.19,
#             "toolTip": "What is Mix 6? Receive a special discount when you buy six or more of any bottles with the Mix 6 tag! Savings automatically applied in cart. ",
#             "type": "MIXSIX"
#         }
#     ],
#     "productPageTitle": "Carmen Gran Reserva Cabernet Sauvignon | Total Wine & More",
#     "productUrl": "/wine/red-wine/cabernet-sauvignon/carmen-gran-reserva-cabernet-sauvignon/p/213696750",
#     "rating": 92,
#     "ratingSource": "James Suckling",
#     "review": "James Suckling-Maipo Valley, Chile- \"\"Blackberries with undertones of black chocolate and flowers. Medium body, tight and firm tannins and a flavorful finish. Lightly chewy...\"\" Drink now or cellar.",
#     "salesStrategy": {
#         "name": "Winery Direct",
#         "type": "WD"
#     },
#     "shoppingOptions": [
#         {
#             "eligible": true,
#             "location": "Cherry Hill",
#             "selected": true,
#             "type": "INSTORE_PICKUP"
#         },
#         {
#             "eligible": true,
#             "location": "Cherry Hill",
#             "selected": false,
#             "type": "DELIVERY"
#         },
#         {
#             "eligible": true,
#             "location": "US-NJ",
#             "selected": false,
#             "type": "SHIPPING"
#         }
#     ],
#     "skuId": "213696750-1",
#     "skus": [
#         {
#             "options": [
#                 {
#                     "type": "CONTAINER",
#                     "value": "Bottle"
#                 },
#                 {
#                     "type": "SIZE",
#                     "value": "750ml"
#                 },
#                 {
#                     "type": "PACKAGE",
#                     "value": "Single"
#                 }
#             ],
#             "skuId": "213696750-1",
#             "url": ""
#         }
#     ],
#     "stockLevel": [
#         {
#             "purchaseLimit": 171,
#             "stock": 171
#         }
#     ],
#     "storeId": "301",
#     "tasteProfiles": [
#         "Elegant",
#         "Black Currant",
#         "Blackberry",
#         "Spice",
#         "Full-bodied"
#     ],
#     "transactional": true
# }

# %%
item_characteristics= data2["itemCharacteristics"]
print(json.dumps(item_characteristics, indent=4, sort_keys=True))

# %%
#there are 350 pages
data_set = []
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36', "referer" : "https://www.totalwine.com/wine/c/c0020?viewall=true&pageSize=24&department=Wine"}
base_url = "https://www.totalwine.com"
count = 2
string_count = str(count)
for page in range(1,5):
    names = []
    time.sleep(.5)
    #url3 =f"https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page={page}&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&_br_uid_2=uid%3D3859515441530%3Av%3D12.0%3Ats%3D1606745577813%3Ahc%3D5"
    
           #f"https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page={page}&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&_br_uid_2=uid%3D3243838382926%3Av%3D12.0%3Ats%3D1606758592624%3Ahc%3D38"
    if (page==1):
        print("in the if")
        url3 = f"https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page={page}&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&batch=true&_br_uid_2=uid%3D3243838382926%3Av%3D12.0%3Ats%3D1606758592624%3Ahc%3D38"
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36', "referer" : "https://www.totalwine.com/wine/c/c0020?viewall=true&pageSize=24&department=Wine"}
        #headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}
       
    else:
        print("in the else")
        url3 = f"https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page={page}&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&_br_uid_2=uid%3D3243838382926%3Av%3D12.0%3Ats%3D1606758592624%3Ahc%3D38"
        #headers = {'3User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36', "referer" : "https://www.totalwine.com/wine/c/c0020?viewall=true&page="+string_count+"&pageSize=24&department=Wine"}
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}

    response_real= requests.get(url3, headers=headers)
    data_real = response_real.json()
    print(f"page: {page} response {response_real}")
    
    

    
    products_all = data_real["products"]
    
    
    for name in products_all:
        names.append(name)


    
    for x in names:
        productsid = x["skuId"]
        #print(f"page: {page}, skuId is {productsid}")
        name = x["name"]
        price = x["price"][0]["price"]
        
        #print(f"page: {page} skid:  {productsid}")
        #time.sleep(.02)
        #productapi = f"https://www.totalwine.com/product/api/product/product-detail/v1/getProduct/{productsid}?shoppingMethod=INSTORE_PICKUP&state=US-NJ&storeId=301"
        #complete = base_url + proudct_url+ "?s=301&igrules=true"
        #referer= https://www.totalwine.com/wine/red-wine/red-blend/renieri-invetro/p/113710750?s=301&igrules=true
      
        data_set.append({"skuId":productsid,
                        "name" : name,
                        "price" : price})
        
print(data_set)  
                
                
                
                
                
                
        #headers3 = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36', "referer" : "https://www.totalwine.com/wine/c/c0020?viewall=true&pageSize=24&department=Wine"}
        #response4 = requests.get(productapi, headers=headers3)
        #print(response4)
        #print(productapi)
# Out:
# in the if
# page: 1 response <Response [200]>
# in the else
# page: 2 response <Response [200]>
# in the else
# page: 3 response <Response [200]>
# in the else
# page: 4 response <Response [200]>
# [{'skuId': '113710750-1', 'name': 'Renieri Invetro, 2016', 'price': 17.99}, {'skuId': '213620750-1', 'name': 'Kia Ora Signature Marlborough Sauvignon Blanc, 2020', 'price': 13.99}, {'skuId': '213689750-1', 'name': 'Cabernario No.8 Cabernet Sauvignon, 2017', 'price': 19.99}, {'skuId': '178708750-1', 'name': 'Uro Toro La Enfermera Tempranillo, 2017', 'price': 9.99}, {'skuId': '219505750-1', 'name': 'Borrasca Prosecco DOCG', 'price': 14.99}, {'skuId': '223960750-1', 'name': 'Vennstone Pinot Noir Tri Appellation, 2019', 'price': 19.99}, {'skuId': '172964750-1', 'name': 'Le Pre Vaujour Sancerre', 'price': 19.99}, {'skuId': '219809750-1', 'name': 'Firebrand Chardonnay Reserve, 2019', 'price': 12.99}, {'skuId': '18266750-1', 'name': 'Guy Mousset Cotes du Rhone Reserve', 'price': 14.99}, {'skuId': '213639750-1', 'name': 'Ed Edmundo Cabernet Sauvignon, 2019', 'price': 9.99}, {'skuId': '214177750-1', 'name': 'Champagne Comtesse Gerin Grande Reserve Brut', 'price': 39.99}, {'skuId': '132101750-1', 'name': 'Chateau Pierre de Montignac Medoc', 'price': 19.99}, {'skuId': '213660750-1', 'name': 'Mascota Vineyards Unanime Malbec, 2016', 'price': 22.99}, {'skuId': '140006750-1', 'name': 'Chateau Fabregues Costieres de Nimes, 2019', 'price': 16.99}, {'skuId': '219918750-1', 'name': 'Josh Cellars Bourbon Barrel Cabernet Sauvignon Family Reserve', 'price': 16.99}, {'skuId': '219512750-1', 'name': 'Laudato Pinot Grigio, 2019', 'price': 16.99}, {'skuId': '173542750-1', 'name': 'Double Black Zinfandel Paso Robles, 2018', 'price': 13.99}, {'skuId': '94390750-1', 'name': 'Muirwood Chardonnay Arroyo Seco, 2018', 'price': 14.99}, {'skuId': '213643750-1', 'name': 'Eccentric Red Blend', 'price': 9.99}, {'skuId': '96105750-1', 'name': 'Dr Heidemanns Riesling QbA', 'price': 12.99}, {'skuId': '107654750-1', 'name': 'Kudos Pinot Noir Willamette', 'price': 17.99}, {'skuId': '123221750-1', 'name': 'Wildhaven Merlot Columbia Valley', 'price': 13.99}, {'skuId': '109682750-1', 'name': 'Radius Cabernet', 'price': 12.99}, {'skuId': '213696750-1', 'name': 'Carmen Gran Reserva Cabernet Sauvignon, 2018', 'price': 17.99}, {'skuId': '130007750-1', 'name': 'Mascota Vineyards Unanime, 2017', 'price': 24.99}, {'skuId': '171353750-1', 'name': 'Buttercream Chardonnay', 'price': 13.99}, {'skuId': '139834750-1', 'name': 'Governors Bay Marlborough Sauvignon Blanc, 2019', 'price': 12.99}, {'skuId': '106559750-1', 'name': 'Angeline Pinot Noir California, 2018', 'price': 12.99}, {'skuId': '20095750-1', 'name': 'Amici Cabernet Sauvignon Napa, 2018', 'price': 49.99}, {'skuId': '79201750-1', 'name': 'Courtney Benham Cabernet Sauvignon Napa, 2018', 'price': 24.99}, {'skuId': '110892750-1', 'name': 'Cloud Break Chardonnay', 'price': 8.99}, {'skuId': '216029750-1', 'name': 'Double Black Cabernet Sauvignon Paso, 2018', 'price': 13.99}, {'skuId': '213628750-1', 'name': 'San Gregorio El Vergal Tempranillo, 2018', 'price': 10.99}, {'skuId': '224647750-1', 'name': 'Renieri Brunello di Montalcino, 2015', 'price': 99.99}, {'skuId': '143686750-1', 'name': 'TULI Pinot Noir Sonoma County', 'price': 26.99}, {'skuId': '224001750-1', 'name': 'BlueWing Vineyards Cabernet Sauvignon Sonoma, 2017', 'price': 19.99}, {'skuId': '181110750-1', 'name': "Samuel Robert Winery Pinot Noir Vintner's Reserve Willamette", 'price': 15.99}, {'skuId': '178686750-1', 'name': 'Kia Ora Marlborough Sauv Blanc', 'price': 9.99}, {'skuId': '134058750-1', 'name': 'Harvester Cabernet Sauvignon Paso Robles', 'price': 19.99}, {'skuId': '103169750-1', 'name': "D'Autrefois Reserve Pinot Noir", 'price': 18.99}, {'skuId': '223961750-1', 'name': 'Angeline Pinot Noir Russian River Valley, 2018', 'price': 19.99}, {'skuId': '133454750-1', 'name': 'Olema Pinot Noir Sonoma County, 2018', 'price': 19.99}, {'skuId': '213305750-1', 'name': 'Mascota Vineyards Unanime Chardonnay, 2018', 'price': 19.99}, {'skuId': '116812750-1', 'name': 'Olema Chardonnay Sonoma County, 2018', 'price': 15.99}, {'skuId': '172976750-1', 'name': 'La Vostra Prosecco' ...

# %%
product_url = "https://www.totalwine.com/product/api/product/product-detail/v1/getProduct/113710750-1?shoppingMethod=INSTORE_PICKUP&state=US-NJ&storeId=301"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}

product_response_real= requests.get(product_url, headers=headers)
product_real = product_response_real.json()
product_real
# Out:
# {'brand': {'id': 'renieri', 'name': 'Renieri', 'departmentCode': 'c0020'},
#  'videos': [{'url': 'https://vimeo.com/98565530',
#    'previewImageUrl': 'https://www.totalwine.com/_ui/desktop/twm/images/sample/item4.jpg'}],
#  'categories': [{'id': '000009', 'name': 'Red Wine', 'type': 'PRODUCT_TYPE'},
#   {'id': '000012', 'name': 'Red Blend', 'type': 'VARIETAL_TYPE'},
#   {'id': '000278', 'name': 'Italy', 'type': 'COUNTRY_STATE'},
#   {'id': '000466', 'name': 'Tuscany', 'type': 'REGION'}],
#  'customerAverageRating': 3.8,
#  'customerReviewsCount': 210,
#  'id': '113710750',
#  'images': [{'imageType': 'DEFAULT',
#    'mobileOptimizedUrl': 'https://www.totalwine.com/dynamic/102x/media/sys_master/twmmedia/h13/h39/13177297371166.png',
#    'thumbnailUrl': 'https://www.totalwine.com/media/sys_master/twmmedia/h13/h39/13177297371166.png',
#    'url': 'https://www.totalwine.com/media/sys_master/twmmedia/h13/h39/13177297371166.png',
#    'zoomImageUrl': 'https://www.totalwine.com/media/sys_master/twmmedia/h13/h39/13177297371166.png'}],
#  'location': 'Aisle 03, Right',
#  'name': 'Renieri Invetro, 2016',
#  'metaDescription': 'Shop Renieri Invetro at the best prices. Explore thousands of wines, spirits and beers, and shop online for delivery or pickup in a store near you.',
#  'productPageTitle': 'Renieri Invetro | Total Wine & More',
#  'productUrl': '/wine/red-wine/red-blend/renieri-invetro/p/113710750',
#  'canonicalUrl': '/wine/red-wine/red-blend/renieri-invetro/p/113710750',
#  'packageDescription': '750ml',
#  'price': [{'price': 17.99, 'type': 'EDLP'},
#   {'price': 16.19,
#    'toolTip': 'What is Mix 6? Receive a special discount when you buy six or more of any bottles with the Mix 6 tag! Savings automatically applied in cart. ',
#    'type': 'MIXSIX'}],
#  'rating': 92,
#  'ratingSource': 'James Suckling',
#  'review': 'James Suckling-Tuscany, Italy (Sangiovese, Merlot and Cabernet Sauvignon) - ""Glazed red cherries, tobacco and cedar with hints of dried leaves. Medium to full body, juicy tannins and a succulent finish. Sangiovese, merlot and cabernet sauvignon.""',
#  'shoppingOptions': [{'eligible': True,
#    'location': 'Cherry Hill',
#    'type': 'INSTORE_PICKUP',
#    'selected': True},
#   {'eligible': True,
#    'location': 'Cherry Hill',
#    'type': 'DELIVERY',
#    'selected': False},
#   {'eligible': True,
#    'location': 'US-NJ',
#    'type': 'SHIPPING',
#    'selected': False}],
#  'skuId': '113710750-1',
#  'stockLevel': [{'purchaseLimit': 962, 'stock': 962}],
#  'storeId': '301',
#  'tasteProfiles': ['Elegant', 'Cherry', 'Plum', 'Medium-bodied'],
#  'transactional': True,
#  'salesStrategy': {'name': 'Winery Direct', 'type': 'WD'},
#  'department': 'c0020',
#  'directType': 'Winery Direct',
#  'itemCharacteristics': [{'attributeName': 'Product Type',
#    'value': 'Red Wine',
#    'type': 'PRODUCT_TYPE',
#    'categoryId': '000009'},
#   {'attributeName': 'Varietal Type',
#    'value': 'Red Blend',
#    'type': 'VARIETAL_TYPE',
#    'categoryId': '000012'},
#   {'attributeName': 'Country State',
#    'value': 'Italy',
#    'type': 'COUNTRY_STATE',
#    'categoryId': '000278'},
#   {'attributeName': 'Region',
#    'value': 'Tuscany',
#    'type': 'REGION',
#    'categoryId': '000466'},
#   {'attributeName': 'Taste', 'value': 'Cherry', 'type': 'TASTE1'},
#   {'attributeName': 'Taste', 'value': 'Plum', 'type': 'TASTE2'},
#   {'attributeName': 'Body', 'value': 'Medium-bodied', 'type': 'BODY'},
#   {'attributeName': 'Style', 'value': 'Elegant', 'type': 'STYLE'}],
#  'skus': [{'skuId': '113710750-1',
#    'options': [{'type': 'CONTAINER', 'value': 'Bottle'},
#     {'type': 'SIZE', 'value': '750ml'},
#     {'type': 'PACKAGE', 'value': 'Single'}],
#    'url': ''}],
#  'breadCrumbs': [{'name': 'Home', 'url': '/'},
#   {'name': 'Wine', 'url': '/wine/c/c0020'},
#   {'name': 'Red Wine', 'url': '/wine/red-wine/c/000009'},
#   {'name': 'Red Blend', 'url': '/wine/red-wine/red-blend/c/000012'},
#   {'name': 'Renieri Invetro, 2016'}],
#  'packageValue': 'Single',
#  'alcoholPercentage': 14,
#  'topSeller': {'badgeText': '#1 Wine of 2020'}}
