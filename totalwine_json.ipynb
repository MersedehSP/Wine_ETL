# %%
import requests
import json
import pandas as pd
import time
from bs4 import BeautifulSoup

# %%
url = "https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page=1&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&batch=true&_br_uid_2=uid%3D711505870994%3Av%3D12.0%3Ats%3D1606923004355%3Ahc%3D2"

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}
response = requests.get(url, headers=headers)
response
#Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36
#print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# <Response [200]>

# %%
data = response.json()
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "autoCorrect": {},
#     "categoryBreadcrumbs": [
#         {
#             "categoryCode": "c0020",
#             "name": "Wine",
#             "url": "/Wine/c/c0020"
#         }
#     ],
#     "categoryName": "c0020",
#     "facets": [
#         {
#             "id": "price",
#             "multiSelect": true,
#             "name": "Price Range",
#             "priority": 9999,
#             "values": [
#                 {
#                     "count": 1183,
#                     "id": "up-to-10",
#                     "name": "Up to $10",
#                     "priority": 1,
#                     "selected": false
#                 },
#                 {
#                     "count": 3031,
#                     "id": "-10-to-20",
#                     "name": "$10 to $20",
#                     "priority": 2,
#                     "selected": false
#                 },
#                 {
#                     "count": 1034,
#                     "id": "-20-to-30",
# ...

# %%
# https://www.totalwine.com/wine/deals/red-wine/red-blend/renieri-invetro/p/113710750&igrules=true
# https://www.totalwine.com/wine/red-wine/red-blend/renieri-invetro/p/113710750&igrules=true
# https://www.totalwine.com/wine/red-wine/red-blend/renieri-invetro/p/113710750?s=301&igrules=true
# https://www.totalwine.com/wine/deals/red-wine/red-blend/renieri-invetro/p/113710750?s=301&igrules=true
productsurl = data["products"][0]
print(json.dumps(productsurl, indent=4, sort_keys=True))

base_url = "https://www.totalwine.com"
end_url = "?s=301&igrules=true"

test1 = data["products"][0]["productUrl"]  

        
        
full_url = base_url +test1+end_url
print(full_url)


   
 
print ("Original string: " + full_url) 
   
 
res_str = full_url.replace('deals/', '') 
   
 
# removes all occurrences of 'e' 
print ("The string after removal of character: " + res_str)
# Out:
# {
#     "brand": {
#         "id": "Renieri",
#         "name": "Renieri"
#     },
#     "categories": [
#         {
#             "id": "000466",
#             "name": "Tuscany",
#             "storefrontUrl": "/wine/italy/tuscany/c/000466",
#             "type": "REGION",
#             "url": "https://www.totalwine.com/wine/italy/tuscany/c/000466"
#         },
#         {
#             "id": "000009",
#             "name": "Red Wine",
#             "storefrontUrl": "/wine/red-wine/c/000009",
#             "type": "PRODUCT_TYPE",
#             "url": "https://www.totalwine.com/wine/red-wine/c/000009"
#         },
#         {
#             "id": "000012",
#             "name": "Red Blend",
#             "storefrontUrl": "/wine/red-wine/red-blend/c/000012",
#             "type": "VARIETAL_TYPE",
#             "url": "https://www.totalwine.com/wine/red-wine/red-blend/c/000012"
#         }
#     ],
#     "containerType": "Bottle",
#     "customerAverageRating": 3.8,
# ...

# %%
products1 = data["products"][0]
print(json.dumps(products1, indent=4, sort_keys=True))
# Out:
# {
#     "brand": {
#         "id": "Renieri",
#         "name": "Renieri"
#     },
#     "categories": [
#         {
#             "id": "000466",
#             "name": "Tuscany",
#             "storefrontUrl": "/wine/italy/tuscany/c/000466",
#             "type": "REGION",
#             "url": "https://www.totalwine.com/wine/italy/tuscany/c/000466"
#         },
#         {
#             "id": "000009",
#             "name": "Red Wine",
#             "storefrontUrl": "/wine/red-wine/c/000009",
#             "type": "PRODUCT_TYPE",
#             "url": "https://www.totalwine.com/wine/red-wine/c/000009"
#         },
#         {
#             "id": "000012",
#             "name": "Red Blend",
#             "storefrontUrl": "/wine/red-wine/red-blend/c/000012",
#             "type": "VARIETAL_TYPE",
#             "url": "https://www.totalwine.com/wine/red-wine/red-blend/c/000012"
#         }
#     ],
#     "containerType": "Bottle",
#     "customerAverageRating": 3.8,
# ...

# %%
productsid = data["products"][0]["skuId"]
print(json.dumps(productsid, indent=4, sort_keys=True))

# %%
productapi = f"https://www.totalwine.com/product/api/product/product-detail/v1/getProduct/{productsid}?shoppingMethod=INSTORE_PICKUP&state=US-NJ&storeId=301"
response2 = requests.get(productapi, headers=headers)
response2
data2 = response2.json()
print(json.dumps(data2, indent=4, sort_keys=True))
# Out:
# {
#     "alcoholPercentage": 13.5,
#     "brand": {
#         "departmentCode": "c0020",
#         "id": "carmen",
#         "name": "Carmen"
#     },
#     "breadCrumbs": [
#         {
#             "name": "Home",
#             "url": "/"
#         },
#         {
#             "name": "Wine",
#             "url": "/wine/c/c0020"
#         },
#         {
#             "name": "Red Wine",
#             "url": "/wine/red-wine/c/000009"
#         },
#         {
#             "name": "Cabernet Sauvignon",
#             "url": "/wine/red-wine/cabernet-sauvignon/c/000011"
#         },
#         {
#             "name": "Carmen Gran Reserva Cabernet Sauvignon, 2018"
#         }
#     ],
#     "canonicalUrl": "/wine/red-wine/cabernet-sauvignon/carmen-gran-reserva-cabernet-sauvignon/p/213696750",
#     "categories": [
#         {
#             "id": "000009",
#             "name": "Red Wine",
#             "type": "PRODUCT_TYPE"
#         },
#         {
#             "id": "000011",
# ...

# %%
item_characteristics= data2["itemCharacteristics"]
print(json.dumps(item_characteristics, indent=4, sort_keys=True))

# %%
#there are 350 pages

data_set = []
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36', "referer" : "https://www.totalwine.com/wine/c/c0020?viewall=true&pageSize=24&department=Wine"}
base_url = "https://www.totalwine.com"
end_url = "?s=301&igrules=true"
#count = 2
#string_count = str(count)
names = []
for page in range(1,5):
    
    time.sleep(2)
          #f"https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page={page}&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&_br_uid_2=uid%3D3243838382926%3Av%3D12.0%3Ats%3D1606758592624%3Ahc%3D38"
    if (page==1):
        print("in the if")
        url3 = f"https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page={page}&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&batch=true&_br_uid_2=uid%3D3243838382926%3Av%3D12.0%3Ats%3D1606758592624%3Ahc%3D38"
        
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66\
        Safari/537.36',"Upgrade-Insecure-Requests": "1","DNT": "1", "accept": "application/json, text/plain, */*",
        "accept-language": "en-US,en;q=0.9", "accept-encoding"  : "gzip, deflate, br"}  
        
        #headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36', 
                   #"referer": "https://www.totalwine.com/wine/c/c0020?viewall=true&pageSize=24&department=Wine", 
                   #"accept": "application/json, text/plain, */*",
                  #"if-none-match" : 'W\"1fad0-bLhemXqmkyZM/HkzvOWPHAxfdfE\"'}

        
    else:                                                                                                          
        #time.sleep(5)
        print("in the else")
        url3 = f"https://www.totalwine.com/search/api/product/categories/v2/categories/c0020/products?page={page}&pageSize=24&state=US-NJ&shoppingMethod=INSTORE_PICKUP%2CDELIVERY%2CSHIPPING&userShoppingMethod=INSTORE_PICKUP&allStoresCount=true&storeId=301&department=Wine&_br_uid_2=uid%3D3243838382926%3Av%3D12.0%3Ats%3D1606758592624%3Ahc%3D38"
        #headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36', 
                   
                    #"referer": f"https://www.totalwine.com/wine/c/c0020?viewall=true&page={page}&pageSize=24&department=Wine",
                   #"accept": "application/json, text/plain, */*"}
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66\
        Safari/537.36',"Upgrade-Insecure-Requests": "1","DNT": "1", "accept": "application/json, text/plain, */*",
        "accept-language": "en-US,en;q=0.9", "accept-encoding"  : "gzip, deflate, br"}             
                  
                    
                    
                    
                    
        # "referer" : f"https://www.totalwine.com/wine/c/c0020?viewall=true&page={page}&pageSize=24&department=Wine",
        #headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}
    
    response_real= requests.get(url3, headers=headers, timeout=200)
    data_real = response_real.json()
    #data_real = json.loads(response_real)
    print(f"page: {page} response {response_real}")
    

    products_all = data_real["products"]

    
    for name in products_all:
        names.append(name)
        
print(page)
print(len(names))
# Out:
# in the if
# page: 1 response <Response [200]>
# in the else
# page: 2 response <Response [200]>
# in the else
# page: 3 response <Response [200]>
# in the else
# page: 4 response <Response [200]>
# 4
# 96

# %%
print(names)
# Out:
# [{'brand': {'id': 'Renieri', 'name': 'Renieri'}, 'categories': [{'id': '000466', 'name': 'Tuscany', 'type': 'REGION', 'url': 'https://www.totalwine.com/wine/italy/tuscany/c/000466', 'storefrontUrl': '/wine/italy/tuscany/c/000466'}, {'id': '000009', 'name': 'Red Wine', 'type': 'PRODUCT_TYPE', 'url': 'https://www.totalwine.com/wine/red-wine/c/000009', 'storefrontUrl': '/wine/red-wine/c/000009'}, {'id': '000012', 'name': 'Red Blend', 'type': 'VARIETAL_TYPE', 'url': 'https://www.totalwine.com/wine/red-wine/red-blend/c/000012', 'storefrontUrl': '/wine/red-wine/red-blend/c/000012'}], 'containerType': 'Bottle', 'customerAverageRating': 3.8, 'customerReviewsCount': 218, 'department': 'c0020', 'directType': 'Winery Direct', 'id': '113710750', 'images': [{'imageType': 'DEFAULT', 'mobileOptimizedUrl': 'https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png', 'thumbnailUrl': 'https://www.totalwine.com/media/sys_master/twmmedia/hbc/hc7/13177299402782.png', 'url': 'https://
# ...

# %%
data_set=[]
for x in names:
    #time.sleep(2)
    test1 = x["productUrl"]  
    full_url = base_url +test1+end_url
       

    res_str = full_url.replace('deals/', '') 

        # removes all occurrences of deals/ 
    print ("referer: " + res_str)

        
    productsid = x["skuId"]
        
        #print(f"page: {page}, skuId is {productsid}")
    name = x["name"]
    price = x["price"][0]["price"]
    print(f"skuid {productsid}")
    print(f"name {name}")
    product_url = f"https://www.totalwine.com/product/api/product/product-detail/v1/getProduct/{productsid}?shoppingMethod=INSTORE_PICKUP&state=US-NJ&storeId=301"
                   https://www.totalwine.com/product/api/product/product-detail/v1/getProduct/113710750-1?shoppingMethod=INSTORE_PICKUP&state=US-NJ&storeId=301    
        #headers:{'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}
    #headers:{'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36', 
                 #"referer": "https://www.totalwine.com/wine/c/c0020?viewall=true&pageSize=24&department=Wine",
            #"referer": res_str,
            #"accept": "application/json, text/plain, */*"}
            
            
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66\
    Safari/537.36',"Upgrade-Insecure-Requests": "1","DNT": "1", "accept": "application/json, text/plain, */*",
        "accept-language": "en-US,en;q=0.9", "accept-encoding"  : "gzip, deflate, br" , "referer": res_str}       
    
        
    #headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66\
    #Safari/537.36',"Upgrade-Insecure-Requests": "1","DNT": "1", "accept": "application/json, text/plain, */*",
        #"accept-language": "en-US,en;q=0.9", "accept-encoding"  : "gzip, deflate, br"}
    individual_product_response= requests.get(product_url, headers=headers, timeout=120)
    product_real = individual_product_response.json()
    print(json.dumps(product_real, indent=4, sort_keys=True))
    type1 = product_real["categories"][0]["name"]
    data_set.append({"skuId":productsid,
                        "name" : name,
                        "price" : price,
                        "type" : type1})
    break    
print(data_set)
# Out:
# referer: https://www.totalwine.com/wine/red-wine/red-blend/renieri-invetro/p/113710750?s=301&igrules=true
# skuid 113710750-1
# name Renieri Invetro, 2016
# {
#     "appId": "PXFF0j69T5",
#     "blockScript": "/FF0j69T5/captcha/captcha.js?a=c&u=40199fc0-35a1-11eb-a1b4-097188b02468&v=&m=0",
#     "firstPartyEnabled": true,
#     "hostUrl": "/FF0j69T5/xhr",
#     "jsClientSrc": "/FF0j69T5/init.js",
#     "uuid": "40199fc0-35a1-11eb-a1b4-097188b02468",
#     "vid": ""
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-222-7e05e7d5386b> in <module>
#      39     product_real = individual_product_response.json()
#      40     print(json.dumps(product_real, indent=4, sort_keys=True))
# ---> 41     type1 = product_real["categories"][0]["name"]
#      42     data_set.append({"skuId":productsid,
#      43                         "name" : name,
#
# ...

# %%
product_url_test = "https://www.totalwine.com/product/api/product/product-detail/v1/getProduct/140006750-1?shoppingMethod=INSTORE_PICKUP&state=US-NJ&storeId=301"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'}

product_response_real= requests.get(product_url_test, headers=headers)
product_real_test = product_response_real.json()

print(json.dumps(product_real_test, indent=4, sort_keys=True))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-154-a563abfd4933> in <module>
#       3
#       4 product_response_real= requests.get(product_url_test, headers=headers)
# ----> 5 product_real_test = product_response_real.json()
#       6
#       7 print(json.dumps(product_real_test, indent=4, sort_keys=True))
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\envs\PythonData\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
# ...

# %%
xxxx= product_real_test["categories"][0]["name"]
xxxx
# Out:
# 'Red Wine'
