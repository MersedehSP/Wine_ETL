# %%
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import pandas as pd
import time
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {"executable_path": ChromeDriverManager().install()}
browser = Browser("chrome", **executable_path, headless=False)

url= "https://lawrenceville.jcanals.com/wines/"

browser.visit(url)
    
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
soup.prettify()
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\brega\.wdm\drivers\chromedriver\win32\87.0.4280.20\chromedriver.exe] found in cache
# ...

# %%
#print(browser.windows)
#time.sleep(14)
#print(browser.is_element_present_by_id('element_to_pop_up'))
  

if browser.is_element_present_by_id('element_to_pop_up'):
    print(browser.windows)
    x= browser.find_by_id('element_to_pop_up')
    x.first.find_by_tag("img").click()

    
    
    #close.click
    #<span class="button b-close"><span><img src="/images/sites/modal-close.png"></span></span>
# Out:
# [<Window CDwindow-2A670DE8275F5D7AD6B82F112EEB623E: https://lawrenceville.jcanals.com/wines/>]
