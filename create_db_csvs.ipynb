# %%
import requests
import json
import pandas as pd
import time

# %%
fileName    = "allwine.csv";
region_df = pd.read_csv(fileName)
region_df
# Out:
#                                                    name        country  \
# 0                     Angels Landing Cabernet Sauvignon  United States
# 1                            Angels Landing Merlot Napa  United States
# 2                                   Antale Veneto Rosso          Italy
# 3             Articulate Cabernet Sauvignon Walla Walla  United States
# 4        Baus Family Cabernet Sauvignon Private Reserve  United States
# ...                                                 ...            ...
# 4531                                   Souverain Merlot  United States
# 4532   Buena Vista Chateau Buena Vista Cabernet Sauv...  United States
# 4533        Robert Mondavi Private Selection Pinot Noir  United States
# 4534                        Lindemans Pinot Noir Bin 99      Australia
# 4535                        14 Hands Cabernet Sauvignon  United States
#
#                   region                    state            varietal  price  \
# 0            Napa Valley               California  Cabernet Sauvignon  22.99
# 1            Napa Valley               California              Merlot  16.99
# 2                 Veneto                   Veneto             Corvina  11.99
# 3     Walla Walla Valley               Washington  Cabernet Sauvignon  14.99
# 4       Alexander Valley               California  Cabernet Sauvignon  16.99
# ...                  ...                      ...                 ...    ...
# 4531                 NaN               California              Merlot   9.99
# 4532         Napa County               California  Cabernet Sauvignon  34.99
# 4533       Central Coast               California          Pinot Noir   8.99
# 4534                 NaN  South Eastern Australia          Pinot Noir   5.99
# 4535     Columbia Valley               Washington  Cabernet Sauvignon  10.99
#
#                                             description          merchant  \
# 0     This Cabernet has it all. Ripe dark fruit, str...      Gary's Wayne
# 1     A rich mix of black fruit, hints of dark choco...      Gary's Wayne
# 2     Producing every style of wine and with great s...      Gary's Wayne
# 3                                                   NaN      Gary's Wayne
# 4     A full-bodied and rich Cabernet, this wine is ...      Gary's Wayne
# ...                                                 ...               ...
# 4531  Authentic - Wines that are the best expression...  Petrocks Liquors
# 4532  In the 1860âs Buena Vista covered more than ...  Petrocks Liquors
# 4533  Unlike other reds, Pinot Noir grapes prefer th...  Petrocks Liquors
# 4534  Lindemanâs wines contain the spirit and pass...  Petrocks Liquors
# 4535  The inspiration for 14 Hands wines recalls a t...  Petrocks Liquors
#
#                                      address
# 0           1308 NJ-23, Wayne, NJ 07470, USA
# 1           1308 NJ-23, Wayne, NJ 07470, USA
# 2           1308 NJ-23, Wayne, NJ 07470, USA
# 3           1308 NJ-23, Wayne, NJ 07470, USA
# 4           1308 NJ-23, Wayne, NJ 07470, USA
# ...                                      ...
# 4531  419 Amwell Road Hillsborough, NJ 08844
# 4532  419 Amwell Road Hillsborough, NJ 08844
# 4533  419 Amwell Road Hillsborough, NJ 08844
# 4534  419 Amwell Road Hillsborough, NJ 08844
# 4535  419 Amwell Road Hillsborough, NJ 08844
#
# [4536 rows x 9 columns]

# %%
pd.set_option('display.max_rows', 100)

# %%
test1 = region_df.groupby(['country','region', 'state']).size().reset_index().rename(columns={0:'count'})
test2 = test1.reset_index()
test3 = test2.rename(columns={"index": 'Region_Id'})

test3=test3.drop(['count'] , axis='columns')
# Out:
#      Region_Id        country              region              state
# 0            0      Argentina             Mendoza               Cuyo
# 1            1      Argentina             Mendoza            Mendoza
# 2            2      Argentina           Patagonia    Southern Region
# 3            3      Argentina               Salta  Andean North West
# 4            4      Australia      Adelaide Hills    South Australia
# ..         ...            ...                 ...                ...
# 413        413  United States  Walla Walla Valley         Washington
# 414        414  United States        Warren Hills         New Jersey
# 415        415  United States          Willamette             Oregon
# 416        416  United States   Willamette Valley             Oregon
# 417        417  United States         Yolo County         California
#
# [418 rows x 4 columns]

# %%
test3.to_csv('region.csv', encoding='utf-8', index=False)

# %%
new_df = pd.merge(region_df, test3,  how='left', left_on=['country','region','state'], right_on = ['country','region','state'])
new_df = new_df.drop(['country','region', 'state', 'address' ] , axis='columns')
# Out:
#                                                    name            varietal  \
# 0                     Angels Landing Cabernet Sauvignon  Cabernet Sauvignon
# 1                            Angels Landing Merlot Napa              Merlot
# 2                                   Antale Veneto Rosso             Corvina
# 3             Articulate Cabernet Sauvignon Walla Walla  Cabernet Sauvignon
# 4        Baus Family Cabernet Sauvignon Private Reserve  Cabernet Sauvignon
# ...                                                 ...                 ...
# 4531                                   Souverain Merlot              Merlot
# 4532   Buena Vista Chateau Buena Vista Cabernet Sauv...  Cabernet Sauvignon
# 4533        Robert Mondavi Private Selection Pinot Noir          Pinot Noir
# 4534                        Lindemans Pinot Noir Bin 99          Pinot Noir
# 4535                        14 Hands Cabernet Sauvignon  Cabernet Sauvignon
#
#       price                                        description  \
# 0     22.99  This Cabernet has it all. Ripe dark fruit, str...
# 1     16.99  A rich mix of black fruit, hints of dark choco...
# 2     11.99  Producing every style of wine and with great s...
# 3     14.99                                                NaN
# 4     16.99  A full-bodied and rich Cabernet, this wine is ...
# ...     ...                                                ...
# 4531   9.99  Authentic - Wines that are the best expression...
# 4532  34.99  In the 1860âs Buena Vista covered more than ...
# 4533   8.99  Unlike other reds, Pinot Noir grapes prefer th...
# 4534   5.99  Lindemanâs wines contain the spirit and pass...
# 4535  10.99  The inspiration for 14 Hands wines recalls a t...
#
#               merchant  Region_Id
# 0         Gary's Wayne      382.0
# 1         Gary's Wayne      382.0
# 2         Gary's Wayne      296.0
# 3         Gary's Wayne      413.0
# 4         Gary's Wayne      352.0
# ...                ...        ...
# 4531  Petrocks Liquors        NaN
# 4532  Petrocks Liquors      381.0
# 4533  Petrocks Liquors      358.0
# 4534  Petrocks Liquors        NaN
# 4535  Petrocks Liquors      362.0
#
# [4536 rows x 6 columns]

# %%
new_df.to_csv('wine.csv', encoding='utf-8', index=False)

# %%
new_df.sort_values(by='Region_Id')
# Out:
#                                                    name        country  \
# 2894                  Tapiz Alta Collection Malbec 2017      Argentina
# 3477                          Alta Vista Classic Malbec      Argentina
# 2564                                  Layer Cake Malbec      Argentina
# 4140                           Don Miguel Gascon Malbec      Argentina
# 2517                                      Alamos Malbec      Argentina
# ...                                                 ...            ...
# 4528   Walter Hansel Estate Chardonnay Russian River...  United States
# 4529                              Dark Horse Pinot Noir  United States
# 4530                  Louis Latour Bourgogne Pinot Noir         France
# 4531                                   Souverain Merlot  United States
# 4534                        Lindemans Pinot Noir Bin 99      Australia
#
#        region                    state    varietal  price  \
# 2894  Mendoza                     Cuyo  Uco Valley  19.99
# 3477  Mendoza                     Cuyo      Malbec  12.99
# 2564  Mendoza                     Cuyo      Malbec  18.99
# 4140  Mendoza                     Cuyo      Malbec  15.99
# 2517  Mendoza                     Cuyo      Malbec  12.99
# ...       ...                      ...         ...    ...
# 4528      NaN                      NaN         NaN  29.99
# 4529      NaN               California  Pinot Noir   7.99
# 4530      NaN                 Burgundy  Pinot Noir  19.99
# 4531      NaN               California      Merlot   9.99
# 4534      NaN  South Eastern Australia  Pinot Noir   5.99
#
#                                             description            merchant  \
# 2894  The Sommelier Journal said Tapiz is a slam dun...  Chatham BottleKing
# 3477  Established in 1998, Alta Vista is a French fa...  Chatham BottleKing
# 2564  The once 5 mile wide Mendoza River is now most...  Chatham BottleKing
# 4140  Tradition and innovation blended harmoniously ...  Chatham BottleKing
# 2517  From the vineyard to the winery, the Alamos wi...  Chatham BottleKing
# ...                                                 ...                 ...
# 4528                                                NaN    Petrocks Liquors
# 4529  At Darkhorse wines, we challenge the belief th...    Petrocks Liquors
# 4530  Over time, Maison Louis Latour has set an idea...    Petrocks Liquors
# 4531  Authentic - Wines that are the best expression...    Petrocks Liquors
# 4534  Lindemanâs wines contain the spirit and pass...    Petrocks Liquors
#
#                                      address  Region_Id  count
# 2894     41 Watchung Ave, Chatham, NJ, 07928        0.0   30.0
# 3477     41 Watchung Ave, Chatham, NJ, 07928        0.0   30.0
# 2564     41 Watchung Ave, Chatham, NJ, 07928        0.0   30.0
# 4140     41 Watchung Ave, Chatham, NJ, 07928        0.0   30.0
# 2517     41 Watchung Ave, Chatham, NJ, 07928        0.0   30.0
# ...                                      ...        ...    ...
# 4528  419 Amwell Road Hillsborough, NJ 08844        NaN    NaN
# 4529  419 Amwell Road Hillsborough, NJ 08844        NaN    NaN
# 4530  419 Amwell Road Hillsborough, NJ 08844        NaN    NaN
# 4531  419 Amwell Road Hillsborough, NJ 08844        NaN    NaN
# 4534  419 Amwell Road Hillsborough, NJ 08844        NaN    NaN
#
# [4536 rows x 11 columns]

# %%
region_df
# Out:
#                                                    name        country  \
# 0                     Angels Landing Cabernet Sauvignon  United States
# 1                            Angels Landing Merlot Napa  United States
# 2                                   Antale Veneto Rosso          Italy
# 3             Articulate Cabernet Sauvignon Walla Walla  United States
# 4        Baus Family Cabernet Sauvignon Private Reserve  United States
# ...                                                 ...            ...
# 4531                                   Souverain Merlot  United States
# 4532   Buena Vista Chateau Buena Vista Cabernet Sauv...  United States
# 4533        Robert Mondavi Private Selection Pinot Noir  United States
# 4534                        Lindemans Pinot Noir Bin 99      Australia
# 4535                        14 Hands Cabernet Sauvignon  United States
#
#                   region                    state            varietal  price  \
# 0            Napa Valley               California  Cabernet Sauvignon  22.99
# 1            Napa Valley               California              Merlot  16.99
# 2                 Veneto                   Veneto             Corvina  11.99
# 3     Walla Walla Valley               Washington  Cabernet Sauvignon  14.99
# 4       Alexander Valley               California  Cabernet Sauvignon  16.99
# ...                  ...                      ...                 ...    ...
# 4531                 NaN               California              Merlot   9.99
# 4532         Napa County               California  Cabernet Sauvignon  34.99
# 4533       Central Coast               California          Pinot Noir   8.99
# 4534                 NaN  South Eastern Australia          Pinot Noir   5.99
# 4535     Columbia Valley               Washington  Cabernet Sauvignon  10.99
#
#                                             description          merchant  \
# 0     This Cabernet has it all. Ripe dark fruit, str...      Gary's Wayne
# 1     A rich mix of black fruit, hints of dark choco...      Gary's Wayne
# 2     Producing every style of wine and with great s...      Gary's Wayne
# 3                                                   NaN      Gary's Wayne
# 4     A full-bodied and rich Cabernet, this wine is ...      Gary's Wayne
# ...                                                 ...               ...
# 4531  Authentic - Wines that are the best expression...  Petrocks Liquors
# 4532  In the 1860âs Buena Vista covered more than ...  Petrocks Liquors
# 4533  Unlike other reds, Pinot Noir grapes prefer th...  Petrocks Liquors
# 4534  Lindemanâs wines contain the spirit and pass...  Petrocks Liquors
# 4535  The inspiration for 14 Hands wines recalls a t...  Petrocks Liquors
#
#                                      address
# 0           1308 NJ-23, Wayne, NJ 07470, USA
# 1           1308 NJ-23, Wayne, NJ 07470, USA
# 2           1308 NJ-23, Wayne, NJ 07470, USA
# 3           1308 NJ-23, Wayne, NJ 07470, USA
# 4           1308 NJ-23, Wayne, NJ 07470, USA
# ...                                      ...
# 4531  419 Amwell Road Hillsborough, NJ 08844
# 4532  419 Amwell Road Hillsborough, NJ 08844
# 4533  419 Amwell Road Hillsborough, NJ 08844
# 4534  419 Amwell Road Hillsborough, NJ 08844
# 4535  419 Amwell Road Hillsborough, NJ 08844
#
# [4536 rows x 9 columns]

# %%
merchant_address = region_df.groupby(['merchant','address']).nunique()
merchant_address = merchant_address.drop(['name','country', 'state', 'region', 'varietal','price', 'description','merchant', 'address' ] , axis='columns')
merchant_address
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Chatham BottleKing, 41 Watchung Ave, Chatham, NJ, 07928), (Gary's Wayne, 1308 NJ-23, Wayne, NJ 07470, USA), (Petrocks Liquors, 419 Amwell Road Hillsborough, NJ 08844)]

# %%
new_df.to_csv('merchant.csv', encoding='utf-8', index=False)
